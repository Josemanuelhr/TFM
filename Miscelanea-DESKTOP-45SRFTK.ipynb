# %% [markdown]
# # Análisis exploratorio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import minmax_scale

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_csv('./results/experimentacion/UC3/hito3.csv')
df["mean"] = df.mean(numeric_only=True, axis=1)
df
# Out:
#     empresa_1  empresa_2  empresa_3      mean
# 0    0.562830   0.790333   0.435621  0.596261
# 1    0.563708   0.789027   0.438457  0.597064
# 2    0.566344   0.782495   0.445831  0.598223
# 3    0.570738   0.775963   0.459444  0.602049
# 4    0.578647   0.773351   0.473624  0.608541
# ..        ...        ...        ...       ...
# 60   0.678823   0.699543   0.686330  0.688232
# 61   0.678823   0.699543   0.686330  0.688232
# 62   0.678823   0.699543   0.686330  0.688232
# 63   0.678823   0.699543   0.686330  0.688232
# 64   0.678823   0.699543   0.686330  0.688232
#
# [65 rows x 4 columns]

# %%
df = pd.read_csv("./data/horizontal/empresa_2/cliente_1.csv")

df.head(10)
# Out:
#       psd_delta     psd_theta     psd_alpha       psd_beta      psd_gamma  \
# 0  1.305710e+07  1.945174e+06  8.350721e+05  582391.139425  503931.675274
# 1  1.316114e+07  1.744535e+06  7.364743e+05  525038.985724  423838.617027
# 2  6.110334e+06  1.538639e+06  7.639427e+05  498007.080396  454352.799634
# 3  6.245169e+06  1.476267e+06  6.425352e+05  461100.468244  484138.573812
# 4  2.192558e+07  1.996175e+06  8.657071e+05  524294.156610  469608.907826
# 5  5.293694e+06  1.574322e+06  1.306561e+06  520706.516106  406643.214169
# 6  1.128205e+07  1.748922e+06  8.659507e+05  532840.793747  476667.471274
# 7  1.231788e+07  1.804999e+06  8.834435e+05  550807.455771  497999.874953
# 8  1.415906e+07  1.964146e+06  9.456553e+05  549177.173852  486123.272008
# 9  1.738014e+07  2.216037e+06  1.060389e+06  747321.174198  782080.224865
#
#    eog_blinks       eog_var     y_reg  y_class
# 0           0  1.037713e-10  0.119233    False
# 1           1  6.786951e-09  0.149089    False
# 2           2  7.330638e-09  0.177563    False
# 3           2  2.657537e-09  0.194524    False
# 4           2  3.379798e-09  0.220294    False
# 5           0  9.780409e-11  0.250505    False
# 6           0  1.611079e-10  0.277601    False
# 7           3  4.298973e-09  0.304634    False
# 8           6  1.369031e-08  0.325717    False
# 9           5  9.058930e-09  0.334196    False

# %%
fig, axes = plt.subplots(figsize=(16,6),nrows=1, ncols=2)


axes[0].plot(minmax_scale(df["eog_blinks"]), label="Blinks")
df["y_reg"].plot(ax=axes[0], label="PERCLOS")
axes[0].set_title("Relacion entre n_parpadeos y el PERCLOS para un sujeto")
axes[0].legend()

axes[1].plot(minmax_scale(df["eog_var"]))
df["y_reg"].plot(ax=axes[1])
axes[1].set_title("Relacion entre varianza_EOG y el PERCLOS para un sujeto")
axes[1].legend()

# %%
fig, axes = plt.subplots(figsize=(16,6), nrows=1, ncols=2)

axes[0].plot(minmax_scale(df["psd_alpha"]))
df["y_reg"].plot(ax=axes[0], label="PERCLOS")
axes[0].set_title("Relacion entre psd_alpha y el PERCLOS para un sujeto")
axes[0].legend()

axes[1].plot(minmax_scale(df["psd_theta"]))
df["y_reg"].plot(ax=axes[1], label="PERCLOS")
axes[1].set_title("Relacion entre psd_theta y el PERCLOS para un sujeto")
axes[1].legend()

# %% [markdown]
# # non-IID

# %% [markdown]
# ## Diferente distribución de clases

# %%
def prepare_model_data(client_file):
    df = pd.read_csv(client_file)
    
    train, test = train_test_split(df, test_size=0.30, random_state=42)
    
    X_train = train[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]
    X_test = test[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]
    y_train = train['y_class']
    y_test = test['y_class']
    
    scaler = StandardScaler()

    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test

# %%
def cargar_dataset_varios_clientes(clientes):
    base_path = "./data/centralizado"
    
    X_train, X_val, y_train, y_val = prepare_model_data(f'{base_path}/cliente_{clientes[0]}.csv')
    
    for cid in clientes[1:]:
        path = f'{base_path}/cliente_{cid}.csv'
        X_train_act, X_val_act, y_train_act, y_val_act = prepare_model_data(path)
    
        X_train = np.vstack((X_train, X_train_act))
        X_val = np.vstack((X_val, X_val_act))
        y_train = np.concatenate((y_train, y_train_act))
        y_val = np.concatenate((y_val, y_val_act))
        
    return X_train, X_val, y_train, y_val

# %%
base_path = "./data/horizontal/"
fig = plt.figure(figsize=(20,6))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, cliente in enumerate(range(2,22,2)):
    path = f"{base_path}empresa_1/cliente_{cliente}.csv"
    x_train, x_val, y_train, y_val = prepare_model_data(path)
    
    y = np.concatenate((y_train, y_val)).astype(int)
    
    ax = fig.add_subplot(2,5,i+1)
    
    ax.hist(x=y, bins=2, color='#0504aa', alpha=0.7, rwidth=0.85)
    ax.set_xticks([0.25, 0.75])
    ax.set_xticklabels(["Despierto", "Somnoliento"])
    ax.set_title(f"Cliente {cliente}")
    
fig.suptitle("Distribución de clases de los clientes para la empresa 1")
# Out:
# Text(0.5, 0.98, 'Distribución de clases de los clientes para la empresa 1')

# %%
base_path = "./data/horizontal/"
fig = plt.figure(figsize=(20,9))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i, cliente in enumerate(range(1,22,2)):
    path = f"{base_path}empresa_2/cliente_{cliente}.csv"
    x_train, x_val, y_train, y_val = prepare_model_data(path)
    
    y = np.concatenate((y_train, y_val)).astype(int)
    
    ax = fig.add_subplot(3,5,i+1)
    
    ax.hist(x=y, bins=2, color='#0504aa', alpha=0.7, rwidth=0.85)
    ax.set_xticks([0.25, 0.75])
    ax.set_xticklabels(["Despierto", "Somnoliento"])
    ax.set_title(f"Cliente {cliente}")
    
fig.suptitle("Distribución de clases de los clientes para la empresa 2")
# Out:
# Text(0.5, 0.98, 'Distribución de clases de los clientes para la empresa 2')

# %% [markdown]
# ## Clustering en base a la distribucion de clases
#
# - Empresa A: D ≈ S
# - Empresa B: D ≫ S
# - Empresa C: S ≫ D
#
# **Si la proporción de despiertos es 66% o superior => B**
#
# **Si la proporción de somnolientos es 66% o superior => C**
#
# **Sino => A**

# %%
empresa = {
    1: [],
    2: [],
    3: []
}

for cid in range(1,22):
    # leer datos
    base_path = "./data/horizontal/"
    path = f"{base_path}empresa_{(int(cid)%2)+1}/cliente_{cid}.csv"
    
    X_train, X_val, y_train, y_val = prepare_model_data(path)
    
    # agrupar train y test en un unico X e y
    
    X = np.vstack((X_train, X_val))
    y = np.concatenate((y_train, y_val))
    
    # calcular proporcion de clases
    total = np.size(y)
    som = np.count_nonzero(y)
    desp = total-som
    p_desp = desp/total
    p_som = som/total

#     print(f'Cid:{cid} --- T:{total}, Des:{desp/total}, Som:{som/total}')
    
    # mapear a A, B o C
    if p_desp > 0.33 and p_desp < 0.66:
        empresa[1].append(cid)
    elif p_desp >= 0.66:
        empresa[2].append(cid)
    else:
        empresa[3].append(cid)
    
empresa
# Out:
# {1: [3, 4, 5, 12, 13, 14, 15, 18],
#  2: [2, 8, 9, 17, 20, 21],
#  3: [1, 6, 7, 10, 11, 16, 19]}

# %%
base_path = "./data/horizontal/"

for e in empresa:
    fig = plt.figure(figsize=(20,6))
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    for i, cid in enumerate(empresa[e]):
        path = f"{base_path}empresa_{(int(cid)%2)+1}/cliente_{cid}.csv"
        x_train, x_val, y_train, y_val = prepare_model_data(path)

        y = np.concatenate((y_train, y_val)).astype(int)

        ax = fig.add_subplot(2,5,i+1)

        ax.hist(x=y, bins=2, color='#0504aa', alpha=0.7, rwidth=0.85)
        ax.set_xticks([0.25, 0.75])
        ax.set_xticklabels(["Despierto", "Somnoliento"])
        ax.set_title(f"Cliente {cid}")
    
    fig.suptitle(f'Distribución de clases de los clientes para la empresa {e}')

# %% [markdown]
# ## Distribuciones de las features para diferentes sujetos

# %%
from pandas.plotting import parallel_coordinates

# %%
average_values = pd.DataFrame(columns=['cliente', 'psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var', 'y_class'])

for i in range(1,22):
    df = pd.read_csv(f"./data/centralizado/cliente_{i}.csv")

    df_norm = df[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]

    df_norm = (df_norm-df_norm.mean())/df_norm.std()

    df_norm["y_class"] = df["y_class"]
    
    
    res = dict(df_norm[df_norm["y_class"] == 0].mean())
    res['cliente'] = i
    average_values = average_values.append(res, ignore_index=True)
    
    res = dict(df_norm[df_norm["y_class"] == 1].mean())
    res['cliente'] = i
    average_values = average_values.append(res, ignore_index=True)

average_values["cliente"] = average_values["cliente"].apply(lambda x: int(x))
average_values
# Out:
#     cliente  psd_delta  psd_theta  psd_alpha  psd_beta  psd_gamma  eog_blinks  \
# 0         1  -0.454906  -0.759680  -0.681680  0.858093   1.012179    0.817201
# 1         1   0.058462   0.097630   0.087605 -0.110277  -0.130079   -0.105022
# 2         2   0.054800  -0.102203  -0.084771 -0.058290  -0.051507    0.090671
# 3         2  -0.313576   0.584831   0.485081  0.333547   0.294737   -0.518840
# 4         3  -0.144076  -0.089279  -0.070592  0.413804   0.353295    0.261539
# 5         3   0.091438   0.056661   0.044801 -0.262622  -0.224219   -0.165986
# 6         4  -0.349842  -0.655552  -0.692951  0.033975   0.199767    0.232703
# 7         4   0.216488   0.405666   0.428809 -0.021024  -0.123619   -0.144001
# 8         5  -0.134237  -0.240883  -0.295889  0.057916   0.067968   -0.032475
# 9         5   0.098171   0.176165   0.216392 -0.042356  -0.049707    0.023750
# 10        6   0.115621  -0.162415  -0.243289 -0.246398  -0.212186    0.210769
# 11        6  -0.019192   0.026959   0.040383  0.040899   0.035220   -0.034985
# 12        7  -0.342204  -0.341342  -0.436759 -0.557006  -0.581071   -0.248265
# 13        7   0.130711   0.130382   0.166828  0.212758   0.221950    0.094829
# 14        8   0.062918   0.054746   0.056471  0.075169   0.069503    0.174224
# 15        8  -0.165325  -0.143851  -0.148385 -0.197516  -0.182626   -0.457793
# 16        9   0.007204  -0.058354  -0.365672 -0.157537   0.108972    0.210479
# 17        9  -0.015425   0.124949   0.782985  0.337322  -0.233333   -0.450683
# 18       10  -0.238213  -0.632737  -0.735751 -0.079606   0.005268    0.320235
# 19       10   0.039915   0.106022   0.123283  0.013339  -0.000883   -0.053659
# 20       11   0.032133  -0.639284  -0.665795 -0.154958  -0.200133   -0.110887
# 21       11  -0.005326   0.105959   0.110353  0.025684   0.033171    0.018379
# 22       12   0.075425  -0.628200  -0.786672  0.112717   0.797402    0.880944
# 23       12  -0.040867   0.340375   0.426238 -0.061073  -0.432052   -0.477318
# 24       13   0.339646  -0.415989  -0.669764 -0.188919   0.285417    1.015794
# 25       13  -0.199241   0.244025   0.392893  0.110823  -0.167430   -0.595879
# 26       14  -0.053551  -0.297449  -0.556625 -0.229264  -0.025586    0.282974
# 27       14   0.027639   0.153522   0.287290  0.118330   0.013206   -0.146051
# 28       15  -0.206113  -0.320619  -0.511738 -0.332182  -0.226733    0.165790
# 29       15   0.208515   0.324356   0.517702  0.336054   0.229376   -0.167723
# 30       16  -0.414549  -0.793487  -0.450538  0.259269   0.427153    0.672559
# 31       16   0.101726   0.194714   0.110557 -0.063622  -0.104819   -0.165039
# 32       17  -0.015917   0.168212  -0.452259  0.060146   0.077143    0.249376
# 33       17   0.047297  -0.499853   1.343917 -0.178729  -0.229236   -0.741038
# 34       18  -0.182402  -0.371818  -0.522089  0.239324   0.379037    0.505532
# 35       18   0.141999   0.289458   0.406443 -0.186312  -0.295078   -0.393554
# 36       19   0.146556  -0.377390  -0.855015  0.077374   0.529525    0.460616
# 37       19  -0.020339   0.052375   0.118660 -0.010738  -0.073488   -0.063925
# 38       20  -0.406305  -0.302617  -0.254349 -0.244450  -0.124492    0.167932
# 39       20   1.023348   0.762193   0.640623  0.615689   0.313553   -0.422966
# 40       21   0.024362  -0.231098  -0.361691  0.096997   0.196134    0.103581
# 41       21  -0.051217   0.485851   0.760405 -0.203924  -0.412344   -0.217764
#
#      eog_var  y_class
# 0   0.809104      0.0
# 1  -0.103981      1.0
# 2   0.084827      0.0
# 3  -0.485396      1.0
# 4   0.350333      0.0
# 5  -0.222340      1.0
# 6   0.078476      0.0
# 7  -0.048562      1.0
# 8  -0.030775      0.0
# 9   0.022507      1.0
# 10  0.382512      0.0
# 11 -0.063492      1.0
# 12 -0.227479      0.0
# 13  0.086890      1.0
# 14  0.108123      0.0
# 15 -0.284105      1.0
# 16  0.198544      0.0
# 17 -0.425126      1.0
# 18  0.204610      0.0
# 19 -0.034285      1.0
# 20 -0.288731      0.0
# 21  0.047856      1.0
# 22  0.965059      0.0
# 23 -0.522893      1.0
# 24  0.995205      0.0
# 25 -0.583801      1.0
# 26  0.356684      0.0
# 27 -0.184095      1.0
# 28  0.082849      0.0
# 29 -0.083814      1.0
# 30  0.513002      0.0
# 31 -0.125885      1.0
# 32  0.291649      0.0
# 33 -0.866653      1.0
# 34  0.429137      0.0
# 35 -0.334081      1.0
# 36 -0.117156      0.0
# 37  0.016259      1.0
# 38  0.256479      0.0
# 39 -0.645986      1.0
# 40  0.120527      0.0
# 41 -0.253391      1.0

# %%
import matplotlib

f = plt.figure(figsize=(12,6))
ax = f.add_subplot()
ax.set_facecolor('white')
ax.tick_params(axis="both", which='major', labelsize=14)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.grid(b=None)

parallel_coordinates(average_values, 'y_class',
                    cols=['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var'],
                    color=["lime", "tomato"],
                    alpha=.7,
                    lw=2, 
                    axvlines_kwds={"color":"black", "lw": 1},)

L = plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0, ncol=1)
L.get_texts()[0].set_text('Despierto')
L.get_texts()[1].set_text('Somnoliento')

# f.savefig('./non-IID.pdf',bbox_extra_artists=(L,), bbox_inches='tight')

# %% [markdown]
# # Eval baseline models

# %% [markdown]
# ## Individual

# %%
df = pd.read_csv("./results/resultados-modelos-individuales.csv")

df["cliente"] = df["cliente"].apply(lambda x: int(x))
df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

df = df.sort_values(by=["cliente"])

print(df[["cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))

print(f'{df[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{df[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#     cliente  accuracy   tpr   tnr  f1_score
# 0         1      0.93  0.94  0.76      0.96
# 1         2      0.91  0.55  0.98      0.67
# 2         3      0.82  0.88  0.73      0.86
# 3         4      0.82  0.89  0.70      0.86
# 4         5      0.83  0.81  0.86      0.85
# 5         6      0.85  0.98  0.15      0.92
# 6         7      0.83  0.92  0.60      0.89
# 7         8      0.85  0.64  0.93      0.70
# 8         9      0.81  0.42  0.98      0.57
# 9        10      0.90  1.00  0.34      0.94
# 10       11      0.89  0.94  0.61      0.94
# 11       12      0.96  0.94  1.00      0.97
# 12       13      0.94  0.94  0.93      0.95
# 13       14      0.76  0.80  0.69      0.82
# 14       15      0.85  0.84  0.86      0.84
# 15       16      0.92  0.96  0.76      0.95
# 16       17      0.95  0.81  0.99      0.88
# 17       18      0.87  0.77  0.98      0.87
# 18       19      0.94  1.00  0.58      0.97
# 19       20      0.95  0.84  0.98      0.89
# 20       21      0.89  0.72  0.97      0.81
# accuracy    0.88
# tpr         0.84
# tnr         0.78
# f1_score    0.86
# dtype: float64
# accuracy    0.06
# tpr         0.15
# tnr         0.23
# f1_score    0.10
# dtype: float64

# %% [markdown]
# **Agrupados por empresa para el UC1/2**

# %%
IDS_EMPRESA = {
    1: [3,4,5,12,  2,8,  1],
    2: [13,14,    6,7,10,11,16],
    3: [15,18,  9,17,20,21,  19]
}

df["empresa"] = [1,1,1,1,1,2,2,1,3,2,2,1,2,2,3,2,3,3,3,3,3]

for e, data in df.groupby("empresa"):
    data = data.sort_values(by=["cliente"])
    print(data[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))
    print(f'{data[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{data[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 0         1        1      0.93  0.94  0.76      0.96
# 1         1        2      0.91  0.55  0.98      0.67
# 2         1        3      0.82  0.88  0.73      0.86
# 3         1        4      0.82  0.89  0.70      0.86
# 4         1        5      0.83  0.81  0.86      0.85
# 7         1        8      0.85  0.64  0.93      0.70
# 11        1       12      0.96  0.94  1.00      0.97
# accuracy    0.87
# tpr         0.81
# tnr         0.85
# f1_score    0.84
# dtype: float64
# accuracy    0.06
# tpr         0.15
# tnr         0.12
# f1_score    0.12
# dtype: float64
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 5         2        6      0.85  0.98  0.15      0.92
# 6         2        7      0.83  0.92  0.60      0.89
# 9         2       10      0.90  1.00  0.34      0.94
# 10        2       11      0.89  0.94  0.61      0.94
# 12        2       13      0.94  0.94  0.93      0.95
# 13        2       14      0.76  0.80  0.69      0.82
# 15        2       16      0.92  0.96  0.76      0.95
# accuracy    0.87
# tpr         0.93
# tnr         0.58
# f1_score    0.91
# dtype: float64
# accuracy    0.06
# tpr         0.06
# tnr         0.26
# f1_score    0.05
# dtype: float64
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 8         3        9      0.81  0.42  0.98      0.57
# 14        3       15      0.85  0.84  0.86      0.84
# 16        3       17      0.95  0.81  0.99      0.88
# 17        3       18      0.87  0.77  0.98      0.87
# 18        3       19      0.94  1.00  0.58      0.97
# 19        3       20      0.95  0.84  0.98      0.89
# 20        3       21      0.89  0.72  0.97      0.81
# accuracy    0.89
# tpr         0.77
# tnr         0.91
# f1_score    0.83
# dtype: float64
# accuracy    0.05
# tpr         0.18
# tnr         0.15
# f1_score    0.12
# dtype: float64

# %% [markdown]
# ## Empresa

# %%
df = pd.read_csv("./results/resultados-modelos-empresa.csv")

df["cliente"] = df["cliente"].apply(lambda x: int(x))
df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

# df = df.sort_values(by=["cliente"])

print(df[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))

print(f'{df[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{df[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#       empresa  cliente  accuracy   tpr   tnr  f1_score
# 0   empresa_1       10      0.76  0.76  0.74      0.84
# 1   empresa_1       12      0.94  0.92  0.99      0.95
# 2   empresa_1       14      0.78  0.79  0.76      0.83
# 3   empresa_1       16      0.91  0.94  0.78      0.94
# 4   empresa_1       18      0.84  0.82  0.88      0.85
# 5   empresa_1        2      0.64  0.90  0.59      0.45
# 6   empresa_1       20      0.80  0.82  0.79      0.68
# 7   empresa_1        4      0.79  0.81  0.77      0.83
# 8   empresa_1        6      0.83  0.94  0.23      0.91
# 9   empresa_1        8      0.80  0.60  0.88      0.63
# 10  empresa_2        1      0.88  0.89  0.76      0.93
# 11  empresa_2       11      0.77  0.82  0.45      0.86
# 12  empresa_2       13      0.81  0.91  0.63      0.85
# 13  empresa_2       15      0.79  0.84  0.75      0.79
# 14  empresa_2       17      0.77  0.85  0.74      0.63
# 15  empresa_2       19      0.83  0.85  0.67      0.90
# 16  empresa_2       21      0.86  0.77  0.91      0.79
# 17  empresa_2        3      0.73  0.73  0.73      0.77
# 18  empresa_2        5      0.80  0.81  0.79      0.83
# 19  empresa_2        7      0.71  0.69  0.76      0.77
# 20  empresa_2        9      0.76  0.66  0.80      0.62
# accuracy    0.80
# tpr         0.82
# tnr         0.73
# f1_score    0.79
# dtype: float64
# accuracy    0.07
# tpr         0.09
# tnr         0.16
# f1_score    0.13
# dtype: float64

# %%
for e, data in df.groupby("empresa"):
    data = data.sort_values(by=["cliente"])
    print(data[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))
    print(f'{data[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{data[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#      empresa  cliente  accuracy   tpr   tnr  f1_score
# 5  empresa_1        2      0.64  0.90  0.59      0.45
# 7  empresa_1        4      0.79  0.81  0.77      0.83
# 8  empresa_1        6      0.83  0.94  0.23      0.91
# 9  empresa_1        8      0.80  0.60  0.88      0.63
# 0  empresa_1       10      0.76  0.76  0.74      0.84
# 1  empresa_1       12      0.94  0.92  0.99      0.95
# 2  empresa_1       14      0.78  0.79  0.76      0.83
# 3  empresa_1       16      0.91  0.94  0.78      0.94
# 4  empresa_1       18      0.84  0.82  0.88      0.85
# 6  empresa_1       20      0.80  0.82  0.79      0.68
# accuracy    0.81
# tpr         0.83
# tnr         0.74
# f1_score    0.79
# dtype: float64
# accuracy    0.08
# tpr         0.10
# tnr         0.21
# f1_score    0.16
# dtype: float64
#       empresa  cliente  accuracy   tpr   tnr  f1_score
# 10  empresa_2        1      0.88  0.89  0.76      0.93
# 17  empresa_2        3      0.73  0.73  0.73      0.77
# 18  empresa_2        5      0.80  0.81  0.79      0.83
# 19  empresa_2        7      0.71  0.69  0.76      0.77
# 20  empresa_2        9      0.76  0.66  0.80      0.62
# 11  empresa_2       11      0.77  0.82  0.45      0.86
# 12  empresa_2       13      0.81  0.91  0.63      0.85
# 13  empresa_2       15      0.79  0.84  0.75      0.79
# 14  empresa_2       17      0.77  0.85  0.74      0.63
# 15  empresa_2       19      0.83  0.85  0.67      0.90
# 16  empresa_2       21      0.86  0.77  0.91      0.79
# accuracy    0.79
# tpr         0.80
# tnr         0.73
# f1_score    0.79
# dtype: float64
# accuracy    0.05
# tpr         0.08
# tnr         0.12
# f1_score    0.10
# dtype: float64

# %% [markdown]
# ## Empresa v2

# %%
df = pd.read_csv("./results/resultados-modelos-empresa_v2.csv")

df["cliente"] = df["cliente"].apply(lambda x: int(x))
df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

# df = df.sort_values(by=["cliente"])

print(df[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))

print(f'{df[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{df[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#       empresa  cliente  accuracy   tpr   tnr  f1_score
# 0   empresa_1       12      0.94  0.91  0.99      0.95
# 1   empresa_1       13      0.89  0.94  0.82      0.92
# 2   empresa_1       14      0.73  0.69  0.80      0.77
# 3   empresa_1       15      0.81  0.84  0.79      0.80
# 4   empresa_1       18      0.78  0.74  0.84      0.79
# 5   empresa_1        3      0.74  0.70  0.81      0.77
# 6   empresa_1        4      0.81  0.85  0.74      0.85
# 7   empresa_1        5      0.76  0.77  0.76      0.80
# 8   empresa_2       17      0.92  0.73  0.98      0.82
# 9   empresa_2        2      0.81  0.50  0.87      0.47
# 10  empresa_2       20      0.89  0.75  0.94      0.78
# 11  empresa_2       21      0.86  0.67  0.95      0.75
# 12  empresa_2        8      0.79  0.48  0.91      0.56
# 13  empresa_2        9      0.81  0.41  0.97      0.56
# 14  empresa_3        1      0.89  0.89  0.86      0.93
# 15  empresa_3       10      0.87  0.96  0.32      0.93
# 16  empresa_3       11      0.82  0.92  0.24      0.90
# 17  empresa_3       16      0.85  1.00  0.28      0.91
# 18  empresa_3       19      0.92  1.00  0.33      0.95
# 19  empresa_3        6      0.85  1.00  0.00      0.92
# 20  empresa_3        7      0.79  0.93  0.43      0.87
# accuracy    0.83
# tpr         0.79
# tnr         0.70
# f1_score    0.81
# dtype: float64
# accuracy    0.06
# tpr         0.18
# tnr         0.30
# f1_score    0.14
# dtype: float64

# %%
for e, data in df.groupby("empresa"):
    data = data.sort_values(by=["cliente"])
    print(data[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))
    print(f'{data[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{data[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#      empresa  cliente  accuracy   tpr   tnr  f1_score
# 5  empresa_1        3      0.74  0.70  0.81      0.77
# 6  empresa_1        4      0.81  0.85  0.74      0.85
# 7  empresa_1        5      0.76  0.77  0.76      0.80
# 0  empresa_1       12      0.94  0.91  0.99      0.95
# 1  empresa_1       13      0.89  0.94  0.82      0.92
# 2  empresa_1       14      0.73  0.69  0.80      0.77
# 3  empresa_1       15      0.81  0.84  0.79      0.80
# 4  empresa_1       18      0.78  0.74  0.84      0.79
# accuracy    0.81
# tpr         0.81
# tnr         0.82
# f1_score    0.83
# dtype: float64
# accuracy    0.07
# tpr         0.09
# tnr         0.08
# f1_score    0.07
# dtype: float64
#       empresa  cliente  accuracy   tpr   tnr  f1_score
# 9   empresa_2        2      0.81  0.50  0.87      0.47
# 12  empresa_2        8      0.79  0.48  0.91      0.56
# 13  empresa_2        9      0.81  0.41  0.97      0.56
# 8   empresa_2       17      0.92  0.73  0.98      0.82
# 10  empresa_2       20      0.89  0.75  0.94      0.78
# 11  empresa_2       21      0.86  0.67  0.95      0.75
# accuracy    0.85
# tpr         0.59
# tnr         0.94
# f1_score    0.66
# dtype: float64
# accuracy    0.05
# tpr         0.14
# tnr         0.04
# f1_score    0.15
# dtype: float64
#       empresa  cliente  accuracy   tpr   tnr  f1_score
# 14  empresa_3        1      0.89  0.89  0.86      0.93
# 19  empresa_3        6      0.85  1.00  0.00      0.92
# 20  empresa_3        7      0.79  0.93  0.43      0.87
# 15  empresa_3       10      0.87  0.96  0.32      0.93
# 16  empresa_3       11      0.82  0.92  0.24      0.90
# 17  empresa_3       16      0.85  1.00  0.28      0.91
# 18  empresa_3       19      0.92  1.00  0.33      0.95
# accuracy    0.85
# tpr         0.96
# tnr         0.35
# f1_score    0.92
# dtype: float64
# accuracy    0.04
# tpr         0.04
# tnr         0.26
# f1_score    0.03
# dtype: float64

# %% [markdown]
# ## Empresa v3 UCs

# %%
df = pd.read_csv("./results/resultados-modelos-empresa_v3.csv")

df["cliente"] = df["cliente"].apply(lambda x: int(x))
df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

df
# Out:
#       empresa  cliente   UC?     tp     tn    fp    fn  accuracy       tpr  \
# 0   empresa_1        1  True  191.0   16.0   5.0  41.0  0.818182  0.823276
# 1   empresa_1        2  True   35.0  142.0  71.0   7.0  0.694118  0.833333
# 2   empresa_1        3  True  116.0   78.0  19.0  48.0  0.743295  0.707317
# 3   empresa_1        4  True  258.0  125.0  68.0  50.0  0.764471  0.837662
# 4   empresa_1        5  True  243.0  164.0  35.0  59.0  0.812375  0.804636
# ..        ...      ...   ...    ...    ...   ...   ...       ...       ...
# 58  empresa_3       17  True   48.0  180.0  13.0  11.0  0.904762  0.813559
# 59  empresa_3       18  True  102.0  112.0   0.0  35.0  0.859438  0.744526
# 60  empresa_3       19  True  176.0   22.0  11.0  55.0  0.750000  0.761905
# 61  empresa_3       20  True   48.0  163.0  25.0  19.0  0.827451  0.716418
# 62  empresa_3       21  True   60.0  146.0  13.0  18.0  0.869198  0.769231
#
#          tnr  f1_score
# 0   0.761905  0.892523
# 1   0.666667  0.472973
# 2   0.804124  0.775920
# 3   0.647668  0.813880
# 4   0.824121  0.837931
# ..       ...       ...
# 58  0.932642  0.800000
# 59  1.000000  0.853556
# 60  0.666667  0.842105
# 61  0.867021  0.685714
# 62  0.918239  0.794702
#
# [63 rows x 11 columns]

# %%
for e, data in df.groupby(["empresa", "UC?"]):
    data = data.sort_values(by=["cliente"])
    print(data[["empresa", "cliente", "UC?", "accuracy", "tpr", "tnr", "f1_score"]].round(2))
    print(f'{data[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{data[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#       empresa  cliente    UC?  accuracy   tpr   tnr  f1_score
# 5   empresa_1        6  False      0.36  0.26  0.87      0.41
# 6   empresa_1        7  False      0.49  0.48  0.53      0.57
# 8   empresa_1        9  False      0.59  0.45  0.65      0.40
# 9   empresa_1       10  False      0.58  0.59  0.55      0.71
# 10  empresa_1       11  False      0.70  0.69  0.74      0.80
# 12  empresa_1       13  False      0.72  0.85  0.50      0.79
# 13  empresa_1       14  False      0.67  0.64  0.71      0.72
# 14  empresa_1       15  False      0.67  0.78  0.58      0.69
# 15  empresa_1       16  False      0.63  0.61  0.70      0.72
# 16  empresa_1       17  False      0.61  0.93  0.51      0.53
# 17  empresa_1       18  False      0.72  0.77  0.67      0.75
# 18  empresa_1       19  False      0.68  0.73  0.36      0.80
# 19  empresa_1       20  False      0.59  0.66  0.56      0.46
# 20  empresa_1       21  False      0.73  0.83  0.67      0.67
# accuracy    0.62
# tpr         0.66
# tnr         0.62
# f1_score    0.64
# dtype: float64
# accuracy    0.10
# tpr         0.18
# tnr         0.13
# f1_score    0.14
# dtype: float64
#       empresa  cliente   UC?  accuracy   tpr   tnr  f1_score
# 0   empresa_1        1  True      0.82  0.82  0.76      0.89
# 1   empresa_1        2  True      0.69  0.83  0.67      0.47
# 2   empresa_1        3  True      0.74  0.71  0.80      0.78
# 3   empresa_1        4  True      0.76  0.84  0.65      0.81
# 4   empresa_1        5  True      0.81  0.80  0.82      0.84
# 7   empresa_1        8  True      0.82  0.48  0.96      0.60
# 11  empresa_1       12  True      0.93  0.92  0.94      0.94
# accuracy    0.80
# tpr         0.77
# tnr         0.80
# f1_score    0.76
# dtype: float64
# accuracy    0.07
# tpr         0.14
# tnr         0.12
# f1_score    0.17
# dtype: float64
#       empresa  cliente    UC?  accuracy   tpr   tnr  f1_score
# 21  empresa_2        1  False      0.77  0.77  0.81      0.86
# 22  empresa_2        2  False      0.28  0.98  0.14      0.31
# 23  empresa_2        3  False      0.62  0.86  0.23      0.74
# 24  empresa_2        4  False      0.69  0.94  0.30      0.79
# 25  empresa_2        5  False      0.57  0.92  0.04      0.72
# 28  empresa_2        8  False      0.29  1.00  0.02      0.44
# 29  empresa_2        9  False      0.32  0.96  0.06      0.46
# 32  empresa_2       12  False      0.86  0.94  0.70      0.89
# 35  empresa_2       15  False      0.63  0.96  0.35      0.70
# 37  empresa_2       17  False      0.31  0.97  0.10      0.39
# 38  empresa_2       18  False      0.63  0.92  0.29      0.73
# 39  empresa_2       19  False      0.83  0.89  0.42      0.90
# 40  empresa_2       20  False      0.36  0.91  0.17      0.43
# 41  empresa_2       21  False      0.38  0.95  0.11      0.50
# accuracy    0.54
# tpr         0.93
# tnr         0.27
# f1_score    0.63
# dtype: float64
# accuracy    0.21
# tpr         0.06
# tnr         0.24
# f1_score    0.20
# dtype: float64
#       empresa  cliente   UC?  accuracy   tpr   tnr  f1_score
# 26  empresa_2        6  True      0.86  1.00  0.10      0.92
# 27  empresa_2        7  True      0.81  0.96  0.43      0.88
# 30  empresa_2       10  True      0.85  0.93  0.39      0.92
# 31  empresa_2       11  True      0.82  0.88  0.47      0.89
# 33  empresa_2       13  True      0.88  0.97  0.73      0.91
# 34  empresa_2       14  True      0.78  0.87  0.61      0.84
# 36  empresa_2       16  True      0.86  0.96  0.46      0.92
# accuracy    0.84
# tpr         0.94
# tnr         0.46
# f1_score    0.90
# dtype: float64
# accuracy    0.03
# tpr         0.05
# tnr         0.20
# f1_score    0.03
# dtype: float64
#       empresa  cliente    UC?  accuracy   tpr   tnr  f1_score
# 42  empresa_3        1  False      0.53  0.49  0.95      0.65
# 43  empresa_3        2  False      0.67  0.67  0.67      0.40
# 44  empresa_3        3  False      0.55  0.43  0.75      0.55
# 45  empresa_3        4  False      0.75  0.71  0.80      0.78
# 46  empresa_3        5  False      0.61  0.47  0.83      0.59
# 47  empresa_3        6  False      0.34  0.22  1.00      0.37
# 48  empresa_3        7  False      0.49  0.36  0.84      0.50
# 49  empresa_3        8  False      0.67  0.16  0.87      0.22
# 51  empresa_3       10  False      0.52  0.46  0.82      0.62
# 52  empresa_3       11  False      0.53  0.51  0.66      0.65
# 53  empresa_3       12  False      0.64  0.62  0.69      0.69
# 54  empresa_3       13  False      0.73  0.79  0.63      0.79
# 55  empresa_3       14  False      0.68  0.56  0.91      0.70
# 57  empresa_3       16  False      0.55  0.48  0.85      0.63
# accuracy    0.59
# tpr         0.50
# tnr         0.81
# f1_score    0.58
# dtype: float64
# accuracy    0.11
# tpr         0.17
# tnr         0.11
# f1_score    0.16
# dtype: float64
#       empresa  cliente   UC?  accuracy   tpr   tnr  f1_score
# 50  empresa_3        9  True      0.76  0.48  0.88      0.54
# 56  empresa_3       15  True      0.84  0.78  0.89      0.82
# 58  empresa_3       17  True      0.90  0.81  0.93      0.80
# 59  empresa_3       18  True      0.86  0.74  1.00      0.85
# 60  empresa_3       19  True      0.75  0.76  0.67      0.84
# 61  empresa_3       20  True      0.83  0.72  0.87      0.69
# 62  empresa_3       21  True      0.87  0.77  0.92      0.79
# accuracy    0.83
# tpr         0.72
# tnr         0.88
# f1_score    0.76
# dtype: float64
# accuracy    0.06
# tpr         0.11
# tnr         0.10
# f1_score    0.11
# dtype: float64

# %% [markdown]
# ## Centralizado

# %%
df = pd.read_csv("./results/resultados-modelo-centralizado.csv")

df["cliente"] = df["cliente"].apply(lambda x: int(x))
df["empresa"] = df["empresa"].apply(lambda x: int(x))
df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

df = df.sort_values(by=["cliente"])

df["empresa_v2"] = [3, 2, 1, 1, 1, 3, 3, 2, 2, 3, 3, 1, 1, 1, 1, 3, 2, 1, 3, 2, 2]

print(df[["empresa", "empresa_v2", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))

print(f'{df[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{df[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#     empresa  empresa_v2  cliente  accuracy   tpr   tnr  f1_score
# 0         2           3        1      0.77  0.76  0.95      0.86
# 1         1           2        2      0.57  0.88  0.51      0.40
# 2         2           1        3      0.72  0.72  0.72      0.76
# 3         1           1        4      0.77  0.84  0.66      0.82
# 4         2           1        5      0.74  0.78  0.68      0.79
# 5         1           3        6      0.79  0.88  0.31      0.88
# 6         2           3        7      0.63  0.62  0.66      0.71
# 7         1           2        8      0.75  0.58  0.82      0.56
# 8         2           2        9      0.68  0.71  0.66      0.57
# 9         1           3       10      0.72  0.78  0.34      0.83
# 10        2           3       11      0.73  0.74  0.68      0.82
# 11        1           1       12      0.93  0.91  0.95      0.94
# 12        2           1       13      0.85  0.96  0.66      0.89
# 13        1           1       14      0.75  0.69  0.85      0.78
# 14        2           1       15      0.78  0.82  0.74      0.77
# 15        1           3       16      0.81  0.86  0.63      0.88
# 16        2           2       17      0.73  0.88  0.68      0.60
# 17        1           1       18      0.84  0.79  0.91      0.85
# 18        2           3       19      0.77  0.80  0.58      0.86
# 19        1           2       20      0.69  0.78  0.66      0.57
# 20        2           2       21      0.81  0.85  0.80      0.75
# accuracy    0.75
# tpr         0.79
# tnr         0.69
# f1_score    0.76
# dtype: float64
# accuracy    0.08
# tpr         0.09
# tnr         0.17
# f1_score    0.14
# dtype: float64

# %%
for e, data in df.groupby("empresa"):
    data = data.sort_values(by=["cliente"])
    print(data[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))
    print(f'{data[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{data[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 1       1.0        2      0.57  0.88  0.51      0.40
# 3       1.0        4      0.77  0.84  0.66      0.82
# 5       1.0        6      0.79  0.88  0.31      0.88
# 7       1.0        8      0.75  0.58  0.82      0.56
# 9       1.0       10      0.72  0.78  0.34      0.83
# 11      1.0       12      0.93  0.91  0.95      0.94
# 13      1.0       14      0.75  0.69  0.85      0.78
# 15      1.0       16      0.81  0.86  0.63      0.88
# 17      1.0       18      0.84  0.79  0.91      0.85
# 19      1.0       20      0.69  0.78  0.66      0.57
# accuracy    0.76
# tpr         0.80
# tnr         0.66
# f1_score    0.75
# dtype: float64
# accuracy    0.10
# tpr         0.10
# tnr         0.23
# f1_score    0.18
# dtype: float64
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 0       2.0        1      0.77  0.76  0.95      0.86
# 2       2.0        3      0.72  0.72  0.72      0.76
# 4       2.0        5      0.74  0.78  0.68      0.79
# 6       2.0        7      0.63  0.62  0.66      0.71
# 8       2.0        9      0.68  0.71  0.66      0.57
# 10      2.0       11      0.73  0.74  0.68      0.82
# 12      2.0       13      0.85  0.96  0.66      0.89
# 14      2.0       15      0.78  0.82  0.74      0.77
# 16      2.0       17      0.73  0.88  0.68      0.60
# 18      2.0       19      0.77  0.80  0.58      0.86
# 20      2.0       21      0.81  0.85  0.80      0.75
# accuracy    0.75
# tpr         0.79
# tnr         0.71
# f1_score    0.76
# dtype: float64
# accuracy    0.06
# tpr         0.09
# tnr         0.10
# f1_score    0.10
# dtype: float64

# %%
for e, data in df.groupby("empresa_v2"):
    data = data.sort_values(by=["cliente"])
    print(data[["empresa_v2", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))
    print(f'{data[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{data[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#     empresa_v2  cliente  accuracy   tpr   tnr  f1_score
# 2            1        3      0.72  0.72  0.72      0.76
# 3            1        4      0.77  0.84  0.66      0.82
# 4            1        5      0.74  0.78  0.68      0.79
# 11           1       12      0.93  0.91  0.95      0.94
# 12           1       13      0.85  0.96  0.66      0.89
# 13           1       14      0.75  0.69  0.85      0.78
# 14           1       15      0.78  0.82  0.74      0.77
# 17           1       18      0.84  0.79  0.91      0.85
# accuracy    0.80
# tpr         0.81
# tnr         0.77
# f1_score    0.82
# dtype: float64
# accuracy    0.07
# tpr         0.09
# tnr         0.12
# f1_score    0.06
# dtype: float64
#     empresa_v2  cliente  accuracy   tpr   tnr  f1_score
# 1            2        2      0.57  0.88  0.51      0.40
# 7            2        8      0.75  0.58  0.82      0.56
# 8            2        9      0.68  0.71  0.66      0.57
# 16           2       17      0.73  0.88  0.68      0.60
# 19           2       20      0.69  0.78  0.66      0.57
# 20           2       21      0.81  0.85  0.80      0.75
# accuracy    0.70
# tpr         0.78
# tnr         0.69
# f1_score    0.58
# dtype: float64
# accuracy    0.08
# tpr         0.12
# tnr         0.11
# f1_score    0.11
# dtype: float64
#     empresa_v2  cliente  accuracy   tpr   tnr  f1_score
# 0            3        1      0.77  0.76  0.95      0.86
# 5            3        6      0.79  0.88  0.31      0.88
# 6            3        7      0.63  0.62  0.66      0.71
# 9            3       10      0.72  0.78  0.34      0.83
# 10           3       11      0.73  0.74  0.68      0.82
# 15           3       16      0.81  0.86  0.63      0.88
# 18           3       19      0.77  0.80  0.58      0.86
# accuracy    0.75
# tpr         0.77
# tnr         0.59
# f1_score    0.83
# dtype: float64
# accuracy    0.06
# tpr         0.09
# tnr         0.22
# f1_score    0.06
# dtype: float64

# %% [markdown]
# ## Centralizado UCs

# %%
df = pd.read_csv("./results/resultados-modelo-centralizado-new-client.csv")
columns=['cliente', 'tp', 'tn', 'fp', 'fn', 'tp_c', 'tn_c', 'fp_c', 'fn_c']


df["cliente"] = df["cliente"].apply(lambda x: int(x))

df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

df["accuracy_c"] = (df["tp_c"]+df["tn_c"])/(df["tp_c"]+df["tn_c"]+df["fp_c"]+df["fn_c"])
df["tpr_c"] = (df["tp_c"])/(df["tp_c"]+df["fn_c"])
df["tnr_c"] = (df["tn_c"])/(df["tn_c"]+df["fp_c"])
df["f1_score_c"] = (df["tp_c"])/( df["tp_c"] + (df["fp_c"]+df["fn_c"])/2 )

df = df.sort_values(by=["cliente"])

# df["empresa"] = [3, 2, 1, 1, 1, 3, 3, 2, 2, 3, 3, 1, 1, 1, 1, 3, 2, 1, 3, 2, 2]

print(df[["cliente", "accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].round(2))

print(f'{df[["accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].mean().round(2)}\n{df[["accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].std().round(2)}')
# Out:
#     cliente  accuracy   tpr   tnr  f1_score  accuracy_c  tpr_c  tnr_c  \
# 0         1      0.77  0.76  0.78      0.79        0.62   0.59   0.90
# 1         2      0.77  0.82  0.70      0.81        0.55   0.88   0.48
# 2         3      0.76  0.78  0.73      0.79        0.60   0.62   0.58
# 3         4      0.76  0.77  0.76      0.79        0.69   0.80   0.52
# 4         5      0.76  0.77  0.76      0.79        0.60   0.61   0.59
# 5         6      0.76  0.76  0.75      0.78        0.34   0.24   0.92
# 6         7      0.77  0.77  0.76      0.79        0.56   0.50   0.71
# 7         8      0.76  0.78  0.73      0.80        0.40   0.25   0.46
# 8         9      0.77  0.79  0.73      0.80        0.56   0.74   0.48
# 9        10      0.76  0.77  0.75      0.79        0.62   0.62   0.63
# 10       11      0.76  0.78  0.74      0.79        0.66   0.66   0.66
# 11       12      0.75  0.77  0.72      0.78        0.86   0.87   0.86
# 12       13      0.76  0.80  0.71      0.79        0.71   0.88   0.42
# 13       14      0.76  0.75  0.76      0.78        0.71   0.64   0.86
# 14       15      0.75  0.80  0.69      0.79        0.74   0.87   0.62
# 15       16      0.76  0.74  0.77      0.78        0.70   0.72   0.63
# 16       17      0.76  0.80  0.71      0.80        0.48   0.92   0.35
# 17       18      0.77  0.79  0.74      0.80        0.71   0.74   0.69
# 18       19      0.76  0.76  0.76      0.79        0.59   0.58   0.67
# 19       20      0.76  0.79  0.71      0.80        0.51   0.64   0.46
# 20       21      0.76  0.77  0.73      0.79        0.79   0.83   0.77
#
#     f1_score_c
# 0         0.74
# 1         0.39
# 2         0.66
# 3         0.76
# 4         0.65
# 5         0.39
# 6         0.62
# 7         0.19
# 8         0.50
# 9         0.73
# 10        0.77
# 11        0.89
# 12        0.79
# 13        0.75
# 14        0.75
# 15        0.79
# 16        0.45
# 17        0.74
# 18        0.72
# 19        0.41
# 20        0.73
# accuracy      0.76
# tpr           0.78
# tnr           0.74
# f1_score      0.79
# accuracy_c    0.62
# tpr_c         0.68
# tnr_c         0.63
# f1_score_c    0.64
# dtype: float64
# accuracy      0.01
# tpr           0.02
# tnr           0.03
# f1_score      0.01
# accuracy_c    0.12
# tpr_c         0.19
# tnr_c         0.16
# f1_score_c    0.18
# dtype: float64

# %% [markdown]
# # Eval FL model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
def prepare_model_data(client_file):
    df = pd.read_csv(client_file)
    
    train, test = train_test_split(df, test_size=0.30, random_state=42)
    
    X_train = train[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]
    X_test = test[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]
    y_train = train['y_class']
    y_test = test['y_class']
    
    scaler = StandardScaler()

    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test

# %%
from keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras.metrics import Precision, Recall, TrueNegatives, TruePositives, FalsePositives, FalseNegatives

# %%
def setup_model(weights_path):
    neurons = 36
    activation = "relu"
    learning_rate = 0.180165
    optimizer = Adadelta(learning_rate=learning_rate)

    input_shape = (7,)

    # Create model
    model = Sequential()

    model.add(Dense(neurons, input_shape=input_shape, activation=activation))

    model.add(BatchNormalization())

    model.add(Dense(neurons, activation=activation))
    model.add(Dense(neurons, activation=activation))
    model.add(Dense(neurons, activation=activation))

    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', TruePositives(), TrueNegatives(), FalsePositives(), FalseNegatives()])
    
    a = np.load(weights_path, allow_pickle=True)

    n_elems = [252, 36,
               36, 36, 36, 36,
               1296, 36,
               1296, 36,
               1296, 36,
               36, 1]

    weights = []

    # https://numpy.org/devdocs/reference/generated/numpy.lib.format.html#version-numbering
    # En base a la doc sabemos que los datos de interes estan al final, y como deben ser float32 => 4 bytes
    # por lo que se toman los n_elementos*4bytes del final

    for i, t in enumerate(a["arr_0"][0].tensors):
        act = np.frombuffer(t[-n_elems[i]*4:], dtype=np.float32)
        weights.append(act)

    # Se cambia la forma para que se adapte a la del modelo
    weights[0] = weights[0].reshape(7,36)
    weights[6] = weights[6].reshape(36,36)
    weights[8] = weights[8].reshape(36,36)
    weights[10] = weights[10].reshape(36,36)
    weights[12] = weights[12].reshape(36,1)

    model.set_weights(weights)
    
    return model

# %% [markdown]
# ## Hito 1

# %%
IDS_EMPRESA = {
    1: [3,4,5,12,  2,8,  1],
    2: [13,14,    6,7,10,11,16],
    3: [15,18,  9,17,20,21,  19]
}

results = pd.DataFrame(columns=['empresa', 'cliente', 'tp', 'tn', 'fp', 'fn'])

for empresa in IDS_EMPRESA:
    CLIENTS_IDS = sorted(IDS_EMPRESA[empresa])
    df_h1 = pd.read_csv(f'./results/hito1_v3-empresa_{empresa}.csv')
    
    best_rnd = df_h1.mean(numeric_only=True, axis=1).idxmax()+1
    
    path = f'./rounds/hito1_v3-empresa_{empresa}-round-{best_rnd}-weights.npz'
    
    model = setup_model(path)
    
    for cid in CLIENTS_IDS:
        path = f'./data/centralizado/cliente_{cid}.csv'
        
        X_train, X_val, y_train, y_val = prepare_model_data(path)
    
        # Evaluar para los clientes conocidos
        res = model.evaluate(X_val, y_val, verbose=0)

        tp = res[2]
        tn = res[3]
        fp = res[4]
        fn = res[5]

        fed_res = {
            "empresa": empresa,
            "cliente": cid,
            "tp": tp,
            "tn": tn,
            "fp": fp,
            "fn": fn
        }

        print(fed_res)
        results = results.append(fed_res, ignore_index=True)
    
results.to_csv("./results/hito1_v3-modelo-federado-por-empresa.csv", index=False, header=True)
# Out:
# {'empresa': 1, 'cliente': 1, 'tp': 139.0, 'tn': 20.0, 'fp': 1.0, 'fn': 93.0}
# {'empresa': 1, 'cliente': 2, 'tp': 36.0, 'tn': 124.0, 'fp': 89.0, 'fn': 6.0}
# {'empresa': 1, 'cliente': 3, 'tp': 104.0, 'tn': 73.0, 'fp': 24.0, 'fn': 60.0}
# {'empresa': 1, 'cliente': 4, 'tp': 252.0, 'tn': 136.0, 'fp': 57.0, 'fn': 56.0}
# {'empresa': 1, 'cliente': 5, 'tp': 218.0, 'tn': 170.0, 'fp': 29.0, 'fn': 84.0}
# {'empresa': 1, 'cliente': 8, 'tp': 47.0, 'tn': 163.0, 'fp': 25.0, 'fn': 26.0}
# {'empresa': 1, 'cliente': 12, 'tp': 144.0, 'tn': 63.0, 'fp': 25.0, 'fn': 12.0}
# {'empresa': 2, 'cliente': 6, 'tp': 219.0, 'tn': 1.0, 'fp': 38.0, 'fn': 0.0}
# {'empresa': 2, 'cliente': 7, 'tp': 169.0, 'tn': 24.0, 'fp': 46.0, 'fn': 14.0}
# {'empresa': 2, 'cliente': 10, 'tp': 195.0, 'tn': 25.0, 'fp': 13.0, 'fn': 29.0}
# {'empresa': 2, 'cliente': 11, 'tp': 173.0, 'tn': 23.0, 'fp': 15.0, 'fn': 43.0}
# {'empresa': 2, 'cliente': 13, 'tp': 148.0, 'tn': 45.0, 'fp': 47.0, 'fn': 2.0}
# {'empresa': 2, 'cliente': 14, 'tp': 156.0, 'tn': 18.0, 'fp': 62.0, 'fn': 4.0}
# {'empresa': 2, 'cliente': 16, 'tp': 204.0, 'tn': 24.0, 'fp': 30.0, 'fn': 6.0}
# {'empresa': 3, 'cliente': 9, 'tp': 34.0, 'tn': 153.0, 'fp': 21.0, 'fn': 39.0}
# {'empresa': 3, 'cliente': 15, 'tp': 84.0, 'tn': 127.0, 'fp': 13.0, 'fn': 35.0}
# {'empresa': 3, 'cliente': 17, 'tp': 47.0, 'tn': 186.0, 'fp': 7.0, 'fn': 12.0}
# {'empresa': 3, 'cliente': 18, 'tp': 87.0, 'tn': 112.0, 'fp': 0.0, 'fn': 50.0}
# {'empresa': 3, 'cliente': 19, 'tp': 107.0, 'tn': 33.0, 'fp': 0.0, 'fn': 124.0}
# {'empresa': 3, 'cliente': 20, 'tp': 38.0, 'tn': 158.0, 'fp': 30.0, 'fn': 29.0}
# {'empresa': 3, 'cliente': 21, 'tp': 56.0, 'tn': 151.0, 'fp': 8.0, 'fn': 22.0}

# %%
df = pd.read_csv("./results/hito1_v3-modelo-federado-por-empresa.csv")

df["cliente"] = df["cliente"].apply(lambda x: int(x))
df["empresa"] = df["empresa"].apply(lambda x: int(x))
df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

df = df.sort_values(by=["empresa", "cliente"])

for e, data in df.groupby("empresa"):
    data = data.sort_values(by=["cliente"])
    print(data[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))
    print(f'{data[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{data[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#    empresa  cliente  accuracy   tpr   tnr  f1_score
# 0        1        1      0.63  0.60  0.95      0.75
# 1        1        2      0.63  0.86  0.58      0.43
# 2        1        3      0.68  0.63  0.75      0.71
# 3        1        4      0.77  0.82  0.70      0.82
# 4        1        5      0.77  0.72  0.85      0.79
# 5        1        8      0.80  0.64  0.87      0.65
# 6        1       12      0.85  0.92  0.72      0.89
# accuracy    0.73
# tpr         0.74
# tnr         0.78
# f1_score    0.72
# dtype: float64
# accuracy    0.09
# tpr         0.13
# tnr         0.12
# f1_score    0.15
# dtype: float64
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 7         2        6      0.85  1.00  0.03      0.92
# 8         2        7      0.76  0.92  0.34      0.85
# 9         2       10      0.84  0.87  0.66      0.90
# 10        2       11      0.77  0.80  0.61      0.86
# 11        2       13      0.80  0.99  0.49      0.86
# 12        2       14      0.72  0.98  0.22      0.83
# 13        2       16      0.86  0.97  0.44      0.92
# accuracy    0.80
# tpr         0.93
# tnr         0.40
# f1_score    0.88
# dtype: float64
# accuracy    0.05
# tpr         0.07
# tnr         0.22
# f1_score    0.04
# dtype: float64
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 14        3        9      0.76  0.47  0.88      0.53
# 15        3       15      0.81  0.71  0.91      0.78
# 16        3       17      0.92  0.80  0.96      0.83
# 17        3       18      0.80  0.64  1.00      0.78
# 18        3       19      0.53  0.46  1.00      0.63
# 19        3       20      0.77  0.57  0.84      0.56
# 20        3       21      0.87  0.72  0.95      0.79
# accuracy    0.78
# tpr         0.62
# tnr         0.93
# f1_score    0.70
# dtype: float64
# accuracy    0.13
# tpr         0.13
# tnr         0.06
# f1_score    0.12
# dtype: float64

# %% [markdown]
# ## Hito 2

# %%
model = setup_model('./round-15-weights.npz')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 36)                288
#
#  batch_normalization_1 (Batc  (None, 36)               144
#  hNormalization)
#
#  dense_6 (Dense)             (None, 36)                1332
#
#  dense_7 (Dense)             (None, 36)                1332
#
#  dense_8 (Dense)             (None, 36)                1332
#
#  dense_9 (Dense)             (None, 1)                 37
#
# =================================================================
# Total params: 4,465
# Trainable params: 4,393
# Non-trainable params: 72
# _________________________________________________________________

# %%
results = pd.DataFrame(columns=['empresa', 'cliente', 'tp', 'tn', 'fp', 'fn'])

for e in empresa:
    for cid in empresa[e]:
        base_path = "./data/horizontal_v2/"
        path = f"{base_path}empresa_{e}/cliente_{cid}.csv"
        
        X_train_act, X_val_act, y_train_act, y_val_act = prepare_model_data(path)
        
        res = model.evaluate(X_val_act, y_val_act, verbose=0)
        
        tp = res[2]
        tn = res[3]
        fp = res[4]
        fn = res[5]
        
        federado_res = {
            "empresa": e,
            "cliente": cid,
            "tp": tp,
            "tn": tn,
            "fp": fp,
            "fn": fn
        }

#         print(federado_res)
        results = results.append(federado_res, ignore_index=True)
    
results.to_csv("./results/hito2-por-cliente.csv", index=False, header=True)

# %% [markdown]
# ## restults

# %%
df = pd.read_csv("./results/hito2-por-cliente.csv")

df["cliente"] = df["cliente"].apply(lambda x: int(x))
df["empresa"] = df["empresa"].apply(lambda x: int(x))
df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

df = df.sort_values(by=["empresa", "cliente"])

print(df[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))

print(f'{df[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{df[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 0         1        3      0.67  0.64  0.71      0.71
# 1         1        4      0.80  0.84  0.74      0.84
# 2         1        5      0.68  0.68  0.68      0.72
# 3         1       12      0.94  0.90  1.00      0.95
# 4         1       13      0.88  0.93  0.78      0.90
# 5         1       14      0.73  0.69  0.82      0.77
# 6         1       15      0.80  0.83  0.78      0.80
# 7         1       18      0.86  0.77  0.96      0.86
# 8         2        2      0.55  0.90  0.48      0.40
# 9         2        8      0.54  0.84  0.43      0.50
# 10        2        9      0.62  0.77  0.55      0.54
# 11        2       17      0.64  0.93  0.55      0.55
# 12        2       20      0.58  0.78  0.52      0.50
# 13        2       21      0.73  0.88  0.65      0.68
# 14        3        1      0.60  0.57  0.95      0.72
# 15        3        6      0.65  0.64  0.67      0.76
# 16        3        7      0.57  0.51  0.70      0.63
# 17        3       10      0.72  0.71  0.79      0.81
# 18        3       11      0.68  0.65  0.84      0.77
# 19        3       16      0.83  0.82  0.89      0.89
# 20        3       19      0.73  0.69  0.97      0.82
# accuracy    0.70
# tpr         0.76
# tnr         0.74
# f1_score    0.72
# dtype: float64
# accuracy    0.11
# tpr         0.12
# tnr         0.17
# f1_score    0.15
# dtype: float64

# %%
for e, data in df.groupby("empresa"):
    data = data.sort_values(by=["cliente"])
    print(data[["empresa", "cliente", "accuracy", "tpr", "tnr", "f1_score"]].round(2))
    print(f'{data[["accuracy", "tpr", "tnr", "f1_score"]].mean().round(2)}\n{data[["accuracy", "tpr", "tnr", "f1_score"]].std().round(2)}')
# Out:
#    empresa  cliente  accuracy   tpr   tnr  f1_score
# 0        1        3      0.67  0.64  0.71      0.71
# 1        1        4      0.80  0.84  0.74      0.84
# 2        1        5      0.68  0.68  0.68      0.72
# 3        1       12      0.94  0.90  1.00      0.95
# 4        1       13      0.88  0.93  0.78      0.90
# 5        1       14      0.73  0.69  0.82      0.77
# 6        1       15      0.80  0.83  0.78      0.80
# 7        1       18      0.86  0.77  0.96      0.86
# accuracy    0.79
# tpr         0.79
# tnr         0.81
# f1_score    0.82
# dtype: float64
# accuracy    0.10
# tpr         0.11
# tnr         0.11
# f1_score    0.09
# dtype: float64
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 8         2        2      0.55  0.90  0.48      0.40
# 9         2        8      0.54  0.84  0.43      0.50
# 10        2        9      0.62  0.77  0.55      0.54
# 11        2       17      0.64  0.93  0.55      0.55
# 12        2       20      0.58  0.78  0.52      0.50
# 13        2       21      0.73  0.88  0.65      0.68
# accuracy    0.61
# tpr         0.85
# tnr         0.53
# f1_score    0.53
# dtype: float64
# accuracy    0.07
# tpr         0.07
# tnr         0.08
# f1_score    0.09
# dtype: float64
#     empresa  cliente  accuracy   tpr   tnr  f1_score
# 14        3        1      0.60  0.57  0.95      0.72
# 15        3        6      0.65  0.64  0.67      0.76
# 16        3        7      0.57  0.51  0.70      0.63
# 17        3       10      0.72  0.71  0.79      0.81
# 18        3       11      0.68  0.65  0.84      0.77
# 19        3       16      0.83  0.82  0.89      0.89
# 20        3       19      0.73  0.69  0.97      0.82
# accuracy    0.68
# tpr         0.66
# tnr         0.83
# f1_score    0.77
# dtype: float64
# accuracy    0.09
# tpr         0.10
# tnr         0.12
# f1_score    0.08
# dtype: float64

# %% [markdown]
# ## results 3 empresas UCs

# %%
df = pd.read_csv("./results/hito2_UCs.csv")

results = pd.DataFrame(columns=['cliente', 'tp', 'tn', 'fp', 'fn', 'tp_c', 'tn_c', 'fp_c', 'fn_c'])

for cid in range(1,22):
    best_rnd = df[df["UC"] == f"cliente_{cid}.csv"]["best_rnd"].values[0]
    
    path = f'./rounds/hito2_v3-UC_cliente_{cid}.csv-round-{best_rnd}-weights.npz'
    
    model = setup_model(path)
    
    actual_clients = list(range(1,22))
    actual_clients.remove(cid)
    X_train, X_val, y_train, y_val = cargar_dataset_varios_clientes(actual_clients)
    
    # Evaluar para los clientes conocidos
    res = model.evaluate(X_val, y_val, verbose=0)
    
    tp = res[2]
    tn = res[3]
    fp = res[4]
    fn = res[5]
    
    # Evaluar para el cliente nuevo
    X_train_c, X_val_c, y_train_c, y_val_c = prepare_model_data(f'./data/centralizado/cliente_{cid}.csv')
    res_c = model.evaluate(X_val_c, y_val_c, verbose=0)
    
    tp_c = res_c[2]
    tn_c = res_c[3]
    fp_c = res_c[4]
    fn_c = res_c[5]
    
    fed_res = {
        "cliente": cid,
        "tp": tp,
        "tn": tn,
        "fp": fp,
        "fn": fn,
        "tp_c": tp_c,
        "tn_c": tn_c,
        "fp_c": fp_c,
        "fn_c": fn_c
    }

    print(f'cid: {cid} - {fed_res}')
    results = results.append(fed_res, ignore_index=True)
    
results.to_csv("./results/resultados-modelo-federado-new-client.csv", index=False, header=True)
# Out:
# cid: 1 - {'cliente': 1, 'tp': 2326.0, 'tn': 1683.0, 'fp': 705.0, 'fn': 845.0, 'tp_c': 140.0, 'tn_c': 18.0, 'fp_c': 3.0, 'fn_c': 92.0}
# cid: 2 - {'cliente': 2, 'tp': 2557.0, 'tn': 1495.0, 'fp': 701.0, 'fn': 804.0, 'tp_c': 38.0, 'tn_c': 102.0, 'fp_c': 111.0, 'fn_c': 4.0}
# cid: 3 - {'cliente': 3, 'tp': 2313.0, 'tn': 1692.0, 'fp': 620.0, 'fn': 926.0, 'tp_c': 95.0, 'tn_c': 56.0, 'fp_c': 41.0, 'fn_c': 69.0}
# cid: 4 - {'cliente': 4, 'tp': 2186.0, 'tn': 1597.0, 'fp': 619.0, 'fn': 909.0, 'tp_c': 250.0, 'tn_c': 128.0, 'fp_c': 65.0, 'fn_c': 58.0}
# cid: 5 - {'cliente': 5, 'tp': 2228.0, 'tn': 1584.0, 'fp': 626.0, 'fn': 873.0, 'tp_c': 161.0, 'tn_c': 137.0, 'fp_c': 62.0, 'fn_c': 141.0}
# cid: 6 - {'cliente': 6, 'tp': 2334.0, 'tn': 1723.0, 'fp': 647.0, 'fn': 850.0, 'tp_c': 62.0, 'tn_c': 34.0, 'fp_c': 5.0, 'fn_c': 157.0}
# cid: 7 - {'cliente': 7, 'tp': 2314.0, 'tn': 1704.0, 'fp': 635.0, 'fn': 906.0, 'tp_c': 78.0, 'tn_c': 47.0, 'fp_c': 23.0, 'fn_c': 105.0}
# cid: 8 - {'cliente': 8, 'tp': 2514.0, 'tn': 1506.0, 'fp': 715.0, 'fn': 816.0, 'tp_c': 59.0, 'tn_c': 59.0, 'fp_c': 129.0, 'fn_c': 14.0}
# cid: 9 - {'cliente': 9, 'tp': 2388.0, 'tn': 1616.0, 'fp': 619.0, 'fn': 942.0, 'tp_c': 47.0, 'tn_c': 117.0, 'fp_c': 57.0, 'fn_c': 26.0}
# cid: 10 - {'cliente': 10, 'tp': 2266.0, 'tn': 1734.0, 'fp': 637.0, 'fn': 913.0, 'tp_c': 146.0, 'tn_c': 29.0, 'fp_c': 9.0, 'fn_c': 78.0}
# cid: 11 - {'cliente': 11, 'tp': 2189.0, 'tn': 1781.0, 'fp': 590.0, 'fn': 998.0, 'tp_c': 136.0, 'tn_c': 26.0, 'fp_c': 12.0, 'fn_c': 80.0}
# cid: 12 - {'cliente': 12, 'tp': 2403.0, 'tn': 1555.0, 'fp': 766.0, 'fn': 844.0, 'tp_c': 139.0, 'tn_c': 78.0, 'fp_c': 10.0, 'fn_c': 17.0}
# cid: 13 - {'cliente': 13, 'tp': 2316.0, 'tn': 1685.0, 'fp': 632.0, 'fn': 937.0, 'tp_c': 137.0, 'tn_c': 51.0, 'fp_c': 41.0, 'fn_c': 13.0}
# cid: 14 - {'cliente': 14, 'tp': 2337.0, 'tn': 1693.0, 'fp': 636.0, 'fn': 906.0, 'tp_c': 110.0, 'tn_c': 68.0, 'fp_c': 12.0, 'fn_c': 50.0}
# cid: 15 - {'cliente': 15, 'tp': 2408.0, 'tn': 1590.0, 'fp': 679.0, 'fn': 876.0, 'tp_c': 96.0, 'tn_c': 94.0, 'fp_c': 46.0, 'fn_c': 23.0}
# cid: 16 - {'cliente': 16, 'tp': 2250.0, 'tn': 1721.0, 'fp': 634.0, 'fn': 943.0, 'tp_c': 152.0, 'tn_c': 45.0, 'fp_c': 9.0, 'fn_c': 58.0}
# cid: 17 - {'cliente': 17, 'tp': 2520.0, 'tn': 1511.0, 'fp': 705.0, 'fn': 824.0, 'tp_c': 53.0, 'tn_c': 101.0, 'fp_c': 92.0, 'fn_c': 6.0}
# cid: 18 - {'cliente': 18, 'tp': 2379.0, 'tn': 1605.0, 'fp': 692.0, 'fn': 887.0, 'tp_c': 99.0, 'tn_c': 104.0, 'fp_c': 8.0, 'fn_c': 38.0}
# cid: 19 - {'cliente': 19, 'tp': 2218.0, 'tn': 1790.0, 'fp': 586.0, 'fn': 954.0, 'tp_c': 144.0, 'tn_c': 33.0, 'fp_c': 0.0, 'fn_c': 87.0}
# cid: 20 - {'cliente': 20, 'tp': 2456.0, 'tn': 1580.0, 'fp': 641.0, 'fn': 880.0, 'tp_c': 45.0, 'tn_c': 101.0, 'fp_c': 87.0, 'fn_c': 22.0}
# cid: 21 - {'cliente': 21, 'tp': 2513.0, 'tn': 1512.0, 'fp': 738.0, 'fn': 812.0, 'tp_c': 72.0, 'tn_c': 111.0, 'fp_c': 48.0, 'fn_c': 6.0}

# %%
df = pd.read_csv("./results/resultados-modelo-federado-new-client.csv")
columns=['cliente', 'tp', 'tn', 'fp', 'fn', 'tp_c', 'tn_c', 'fp_c', 'fn_c']


df["cliente"] = df["cliente"].apply(lambda x: int(x))

df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

df["accuracy_c"] = (df["tp_c"]+df["tn_c"])/(df["tp_c"]+df["tn_c"]+df["fp_c"]+df["fn_c"])
df["tpr_c"] = (df["tp_c"])/(df["tp_c"]+df["fn_c"])
df["tnr_c"] = (df["tn_c"])/(df["tn_c"]+df["fp_c"])
df["f1_score_c"] = (df["tp_c"])/( df["tp_c"] + (df["fp_c"]+df["fn_c"])/2 )

df = df.sort_values(by=["cliente"])

# df["empresa"] = [3, 2, 1, 1, 1, 3, 3, 2, 2, 3, 3, 1, 1, 1, 1, 3, 2, 1, 3, 2, 2]

print(df[["cliente", "accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].round(2))

print(f'{df[["accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].mean().round(2)}\n{df[["accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].std().round(2)}')
# Out:
#     cliente  accuracy   tpr   tnr  f1_score  accuracy_c  tpr_c  tnr_c  \
# 0         1      0.72  0.73  0.70      0.75        0.62   0.60   0.86
# 1         2      0.73  0.76  0.68      0.77        0.55   0.90   0.48
# 2         3      0.72  0.71  0.73      0.75        0.58   0.58   0.58
# 3         4      0.71  0.71  0.72      0.74        0.75   0.81   0.66
# 4         5      0.72  0.72  0.72      0.75        0.59   0.53   0.69
# 5         6      0.73  0.73  0.73      0.76        0.37   0.28   0.87
# 6         7      0.72  0.72  0.73      0.75        0.49   0.43   0.67
# 7         8      0.72  0.75  0.68      0.77        0.45   0.81   0.31
# 8         9      0.72  0.72  0.72      0.75        0.66   0.64   0.67
# 9        10      0.72  0.71  0.73      0.75        0.67   0.65   0.76
# 10       11      0.71  0.69  0.75      0.73        0.64   0.63   0.68
# 11       12      0.71  0.74  0.67      0.75        0.89   0.89   0.89
# 12       13      0.72  0.71  0.73      0.75        0.78   0.91   0.55
# 13       14      0.72  0.72  0.73      0.75        0.74   0.69   0.85
# 14       15      0.72  0.73  0.70      0.76        0.73   0.81   0.67
# 15       16      0.72  0.70  0.73      0.74        0.75   0.72   0.83
# 16       17      0.72  0.75  0.68      0.77        0.61   0.90   0.52
# 17       18      0.72  0.73  0.70      0.75        0.82   0.72   0.93
# 18       19      0.72  0.70  0.75      0.74        0.67   0.62   1.00
# 19       20      0.73  0.74  0.71      0.76        0.57   0.67   0.54
# 20       21      0.72  0.76  0.67      0.76        0.77   0.92   0.70
#
#     f1_score_c
# 0         0.75
# 1         0.40
# 2         0.63
# 3         0.80
# 4         0.61
# 5         0.43
# 6         0.55
# 7         0.45
# 8         0.53
# 9         0.77
# 10        0.75
# 11        0.91
# 12        0.84
# 13        0.78
# 14        0.74
# 15        0.82
# 16        0.52
# 17        0.81
# 18        0.77
# 19        0.45
# 20        0.73
# accuracy      0.72
# tpr           0.73
# tnr           0.71
# f1_score      0.75
# accuracy_c    0.65
# tpr_c         0.70
# tnr_c         0.70
# f1_score_c    0.67
# dtype: float64
# accuracy      0.01
# tpr           0.02
# tnr           0.02
# f1_score      0.01
# accuracy_c    0.13
# tpr_c         0.17
# tnr_c         0.17
# f1_score_c    0.16
# dtype: float64

# %% [markdown]
# ## results 4 empresas UCs

# %%
df = pd.read_csv("./results/hito2_UCs_v2.csv")

results = pd.DataFrame(columns=['cliente', 'tp', 'tn', 'fp', 'fn', 'tp_c', 'tn_c', 'fp_c', 'fn_c'])

for cid in range(1,22):
    best_rnd = df[df["UC"] == f"cliente_{cid}.csv"]["best_rnd"].values[0]
    
    path = f'./rounds/hito2_v4-UC_cliente_{cid}.csv-round-{best_rnd}-weights.npz'
    
#     print(f'best_rnd: {best_rnd}\npath: {path}')
    
    model = setup_model(path)
    
    actual_clients = list(range(1,22))
    actual_clients.remove(cid)
    X_train, X_val, y_train, y_val = cargar_dataset_varios_clientes(actual_clients)
    
    # Evaluar para los clientes conocidos
    res = model.evaluate(X_val, y_val, verbose=0)
    
    tp = res[2]
    tn = res[3]
    fp = res[4]
    fn = res[5]
    
    # Evaluar para el cliente nuevo
    X_train_c, X_val_c, y_train_c, y_val_c = prepare_model_data(f'./data/centralizado/cliente_{cid}.csv')
    res_c = model.evaluate(X_val_c, y_val_c, verbose=0)
    
    tp_c = res_c[2]
    tn_c = res_c[3]
    fp_c = res_c[4]
    fn_c = res_c[5]
    
    fed_res = {
        "cliente": cid,
        "tp": tp,
        "tn": tn,
        "fp": fp,
        "fn": fn,
        "tp_c": tp_c,
        "tn_c": tn_c,
        "fp_c": fp_c,
        "fn_c": fn_c
    }

    print(f'cid: {cid} - {fed_res}')
    results = results.append(fed_res, ignore_index=True)
    
results.to_csv("./results/resultados-modelo-federado-new-client_v4.csv", index=False, header=True)
# Out:
# cid: 1 - {'cliente': 1, 'tp': 2148.0, 'tn': 1851.0, 'fp': 537.0, 'fn': 1023.0, 'tp_c': 132.0, 'tn_c': 19.0, 'fp_c': 2.0, 'fn_c': 100.0}
# cid: 2 - {'cliente': 2, 'tp': 2474.0, 'tn': 1585.0, 'fp': 611.0, 'fn': 887.0, 'tp_c': 38.0, 'tn_c': 109.0, 'fp_c': 104.0, 'fn_c': 4.0}
# cid: 3 - {'cliente': 3, 'tp': 2299.0, 'tn': 1721.0, 'fp': 591.0, 'fn': 940.0, 'tp_c': 95.0, 'tn_c': 66.0, 'fp_c': 31.0, 'fn_c': 69.0}
# cid: 4 - {'cliente': 4, 'tp': 2125.0, 'tn': 1665.0, 'fp': 551.0, 'fn': 970.0, 'tp_c': 243.0, 'tn_c': 145.0, 'fp_c': 48.0, 'fn_c': 65.0}
# cid: 5 - {'cliente': 5, 'tp': 2204.0, 'tn': 1624.0, 'fp': 586.0, 'fn': 897.0, 'tp_c': 160.0, 'tn_c': 143.0, 'fp_c': 56.0, 'fn_c': 142.0}
# cid: 6 - {'cliente': 6, 'tp': 2207.0, 'tn': 1839.0, 'fp': 531.0, 'fn': 977.0, 'tp_c': 56.0, 'tn_c': 34.0, 'fp_c': 5.0, 'fn_c': 163.0}
# cid: 7 - {'cliente': 7, 'tp': 2280.0, 'tn': 1749.0, 'fp': 590.0, 'fn': 940.0, 'tp_c': 74.0, 'tn_c': 49.0, 'fp_c': 21.0, 'fn_c': 109.0}
# cid: 8 - {'cliente': 8, 'tp': 2437.0, 'tn': 1593.0, 'fp': 628.0, 'fn': 893.0, 'tp_c': 51.0, 'tn_c': 97.0, 'fp_c': 91.0, 'fn_c': 22.0}
# cid: 9 - {'cliente': 9, 'tp': 2404.0, 'tn': 1617.0, 'fp': 618.0, 'fn': 926.0, 'tp_c': 47.0, 'tn_c': 111.0, 'fp_c': 63.0, 'fn_c': 26.0}
# cid: 10 - {'cliente': 10, 'tp': 2180.0, 'tn': 1805.0, 'fp': 566.0, 'fn': 999.0, 'tp_c': 140.0, 'tn_c': 32.0, 'fp_c': 6.0, 'fn_c': 84.0}
# cid: 11 - {'cliente': 11, 'tp': 2215.0, 'tn': 1795.0, 'fp': 576.0, 'fn': 972.0, 'tp_c': 131.0, 'tn_c': 32.0, 'fp_c': 6.0, 'fn_c': 85.0}
# cid: 12 - {'cliente': 12, 'tp': 2235.0, 'tn': 1713.0, 'fp': 608.0, 'fn': 1012.0, 'tp_c': 138.0, 'tn_c': 84.0, 'fp_c': 4.0, 'fn_c': 18.0}
# cid: 13 - {'cliente': 13, 'tp': 2314.0, 'tn': 1680.0, 'fp': 637.0, 'fn': 939.0, 'tp_c': 135.0, 'tn_c': 59.0, 'fp_c': 33.0, 'fn_c': 15.0}
# cid: 14 - {'cliente': 14, 'tp': 2324.0, 'tn': 1680.0, 'fp': 649.0, 'fn': 919.0, 'tp_c': 105.0, 'tn_c': 69.0, 'fp_c': 11.0, 'fn_c': 55.0}
# cid: 15 - {'cliente': 15, 'tp': 2318.0, 'tn': 1636.0, 'fp': 633.0, 'fn': 966.0, 'tp_c': 95.0, 'tn_c': 99.0, 'fp_c': 41.0, 'fn_c': 24.0}
# cid: 16 - {'cliente': 16, 'tp': 2228.0, 'tn': 1756.0, 'fp': 599.0, 'fn': 965.0, 'tp_c': 151.0, 'tn_c': 41.0, 'fp_c': 13.0, 'fn_c': 59.0}
# cid: 17 - {'cliente': 17, 'tp': 2451.0, 'tn': 1595.0, 'fp': 621.0, 'fn': 893.0, 'tp_c': 52.0, 'tn_c': 85.0, 'fp_c': 108.0, 'fn_c': 7.0}
# cid: 18 - {'cliente': 18, 'tp': 2349.0, 'tn': 1631.0, 'fp': 666.0, 'fn': 917.0, 'tp_c': 101.0, 'tn_c': 105.0, 'fp_c': 7.0, 'fn_c': 36.0}
# cid: 19 - {'cliente': 19, 'tp': 2185.0, 'tn': 1813.0, 'fp': 563.0, 'fn': 987.0, 'tp_c': 145.0, 'tn_c': 32.0, 'fp_c': 1.0, 'fn_c': 86.0}
# cid: 20 - {'cliente': 20, 'tp': 2408.0, 'tn': 1604.0, 'fp': 617.0, 'fn': 928.0, 'tp_c': 38.0, 'tn_c': 108.0, 'fp_c': 80.0, 'fn_c': 29.0}
# cid: 21 - {'cliente': 21, 'tp': 2447.0, 'tn': 1555.0, 'fp': 695.0, 'fn': 878.0, 'tp_c': 65.0, 'tn_c': 120.0, 'fp_c': 39.0, 'fn_c': 13.0}

# %%
df = pd.read_csv("./results/resultados-modelo-federado-new-client_v4.csv")
columns=['cliente', 'tp', 'tn', 'fp', 'fn', 'tp_c', 'tn_c', 'fp_c', 'fn_c']


df["cliente"] = df["cliente"].apply(lambda x: int(x))

df["accuracy"] = (df["tp"]+df["tn"])/(df["tp"]+df["tn"]+df["fp"]+df["fn"])
df["tpr"] = (df["tp"])/(df["tp"]+df["fn"])
df["tnr"] = (df["tn"])/(df["tn"]+df["fp"])
df["f1_score"] = (df["tp"])/( df["tp"] + (df["fp"]+df["fn"])/2 )

df["accuracy_c"] = (df["tp_c"]+df["tn_c"])/(df["tp_c"]+df["tn_c"]+df["fp_c"]+df["fn_c"])
df["tpr_c"] = (df["tp_c"])/(df["tp_c"]+df["fn_c"])
df["tnr_c"] = (df["tn_c"])/(df["tn_c"]+df["fp_c"])
df["f1_score_c"] = (df["tp_c"])/( df["tp_c"] + (df["fp_c"]+df["fn_c"])/2 )

df = df.sort_values(by=["cliente"])

# df["empresa"] = [3, 2, 1, 1, 1, 3, 3, 2, 2, 3, 3, 1, 1, 1, 1, 3, 2, 1, 3, 2, 2]

print(df[["cliente", "accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].round(2))

print(f'{df[["accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].mean().round(2)}\n{df[["accuracy", "tpr", "tnr", "f1_score", "accuracy_c", "tpr_c", "tnr_c", "f1_score_c"]].std().round(2)}')
# Out:
#     cliente  accuracy   tpr   tnr  f1_score  accuracy_c  tpr_c  tnr_c  \
# 0         1      0.72  0.68  0.78      0.73        0.60   0.57   0.90
# 1         2      0.73  0.74  0.72      0.77        0.58   0.90   0.51
# 2         3      0.72  0.71  0.74      0.75        0.62   0.58   0.68
# 3         4      0.71  0.69  0.75      0.74        0.77   0.79   0.75
# 4         5      0.72  0.71  0.73      0.75        0.60   0.53   0.72
# 5         6      0.73  0.69  0.78      0.75        0.35   0.26   0.87
# 6         7      0.72  0.71  0.75      0.75        0.49   0.40   0.70
# 7         8      0.73  0.73  0.72      0.76        0.57   0.70   0.52
# 8         9      0.72  0.72  0.72      0.76        0.64   0.64   0.64
# 9        10      0.72  0.69  0.76      0.74        0.66   0.62   0.84
# 10       11      0.72  0.70  0.76      0.74        0.64   0.61   0.84
# 11       12      0.71  0.69  0.74      0.73        0.91   0.88   0.95
# 12       13      0.72  0.71  0.73      0.75        0.80   0.90   0.64
# 13       14      0.72  0.72  0.72      0.75        0.72   0.66   0.86
# 14       15      0.71  0.71  0.72      0.74        0.75   0.80   0.71
# 15       16      0.72  0.70  0.75      0.74        0.73   0.72   0.76
# 16       17      0.73  0.73  0.72      0.76        0.54   0.88   0.44
# 17       18      0.72  0.72  0.71      0.75        0.83   0.74   0.94
# 18       19      0.72  0.69  0.76      0.74        0.67   0.63   0.97
# 19       20      0.72  0.72  0.72      0.76        0.57   0.57   0.57
# 20       21      0.72  0.74  0.69      0.76        0.78   0.83   0.75
#
#     f1_score_c
# 0         0.72
# 1         0.41
# 2         0.66
# 3         0.81
# 4         0.62
# 5         0.40
# 6         0.53
# 7         0.47
# 8         0.51
# 9         0.76
# 10        0.74
# 11        0.93
# 12        0.85
# 13        0.76
# 14        0.75
# 15        0.81
# 16        0.47
# 17        0.82
# 18        0.77
# 19        0.41
# 20        0.71
# accuracy      0.72
# tpr           0.71
# tnr           0.74
# f1_score      0.75
# accuracy_c    0.66
# tpr_c         0.68
# tnr_c         0.74
# f1_score_c    0.66
# dtype: float64
# accuracy      0.01
# tpr           0.02
# tnr           0.02
# f1_score      0.01
# accuracy_c    0.13
# tpr_c         0.17
# tnr_c         0.15
# f1_score_c    0.16
# dtype: float64

# %% [markdown]
# ### Distribucion clases agregada

# %%
X_train, X_val, y_train, y_val = cargar_dataset_varios_clientes(list(range(1,22)))

y = np.concatenate((y_train, y_val)).astype(int)

# %%
total = len(y)
som = sum(y==1)
des = sum(y==0)

# %%
print(f'des: {des/total}; som: {som/total}')
# Out:
# des: 0.41293892537622173; som: 0.5870610746237782

# %% [markdown]
# # Experimentacion

# %% [markdown]
# ## Lectura de datos

# %%
x=[]

''' Centralizado '''
Cent_y_k=[]
Cent_e_k=[]

Cent_y_u=[]
Cent_e_u=[]

''' UC2 '''
UC2_y_k=[]
UC2_e_k=[]

UC2_y_u=[]
UC2_e_u=[]

''' UC3 '''
UC3_y_k=[]
UC3_e_k=[]

UC3_y_u=[]
UC3_e_u=[]

n_ucs = 14
for ucs in range(n_ucs, 0, -1):
    path_Cent = f"./results/experimentacion/Centralizado/{ucs}UCs.csv"
    
    df = pd.read_csv(path_Cent)
    
    mean = df[["k_acc", "k_sens", "k_spec", "k_f1", "u_acc", "u_sens", "u_spec", "u_f1"]].mean().round(2)
    std = df[["k_acc", "k_sens", "k_spec", "k_f1", "u_acc", "u_sens", "u_spec", "u_f1"]].std().round(2)
    
    x.append(str(ucs))
    
    Cent_y_k.append(mean[0])
    Cent_e_k.append(std[0])

    Cent_y_u.append(mean[4])
    Cent_e_u.append(std[4])
    
    path_UC2 = f"./results/experimentacion/UC2/hito2_{ucs}UCs.csv"
    
    df = pd.read_csv(path_UC2)
    
    mean = df[["k_acc", "k_sens", "k_spec", "k_f1", "u_acc", "u_sens", "u_spec", "u_f1"]].mean().round(2)
    std = df[["k_acc", "k_sens", "k_spec", "k_f1", "u_acc", "u_sens", "u_spec", "u_f1"]].std().round(2)
    
    UC2_y_k.append(mean[0])
    UC2_e_k.append(std[0])

    UC2_y_u.append(mean[4])
    UC2_e_u.append(std[4])

    path_UC3 = f"./results/experimentacion/UC3/hito3_{ucs}UCs.csv"
    
    df = pd.read_csv(path_UC3)
    mean = df[["k_acc", "k_sens", "k_spec", "k_f1", "u_acc", "u_sens", "u_spec", "u_f1"]].mean().round(2)
    std = df[["k_acc", "k_sens", "k_spec", "k_f1", "u_acc", "u_sens", "u_spec", "u_f1"]].std().round(2)

    UC3_y_k.append(mean[0])
    UC3_e_k.append(std[0])

    UC3_y_u.append(mean[4])
    UC3_e_u.append(std[4])

# %%
df_conocidos = pd.DataFrame(columns=["Modelo", "Usuarios conocidos", "Accuracy"])
df_nuevos = pd.DataFrame(columns=["Modelo", "Usuarios nuevos", "Accuracy"])

n_ucs=14
for ucs in range(n_ucs, 0, -1):
    path_Cent = f"./results/experimentacion/Centralizado/{ucs}UCs.csv"
    
    df = pd.read_csv(path_Cent)
    
    for ind in df.index:
        data = {
            "Modelo": "Centralizado conocidos",
            "Usuarios conocidos": 21-ucs,
            "Accuracy": df['k_acc'][ind]
        }
        
        df_conocidos = df_conocidos.append(data, ignore_index=True)
        
        data = {
            "Modelo": "Centralizado nuevos",
            "Usuarios nuevos": ucs,
            "Accuracy": df['u_acc'][ind]
        }
        
        df_nuevos = df_nuevos.append(data, ignore_index=True)
        
    path_UC2 = f"./results/experimentacion/UC2/hito2_{ucs}UCs.csv"
    
    df = pd.read_csv(path_UC2)
    
    for ind in df.index:
        data = {
            "Modelo": "UC2 conocidos",
            "Usuarios conocidos": 21-ucs,
            "Accuracy": df['k_acc'][ind]
        }
        
        df_conocidos = df_conocidos.append(data, ignore_index=True)
        
        data = {
            "Modelo": "UC2 nuevos",
            "Usuarios nuevos": ucs,
            "Accuracy": df['u_acc'][ind]
        }
        
        df_nuevos = df_nuevos.append(data, ignore_index=True)
        
    path_UC3 = f"./results/experimentacion/UC3/hito3_{ucs}UCs.csv"
    
    df = pd.read_csv(path_UC3)
    
    for ind in df.index:
        data = {
            "Modelo": "UC3 conocidos",
            "Usuarios conocidos": 21-ucs,
            "Accuracy": df['k_acc'][ind]
        }
        
        df_conocidos = df_conocidos.append(data, ignore_index=True)
        
        data = {
            "Modelo": "UC3 nuevos",
            "Usuarios nuevos": ucs,
            "Accuracy": df['u_acc'][ind]
        }
        
        df_nuevos = df_nuevos.append(data, ignore_index=True)

# %%
df_conocidos_plot1 = df_conocidos[df_conocidos.Modelo != "UC3 conocidos"]

df_nuevos_plot1 = df_nuevos[df_nuevos.Modelo != "UC3 nuevos"]

df_conocidos_plot2 = df_conocidos[df_conocidos.Modelo != "Centralizado conocidos"]

df_nuevos_plot2 = df_nuevos[df_nuevos.Modelo != "Centralizado nuevos"]

# %%
df_conocidos_plot2.groupby(["Modelo", "Usuarios conocidos"]).mean().round(3)
# Out:
#                                   Accuracy
# Modelo        Usuarios conocidos
# UC2 conocidos 7                      0.717
#               8                      0.708
#               9                      0.714
#               10                     0.710
#               11                     0.720
#               12                     0.713
#               13                     0.713
#               14                     0.716
#               15                     0.713
#               16                     0.713
#               17                     0.716
#               18                     0.711
#               19                     0.713
#               20                     0.711
# UC3 conocidos 7                      0.719
#               8                      0.700
#               9                      0.704
#               10                     0.692
#               11                     0.704
#               12                     0.691
#               13                     0.686
#               14                     0.684
#               15                     0.681
#               16                     0.691
#               17                     0.683
#               18                     0.680
#               19                     0.685
#               20                     0.683

# %%
# CONOCIDOS
# General ML 77,4%-73,2%
# General FL 71,7%-71,1%
# General HFL 71,9%-68,3%

# NUEVOS
# General ML 63,2%-63,6%
# General FL 62,0%-67,1%
# General HFL 63,1%-63,5%

# %%
df_nuevos_plot1["Usuarios nuevos"] = df_nuevos_plot1["Usuarios nuevos"].apply(str)
df_nuevos_plot2["Usuarios nuevos"] = df_nuevos_plot2["Usuarios nuevos"].apply(str)
# Out:
# C:\Users\34601\AppData\Local\Temp/ipykernel_15260/1006162278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nuevos_plot1["Usuarios nuevos"] = df_nuevos_plot1["Usuarios nuevos"].apply(str)
# C:\Users\34601\AppData\Local\Temp/ipykernel_15260/1006162278.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nuevos_plot2["Usuarios nuevos"] = df_nuevos_plot2["Usuarios nuevos"].apply(str)

# %% [markdown]
# ## Visualizaciones

# %%
# Parametros
fmt = "-o"
markersize = 8
elinewidth = 4
capsize=10
capthick=4

UC1_k_thresh = (0.74+0.80+0.78)/3
UC1_u_thresh = (0.67+0.55+0.63)/3

# %% [markdown]
# ### Federado por empresa vs Centralizado vs Federado centralizado (UC2)

# %%
''' CONOCIDOS '''
f = plt.figure(figsize=(20,8))

plt.axhline(UC1_k_thresh , color="blue", linestyle="--", label="UC1 conocidos")

plt.errorbar(x, Cent_y_k, label="Centralizado conocidos",
             fmt=fmt, markersize=markersize, color="green",
             elinewidth=elinewidth, capsize=capsize, capthick=capthick, ecolor="lightblue")

plt.errorbar(x, UC2_y_k, label="UC2 conocidos",
             fmt=fmt, markersize=markersize, color="blue",
             elinewidth=elinewidth, capsize=capsize, capthick=capthick, ecolor="lightblue")

size_ticks = 20
plt.xticks(x, fontsize=size_ticks)
plt.yticks(fontsize=size_ticks)
plt.ylim(0.5,1)

size_label = 26
plt.xlabel('Clientes desconocidos', fontweight ='bold', labelpad = 10,fontsize = size_label)
plt.ylabel('Accuracy', fontweight ='bold', labelpad = 10,fontsize = size_label)

size_legend = 20; plt.legend(loc='upper right', fontsize = size_legend)

''' NUEVOS '''
plt.show()
# f.savefig('../recursos/PEvsCentvsUC2_known.pdf', bbox_inches='tight')

f = plt.figure(figsize=(20,8))

plt.axhline(UC1_u_thresh, color="red", linestyle="--", label="UC1 nuevos")

plt.errorbar(x, Cent_y_k, label="Centralizado nuevos",
             fmt=fmt, markersize=markersize, color="green",
             elinewidth=elinewidth, capsize=capsize, capthick=capthick, ecolor="lightblue")

plt.errorbar(x, UC2_y_u, label="UC2 nuevos",
            fmt=fmt, markersize=markersize, color="blue",
            elinewidth=elinewidth, capsize=capsize, capthick=capthick, ecolor="lightblue")

size_ticks = 20
plt.xticks(x, fontsize=size_ticks)
plt.yticks(fontsize=size_ticks)
plt.ylim(0.5,1)

size_label = 26
plt.xlabel('Clientes desconocidos', fontweight ='bold', labelpad = 10,fontsize = size_label)
plt.ylabel('Accuracy', fontweight ='bold', labelpad = 10,fontsize = size_label)

size_legend = 20; plt.legend(loc='upper right', fontsize = size_legend)

plt.show()
# f.savefig('../recursos/PEvsCentvsUC2_new.pdf', bbox_inches='tight')

# %%
import seaborn as sns

''' Conocidos '''
f = plt.figure(figsize=(20,8))

plt.axhline(UC1_k_thresh , color="black", linestyle="--", label="UC1 conocidos")
sns.lineplot(data=df_conocidos_plot1, x="Usuarios conocidos", y="Accuracy", hue="Modelo", palette= ["#00FF00", "#0000FF"])

size_ticks = 20
plt.xticks(range(7,20+1), fontsize=size_ticks)
plt.yticks(fontsize=size_ticks)
plt.ylim(0.5,1)

size_label = 26
plt.xlabel('Conductores conocidos', fontweight ='bold', labelpad = 10, fontsize = size_label)
plt.ylabel('Accuracy', fontweight ='bold', labelpad = 10,fontsize = size_label)

size_legend = 20; plt.legend(loc='upper right', fontsize = size_legend)

plt.show()
f.savefig('../recursos/PEvsCentvsUC2_known.pdf', bbox_inches='tight')

''' Nuevos '''
f = plt.figure(figsize=(20,8))
plt.axhline(UC1_u_thresh, color="black", linestyle="--", label="UC1 nuevos")
sns.lineplot(data=df_nuevos_plot1, x="Usuarios nuevos", y="Accuracy", hue="Modelo", palette= ["#00FF00", "#0000FF"])

size_ticks = 20
plt.xticks(fontsize=size_ticks)
plt.yticks(fontsize=size_ticks)
plt.ylim(0.5,1)

size_label = 26
plt.xlabel('Conductores desconocidos', fontweight ='bold', labelpad = 10,fontsize = size_label)
plt.ylabel('Accuracy', fontweight ='bold', labelpad = 10,fontsize = size_label)

size_legend = 20; plt.legend(loc='upper right', fontsize = size_legend)

plt.show()
f.savefig('../recursos/PEvsCentvsUC2_new.pdf', bbox_inches='tight')

# %% [markdown]
# ### UC2 vs UC3

# %%
''' CONOCIDOS '''
f = plt.figure(figsize=(20,8))
plt.errorbar(x, UC2_y_k, label="UC2 conocidos",
             fmt=fmt, markersize=markersize, color="blue",
             elinewidth=elinewidth, capsize=capsize, capthick=capthick, ecolor="lightblue")

plt.errorbar(x, UC3_y_k, label="UC3 conocidos",
             fmt=fmt, markersize=markersize, color="red",
             elinewidth=elinewidth, capsize=capsize, capthick=capthick, ecolor="orange")

size_ticks = 20
plt.xticks(x, fontsize=size_ticks)
plt.yticks(fontsize=size_ticks)
plt.ylim(0.5,1)

size_label = 26
plt.xlabel('Clientes desconocidos', fontweight ='bold', labelpad = 10,fontsize = size_label)
plt.ylabel('Accuracy', fontweight ='bold', labelpad = 10,fontsize = size_label)

size_legend = 20; plt.legend(loc='upper right', fontsize = size_legend)

''' NUEVOS '''
plt.show()
#f.savefig('../recursos/UC2vsUC3_known.pdf', bbox_inches='tight')

f = plt.figure(figsize=(20,8))
plt.errorbar(x, UC2_y_u, label="UC2 nuevos",
            fmt=fmt, markersize=markersize, color="blue",
            elinewidth=elinewidth, capsize=capsize, capthick=capthick, ecolor="lightblue")

plt.errorbar(x, UC3_y_u, label="UC3 nuevos",
            fmt=fmt, markersize=markersize, color="red",
            elinewidth=elinewidth, capsize=capsize, capthick=capthick, ecolor="orange")

size_ticks = 20
plt.xticks(x, fontsize=size_ticks)
plt.yticks(fontsize=size_ticks)
plt.ylim(0.5,1)

size_label = 26
plt.xlabel('Clientes desconocidos', fontweight ='bold', labelpad = 10,fontsize = size_label)
plt.ylabel('Accuracy', fontweight ='bold', labelpad = 10,fontsize = size_label)

size_legend = 20; plt.legend(loc='upper right', fontsize = size_legend)

plt.show()
#f.savefig('../recursos/UC2vsUC3_new.pdf', bbox_inches='tight')

# %%
''' Conocidos '''
f = plt.figure(figsize=(20,8))

sns.lineplot(data=df_conocidos_plot2, x="Usuarios conocidos", y="Accuracy", hue="Modelo", palette= ["#0000FF", "#FF0000"])

size_ticks = 20
plt.xticks(range(7,20+1), fontsize=size_ticks)
plt.yticks(fontsize=size_ticks)
plt.ylim(0.5,1)

size_label = 26
plt.xlabel('Conductores conocidos', fontweight ='bold', labelpad = 10,fontsize = size_label)
plt.ylabel('Accuracy', fontweight ='bold', labelpad = 10,fontsize = size_label)

size_legend = 20; plt.legend(loc='upper right', fontsize = size_legend)

plt.show()
f.savefig('../recursos/UC2vsUC3_known.pdf', bbox_inches='tight')

''' Nuevos '''
f = plt.figure(figsize=(20,8))

sns.lineplot(data=df_nuevos_plot2, x="Usuarios nuevos", y="Accuracy", hue="Modelo", palette= ["#0000FF", "#FF0000"])

size_ticks = 20
plt.xticks(fontsize=size_ticks)
plt.yticks(fontsize=size_ticks)
plt.ylim(0.5,1)

size_label = 26
plt.xlabel('Conductores desconocidos', fontweight ='bold', labelpad = 10,fontsize = size_label)
plt.ylabel('Accuracy', fontweight ='bold', labelpad = 10,fontsize = size_label)

size_legend = 20; plt.legend(loc='upper right', fontsize = size_legend)

plt.show()
f.savefig('../recursos/UC2vsUC3_new.pdf', bbox_inches='tight')
