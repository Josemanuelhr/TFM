# %%
from itertools import combinations
import random

import os
import math

# Make TensorFlow logs less verbose
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import flwr as fl
import tensorflow as tf

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

from keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.optimizers import Adadelta

from typing import Dict

from flwr.common.logger import log
from logging import INFO
from csv import writer


from numpy.random import seed
from tensorflow.keras.utils import set_random_seed

from tensorflow.keras.metrics import Precision, Recall, TrueNegatives, TruePositives, FalsePositives, FalseNegatives

import regex as re

# %%
ALL_IDS = list(range(1,21+1))

CONDUCTORES_IDS = {
    1: [3,4,5,12,  2,8,  1],
    2: [13,14,    6,7,10,11,16],
    3: [15,18,  9,17,20,21,  19]
}

# Parametros:
    # tam: numero de sujetos que debe haber en las combinaciones generadas
# Retorna:
    # Lista de listas, cada lista se corresponde con una combinacion diferente de tamaño n_desconocidos
def generar_combinaciones(tam):
    return list(combinations(ALL_IDS, tam))

# Parametros:
    # comb: lista con los conductores de la combinacion
# Retorna:
    # True: si hay al menos uno de cada empresa
    # False: en caso contrario
def uno_por_empresa(comb):
    conds = {
        1: False,
        2: False,
        3: False
    }
    
    for cid in comb:
        for empid in CONDUCTORES_IDS:
            if(cid in CONDUCTORES_IDS[empid]):
                conds[empid] = True
    
    return conds[1] and conds[2] and conds[3]

def subset_combinaciones_validas(combs, n):
    seleccionadas = []
    idx_comprobados = []
    n_seleccionadas = 0
    
    seed(123)
    
    while (n_seleccionadas<n):
        idx = int(np.random.randint(0, len(combs), 1))
        
        if (idx not in idx_comprobados):
            comb = combs[idx]
            
            if (uno_por_empresa(comb)):
                seleccionadas.append(comb)
                n_seleccionadas += 1
                
        idx_comprobados.append(idx)
            
    return seleccionadas

def prepare_model_data(client_file):
    df = pd.read_csv(client_file)
    
    train, test = train_test_split(df, test_size=0.30, random_state=42)
    
    X_train = train[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]
    X_test = test[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]
    y_train = train['y_class']
    y_test = test['y_class']
    
    scaler = StandardScaler()

    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test

def cargar_dataset_varios_clientes(clientes):
    base_path = "./data/centralizado"
    
    X_train, X_val, y_train, y_val = prepare_model_data(f'{base_path}/cliente_{clientes[0]}.csv')
    
    for cid in clientes[1:]:
        path = f'{base_path}/cliente_{cid}.csv'
        X_train_act, X_val_act, y_train_act, y_val_act = prepare_model_data(path)
    
        X_train = np.vstack((X_train, X_train_act))
        X_val = np.vstack((X_val, X_val_act))
        y_train = np.concatenate((y_train, y_train_act))
        y_val = np.concatenate((y_val, y_val_act))
        
    return X_train, X_val, y_train, y_val

def get_model():
    # Model best hyperparameters (Ver notebook Hito0-Optimizacion-Baseline)
    neurons = 36
    activation = "relu"
    learning_rate = 0.180165
    optimizer = Adadelta(learning_rate=learning_rate)
    
    input_shape = (7,)
    
    # Create model
    model = Sequential()
    
    model.add(Dense(neurons, input_shape=input_shape, activation=activation))
    
    model.add(BatchNormalization())
        
    model.add(Dense(neurons, activation=activation))
    model.add(Dense(neurons, activation=activation))
    model.add(Dense(neurons, activation=activation))
    
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', TruePositives(), TrueNegatives(), FalsePositives(), FalseNegatives()])
    
    
    return model

def train_model(model, X_train, y_train, X_val, y_val, batch_size = 32, epochs = 150, es = True):
    
    callbacks = []
    if es:
        callbacks.append(EarlyStopping(monitor='accuracy', mode='max', verbose=1, patience=20, restore_best_weights=True))

    hist = model.fit(
        X_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        verbose=0,
        validation_data=(X_val, y_val),
        callbacks = callbacks)
    
    return hist

# %%
for n_desconocidos in range(1,14+1):
    combs = generar_combinaciones(21-n_desconocidos)
    if (n_desconocidos > 1):
        combs = subset_combinaciones_validas(combs, 30)
    
    # Se crea el fichero si no existe previamente
    if not os.path.exists(f"./results/experimentacion/Centralizado/{n_desconocidos}UCs.csv"):
        results_cent = pd.DataFrame(columns=["UCs", "k_acc", "k_sens", "k_spec", "k_f1", "u_acc", "u_sens", "u_spec", "u_f1"])
        results_cent.to_csv(f"./results/experimentacion/Centralizado/{n_desconocidos}UCs.csv", mode='w', index=False, header=True)
    
    # Se busca si ya hay algun registro
    with open(f"./results/experimentacion/Centralizado/{n_desconocidos}UCs.csv", 'r') as f:
        start_comb = len(f.readlines())-1 # restandole el header
        
    # Se comienza/retoma el experimento de n_desconocidos
    for comb in combs[start_comb:]:
        if (uno_por_empresa(comb)):
            global UNSEEN_CLIENTS
            UNSEEN_CLIENTS = list(set(ALL_IDS)-set(comb))
            
            global KNOWN_CLIENTS
            KNOWN_CLIENTS = list(comb)
            
            print(f'{n_desconocidos} - {UNSEEN_CLIENTS}')
            
            # Entrenar modelo centralizado
            X_train, X_val, y_train, y_val = cargar_dataset_varios_clientes(KNOWN_CLIENTS)
            
            seed(1)
            set_random_seed(2)

            # Entrenamiento de modelo centralizado
            model = get_model()
            hist = hist = model.fit(
                X_train, y_train,
                batch_size=32,
                epochs=20,
                verbose=0,
                use_multiprocessing=True,
                workers=6,
                validation_data=(X_val, y_val))

            # Evaluar para los clientes conocidos
            res = hist.model.evaluate(X_val, y_val, verbose=2)
            
            tp_k = res[2]
            tn_k = res[3]
            fp_k = res[4]
            fn_k = res[5]
            
            k_acc = (tp_k+tn_k)/(tp_k+tn_k+fp_k+fn_k)
            k_sens = (tp_k)/(tp_k+fn_k)
            k_spec = (tn_k)/(tn_k+fp_k)
            k_f1 = (tp_k)/( tp_k + (fp_k+fn_k)/2 )

            # Evaluar para el cliente nuevo
            X_train, X_val, y_train, y_val = cargar_dataset_varios_clientes(KNOWN_CLIENTS)
            res = hist.model.evaluate(X_val, y_val, verbose=2)

            tp_u = res[2]
            tn_u = res[3]
            fp_u = res[4]
            fn_u = res[5]

            u_acc = (tp_u+tn_u)/(tp_u+tn_u+fp_u+fn_u)
            u_sens = (tp_u)/(tp_u+fn_u)
            u_spec = (tn_u)/(tn_u+fp_u)
            u_f1 = (tp_u)/( tp_u + (fp_u+fn_u)/2 )
            
            results_cent = pd.DataFrame(columns=["UCs", "k_acc", "k_sens", "k_spec", "k_f1", "u_acc", "u_sens", "u_spec", "u_f1"])
            fed_res = {
                "UCs": UNSEEN_CLIENTS,
                "k_acc": k_acc,
                "k_sens": k_sens,
                "k_spec": k_spec,
                "k_f1": k_f1,
                "u_acc": u_acc,
                "u_sens": u_sens,
                "u_spec": u_spec,
                "u_f1": u_f1
            }
            
            results_cent = results_cent.append(fed_res, ignore_index=True)
            results_cent.to_csv(f"./results/experimentacion/Centralizado/{n_desconocidos}UCs.csv", mode='a', index=False, header=False)
# Out:
# 1 - [19]
# 174/174 - 1s - loss: 0.5283 - accuracy: 0.7296 - true_positives_6: 2213.0000 - true_negatives_6: 1835.0000 - false_positives_6: 541.0000 - false_negatives_6: 959.0000 - 718ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5283 - accuracy: 0.7296 - true_positives_6: 2213.0000 - true_negatives_6: 1835.0000 - false_positives_6: 541.0000 - false_negatives_6: 959.0000 - 686ms/epoch - 4ms/step
# 1 - [18]
# 174/174 - 1s - loss: 0.5302 - accuracy: 0.7291 - true_positives_7: 2453.0000 - true_negatives_7: 1603.0000 - false_positives_7: 694.0000 - false_negatives_7: 813.0000 - 787ms/epoch - 5ms/step
# 174/174 - 1s - loss: 0.5302 - accuracy: 0.7291 - true_positives_7: 2453.0000 - true_negatives_7: 1603.0000 - false_positives_7: 694.0000 - false_negatives_7: 813.0000 - 814ms/epoch - 5ms/step
# 1 - [17]
# 174/174 - 1s - loss: 0.5193 - accuracy: 0.7376 - true_positives_8: 2692.0000 - true_negatives_8: 1409.0000 - false_positives_8: 807.0000 - false_negatives_8: 652.0000 - 810ms/epoch - 5ms/step
# 174/174 - 1s - loss: 0.5193 - accuracy: 0.7376 - true_positives_8: 2692.0000 - true_negatives_8: 1409.0000 - false_positives_8: 807.0000 - false_negatives_8: 652.0000 - 794ms/epoch - 5ms/step
# 1 - [16]
# 174/174 - 1s - loss: 0.5290 - accuracy: 0.7318 - true_positives_9: 2298.0000 - true_negatives_9: 1762.0000 - false_positives_9: 593.0000 - false_negatives_9: 895.0000 - 804ms/epoch - 5ms/step
# 174/174 - 1s - loss: 0.5290 - accuracy: 0.7318 - true_positives_9: 2298.0000 - true_negatives_9: 1762.0000 - false_positives_9: 593.0000 - false_negatives_9: 895.0000 - 826ms/epoch - 5ms/step
# 1 - [15]
# 174/174 - 1s - loss: 0.5272 - accuracy: 0.7256 - true_positives_10: 2464.0000 - true_negatives_10: 1565.0000 - false_positives_10: 704.0000 - false_negatives_10: 820.0000 - 781ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5272 - accuracy: 0.7256 - true_positives_10: 2464.0000 - true_negatives_10: 1565.0000 - false_positives_10: 704.0000 - false_negatives_10: 820.0000 - 796ms/epoch - 5ms/step
# 1 - [14]
# 175/175 - 1s - loss: 0.5293 - accuracy: 0.7315 - true_positives_11: 2305.0000 - true_negatives_11: 1771.0000 - false_positives_11: 558.0000 - false_negatives_11: 938.0000 - 786ms/epoch - 4ms/step
# 175/175 - 1s - loss: 0.5293 - accuracy: 0.7315 - true_positives_11: 2305.0000 - true_negatives_11: 1771.0000 - false_positives_11: 558.0000 - false_negatives_11: 938.0000 - 812ms/epoch - 5ms/step
# 1 - [13]
# 175/175 - 1s - loss: 0.5326 - accuracy: 0.7307 - true_positives_12: 2420.0000 - true_negatives_12: 1650.0000 - false_positives_12: 667.0000 - false_negatives_12: 833.0000 - 826ms/epoch - 5ms/step
# 175/175 - 1s - loss: 0.5326 - accuracy: 0.7307 - true_positives_12: 2420.0000 - true_negatives_12: 1650.0000 - false_positives_12: 667.0000 - false_negatives_12: 833.0000 - 857ms/epoch - 5ms/step
# 1 - [12]
# 174/174 - 1s - loss: 0.5360 - accuracy: 0.7213 - true_positives_13: 2390.0000 - true_negatives_13: 1626.0000 - false_positives_13: 695.0000 - false_negatives_13: 857.0000 - 750ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5360 - accuracy: 0.7213 - true_positives_13: 2390.0000 - true_negatives_13: 1626.0000 - false_positives_13: 695.0000 - false_negatives_13: 857.0000 - 798ms/epoch - 5ms/step
# 1 - [11]
# 174/174 - 1s - loss: 0.5254 - accuracy: 0.7370 - true_positives_14: 2322.0000 - true_negatives_14: 1774.0000 - false_positives_14: 597.0000 - false_negatives_14: 865.0000 - 791ms/epoch - 5ms/step
# 174/174 - 1s - loss: 0.5254 - accuracy: 0.7370 - true_positives_14: 2322.0000 - true_negatives_14: 1774.0000 - false_positives_14: 597.0000 - false_negatives_14: 865.0000 - 826ms/epoch - 5ms/step
# 1 - [10]
# 174/174 - 1s - loss: 0.5272 - accuracy: 0.7294 - true_positives_15: 2336.0000 - true_negatives_15: 1712.0000 - false_positives_15: 659.0000 - false_negatives_15: 843.0000 - 757ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5272 - accuracy: 0.7294 - true_positives_15: 2336.0000 - true_negatives_15: 1712.0000 - false_positives_15: 659.0000 - false_negatives_15: 843.0000 - 665ms/epoch - 4ms/step
# 1 - [9]
# 174/174 - 1s - loss: 0.5219 - accuracy: 0.7357 - true_positives_16: 2565.0000 - true_negatives_16: 1529.0000 - false_positives_16: 706.0000 - false_negatives_16: 765.0000 - 800ms/epoch - 5ms/step
# 174/174 - 1s - loss: 0.5219 - accuracy: 0.7357 - true_positives_16: 2565.0000 - true_negatives_16: 1529.0000 - false_positives_16: 706.0000 - false_negatives_16: 765.0000 - 831ms/epoch - 5ms/step
# 1 - [8]
# 174/174 - 1s - loss: 0.5187 - accuracy: 0.7397 - true_positives_17: 2576.0000 - true_negatives_17: 1530.0000 - false_positives_17: 691.0000 - false_negatives_17: 754.0000 - 776ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5187 - accuracy: 0.7397 - true_positives_17: 2576.0000 - true_negatives_17: 1530.0000 - false_positives_17: 691.0000 - false_negatives_17: 754.0000 - 823ms/epoch - 5ms/step
# 1 - [7]
# 174/174 - 1s - loss: 0.5202 - accuracy: 0.7332 - true_positives_18: 2416.0000 - true_negatives_18: 1660.0000 - false_positives_18: 679.0000 - false_negatives_18: 804.0000 - 659ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5202 - accuracy: 0.7332 - true_positives_18: 2416.0000 - true_negatives_18: 1660.0000 - false_positives_18: 679.0000 - false_negatives_18: 804.0000 - 752ms/epoch - 4ms/step
# 1 - [6]
# 174/174 - 1s - loss: 0.5185 - accuracy: 0.7346 - true_positives_19: 2260.0000 - true_negatives_19: 1820.0000 - false_positives_19: 550.0000 - false_negatives_19: 924.0000 - 692ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5185 - accuracy: 0.7346 - true_positives_19: 2260.0000 - true_negatives_19: 1820.0000 - false_positives_19: 550.0000 - false_negatives_19: 924.0000 - 678ms/epoch - 4ms/step
# 1 - [5]
# 166/166 - 1s - loss: 0.5281 - accuracy: 0.7330 - true_positives_20: 2189.0000 - true_negatives_20: 1704.0000 - false_positives_20: 506.0000 - false_negatives_20: 912.0000 - 652ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5281 - accuracy: 0.7330 - true_positives_20: 2189.0000 - true_negatives_20: 1704.0000 - false_positives_20: 506.0000 - false_negatives_20: 912.0000 - 669ms/epoch - 4ms/step
# 1 - [4]
# 166/166 - 1s - loss: 0.5345 - accuracy: 0.7277 - true_positives_21: 2158.0000 - true_negatives_21: 1707.0000 - false_positives_21: 509.0000 - false_negatives_21: 937.0000 - 659ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5345 - accuracy: 0.7277 - true_positives_21: 2158.0000 - true_negatives_21: 1707.0000 - false_positives_21: 509.0000 - false_negatives_21: 937.0000 - 675ms/epoch - 4ms/step
# 1 - [3]
# 174/174 - 1s - loss: 0.5260 - accuracy: 0.7325 - true_positives_22: 2401.0000 - true_negatives_22: 1665.0000 - false_positives_22: 647.0000 - false_negatives_22: 838.0000 - 684ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5260 - accuracy: 0.7325 - true_positives_22: 2401.0000 - true_negatives_22: 1665.0000 - false_positives_22: 647.0000 - false_negatives_22: 838.0000 - 679ms/epoch - 4ms/step
# 1 - [2]
# 174/174 - 1s - loss: 0.5126 - accuracy: 0.7351 - true_positives_23: 2614.0000 - true_negatives_23: 1471.0000 - false_positives_23: 725.0000 - false_negatives_23: 747.0000 - 661ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5126 - accuracy: 0.7351 - true_positives_23: 2614.0000 - true_negatives_23: 1471.0000 - false_positives_23: 725.0000 - false_negatives_23: 747.0000 - 668ms/epoch - 4ms/step
# 1 - [1]
# 174/174 - 1s - loss: 0.5254 - accuracy: 0.7343 - true_positives_24: 2359.0000 - true_negatives_24: 1723.0000 - false_positives_24: 665.0000 - false_negatives_24: 812.0000 - 670ms/epoch - 4ms/step
# 174/174 - 1s - loss: 0.5254 - accuracy: 0.7343 - true_positives_24: 2359.0000 - true_negatives_24: 1723.0000 - false_positives_24: 665.0000 - false_negatives_24: 812.0000 - 674ms/epoch - 4ms/step
# 2 - [17, 6]
# 166/166 - 1s - loss: 0.5092 - accuracy: 0.7495 - true_positives_25: 2315.0000 - true_negatives_25: 1659.0000 - false_positives_25: 518.0000 - false_negatives_25: 810.0000 - 641ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5092 - accuracy: 0.7495 - true_positives_25: 2315.0000 - true_negatives_25: 1659.0000 - false_positives_25: 518.0000 - false_negatives_25: 810.0000 - 667ms/epoch - 4ms/step
# 2 - [5, 15]
# 158/158 - 1s - loss: 0.5295 - accuracy: 0.7282 - true_positives_26: 2250.0000 - true_negatives_26: 1429.0000 - false_positives_26: 641.0000 - false_negatives_26: 732.0000 - 593ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5295 - accuracy: 0.7282 - true_positives_26: 2250.0000 - true_negatives_26: 1429.0000 - false_positives_26: 641.0000 - false_negatives_26: 732.0000 - 602ms/epoch - 4ms/step
# 2 - [9, 21]
# 167/167 - 1s - loss: 0.5219 - accuracy: 0.7318 - true_positives_27: 2493.0000 - true_negatives_27: 1406.0000 - false_positives_27: 670.0000 - false_negatives_27: 759.0000 - 631ms/epoch - 4ms/step
# 167/167 - 1s - loss: 0.5219 - accuracy: 0.7318 - true_positives_27: 2493.0000 - true_negatives_27: 1406.0000 - false_positives_27: 670.0000 - false_negatives_27: 759.0000 - 628ms/epoch - 4ms/step
# 2 - [14, 7]
# 167/167 - 1s - loss: 0.5204 - accuracy: 0.7340 - true_positives_28: 2262.0000 - true_negatives_28: 1642.0000 - false_positives_28: 617.0000 - false_negatives_28: 798.0000 - 635ms/epoch - 4ms/step
# 167/167 - 1s - loss: 0.5204 - accuracy: 0.7340 - true_positives_28: 2262.0000 - true_negatives_28: 1642.0000 - false_positives_28: 617.0000 - false_negatives_28: 798.0000 - 647ms/epoch - 4ms/step
# 2 - [19, 15]
# 166/166 - 1s - loss: 0.5284 - accuracy: 0.7287 - true_positives_29: 2241.0000 - true_negatives_29: 1613.0000 - false_positives_29: 623.0000 - false_negatives_29: 812.0000 - 631ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5284 - accuracy: 0.7287 - true_positives_29: 2241.0000 - true_negatives_29: 1613.0000 - false_positives_29: 623.0000 - false_negatives_29: 812.0000 - 640ms/epoch - 4ms/step
# 2 - [8, 16]
# 166/166 - 1s - loss: 0.5212 - accuracy: 0.7386 - true_positives_30: 2418.0000 - true_negatives_30: 1487.0000 - false_positives_30: 680.0000 - false_negatives_30: 702.0000 - 632ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5212 - accuracy: 0.7386 - true_positives_30: 2418.0000 - true_negatives_30: 1487.0000 - false_positives_30: 680.0000 - false_negatives_30: 702.0000 - 639ms/epoch - 4ms/step
# 2 - [20, 6]
# 166/166 - 1s - loss: 0.5069 - accuracy: 0.7403 - true_positives_31: 2276.0000 - true_negatives_31: 1647.0000 - false_positives_31: 535.0000 - false_negatives_31: 841.0000 - 603ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5069 - accuracy: 0.7403 - true_positives_31: 2276.0000 - true_negatives_31: 1647.0000 - false_positives_31: 535.0000 - false_negatives_31: 841.0000 - 636ms/epoch - 4ms/step
# 2 - [18, 5]
# 159/159 - 1s - loss: 0.5323 - accuracy: 0.7220 - true_positives_32: 2171.0000 - true_negatives_32: 1484.0000 - false_positives_32: 614.0000 - false_negatives_32: 793.0000 - 605ms/epoch - 4ms/step
# 159/159 - 1s - loss: 0.5323 - accuracy: 0.7220 - true_positives_32: 2171.0000 - true_negatives_32: 1484.0000 - false_positives_32: 614.0000 - false_negatives_32: 793.0000 - 642ms/epoch - 4ms/step
# 2 - [10, 19]
# 166/166 - 1s - loss: 0.5277 - accuracy: 0.7331 - true_positives_33: 2020.0000 - true_negatives_33: 1855.0000 - false_positives_33: 483.0000 - false_negatives_33: 928.0000 - 634ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5277 - accuracy: 0.7331 - true_positives_33: 2020.0000 - true_negatives_33: 1855.0000 - false_positives_33: 483.0000 - false_negatives_33: 928.0000 - 646ms/epoch - 4ms/step
# 2 - [16, 7]
# 166/166 - 1s - loss: 0.5208 - accuracy: 0.7365 - true_positives_34: 2153.0000 - true_negatives_34: 1747.0000 - false_positives_34: 538.0000 - false_negatives_34: 857.0000 - 630ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5208 - accuracy: 0.7365 - true_positives_34: 2153.0000 - true_negatives_34: 1747.0000 - false_positives_34: 538.0000 - false_negatives_34: 857.0000 - 636ms/epoch - 4ms/step
# 2 - [13, 6]
# 166/166 - 1s - loss: 0.5243 - accuracy: 0.7391 - true_positives_35: 2172.0000 - true_negatives_35: 1754.0000 - false_positives_35: 524.0000 - false_negatives_35: 862.0000 - 665ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5243 - accuracy: 0.7391 - true_positives_35: 2172.0000 - true_negatives_35: 1754.0000 - false_positives_35: 524.0000 - false_negatives_35: 862.0000 - 685ms/epoch - 4ms/step
# 2 - [19, 11]
# 166/166 - 1s - loss: 0.5242 - accuracy: 0.7348 - true_positives_36: 2082.0000 - true_negatives_36: 1808.0000 - false_positives_36: 530.0000 - false_negatives_36: 874.0000 - 664ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5242 - accuracy: 0.7348 - true_positives_36: 2082.0000 - true_negatives_36: 1808.0000 - false_positives_36: 530.0000 - false_negatives_36: 874.0000 - 696ms/epoch - 4ms/step
# 2 - [9, 14]
# 167/167 - 1s - loss: 0.5231 - accuracy: 0.7320 - true_positives_37: 2358.0000 - true_negatives_37: 1540.0000 - false_positives_37: 615.0000 - false_negatives_37: 812.0000 - 631ms/epoch - 4ms/step
# 167/167 - 1s - loss: 0.5231 - accuracy: 0.7320 - true_positives_37: 2358.0000 - true_negatives_37: 1540.0000 - false_positives_37: 615.0000 - false_negatives_37: 812.0000 - 638ms/epoch - 4ms/step
# 2 - [17, 13]
# 167/167 - 1s - loss: 0.5244 - accuracy: 0.7416 - true_positives_38: 2454.0000 - true_negatives_38: 1490.0000 - false_positives_38: 634.0000 - false_negatives_38: 740.0000 - 648ms/epoch - 4ms/step
# 167/167 - 1s - loss: 0.5244 - accuracy: 0.7416 - true_positives_38: 2454.0000 - true_negatives_38: 1490.0000 - false_positives_38: 634.0000 - false_negatives_38: 740.0000 - 671ms/epoch - 4ms/step
# 2 - [2, 18]
# 166/166 - 1s - loss: 0.5153 - accuracy: 0.7355 - true_positives_39: 2535.0000 - true_negatives_39: 1369.0000 - false_positives_39: 715.0000 - false_negatives_39: 689.0000 - 546ms/epoch - 3ms/step
# 166/166 - 1s - loss: 0.5153 - accuracy: 0.7355 - true_positives_39: 2535.0000 - true_negatives_39: 1369.0000 - false_positives_39: 715.0000 - false_negatives_39: 689.0000 - 609ms/epoch - 4ms/step
# 2 - [6, 15]
# 166/166 - 1s - loss: 0.5185 - accuracy: 0.7337 - true_positives_40: 2286.0000 - true_negatives_40: 1599.0000 - false_positives_40: 631.0000 - false_negatives_40: 779.0000 - 660ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5185 - accuracy: 0.7337 - true_positives_40: 2286.0000 - true_negatives_40: 1599.0000 - false_positives_40: 631.0000 - false_negatives_40: 779.0000 - 682ms/epoch - 4ms/step
# 2 - [3, 21]
# 167/167 - 1s - loss: 0.5262 - accuracy: 0.7251 - true_positives_41: 2308.0000 - true_negatives_41: 1545.0000 - false_positives_41: 608.0000 - false_negatives_41: 853.0000 - 658ms/epoch - 4ms/step
# 167/167 - 1s - loss: 0.5262 - accuracy: 0.7251 - true_positives_41: 2308.0000 - true_negatives_41: 1545.0000 - false_positives_41: 608.0000 - false_negatives_41: 853.0000 - 664ms/epoch - 4ms/step
# 2 - [8, 21]
# 167/167 - 1s - loss: 0.5212 - accuracy: 0.7309 - true_positives_42: 2585.0000 - true_negatives_42: 1299.0000 - false_positives_42: 763.0000 - false_negatives_42: 667.0000 - 641ms/epoch - 4ms/step
# 167/167 - 1s - loss: 0.5212 - accuracy: 0.7309 - true_positives_42: 2585.0000 - true_negatives_42: 1299.0000 - false_positives_42: 763.0000 - false_negatives_42: 667.0000 - 723ms/epoch - 4ms/step
# 2 - [10, 3]
# 166/166 - 1s - loss: 0.5226 - accuracy: 0.7381 - true_positives_43: 2180.0000 - true_negatives_43: 1724.0000 - false_positives_43: 550.0000 - false_negatives_43: 835.0000 - 649ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5226 - accuracy: 0.7381 - true_positives_43: 2180.0000 - true_negatives_43: 1724.0000 - false_positives_43: 550.0000 - false_negatives_43: 835.0000 - 659ms/epoch - 4ms/step
# 2 - [1, 3]
# 166/166 - 1s - loss: 0.5205 - accuracy: 0.7391 - true_positives_44: 2213.0000 - true_negatives_44: 1703.0000 - false_positives_44: 588.0000 - false_negatives_44: 794.0000 - 627ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5205 - accuracy: 0.7391 - true_positives_44: 2213.0000 - true_negatives_44: 1703.0000 - false_positives_44: 588.0000 - false_negatives_44: 794.0000 - 638ms/epoch - 4ms/step
# 2 - [9, 19]
# 166/166 - 1s - loss: 0.5239 - accuracy: 0.7393 - true_positives_45: 2315.0000 - true_negatives_45: 1604.0000 - false_positives_45: 598.0000 - false_negatives_45: 784.0000 - 652ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5239 - accuracy: 0.7393 - true_positives_45: 2315.0000 - true_negatives_45: 1604.0000 - false_positives_45: 598.0000 - false_negatives_45: 784.0000 - 667ms/epoch - 4ms/step
# 2 - [17, 11]
# 166/166 - 1s - loss: 0.5197 - accuracy: 0.7371 - true_positives_46: 2359.0000 - true_negatives_46: 1552.0000 - false_positives_46: 626.0000 - false_negatives_46: 769.0000 - 805ms/epoch - 5ms/step
# 166/166 - 1s - loss: 0.5197 - accuracy: 0.7371 - true_positives_46: 2359.0000 - true_negatives_46: 1552.0000 - false_positives_46: 626.0000 - false_negatives_46: 769.0000 - 674ms/epoch - 4ms/step
# 2 - [10, 21]
# 167/167 - 1s - loss: 0.5300 - accuracy: 0.7250 - true_positives_47: 2348.0000 - true_negatives_47: 1504.0000 - false_positives_47: 708.0000 - false_negatives_47: 753.0000 - 639ms/epoch - 4ms/step
# 167/167 - 1s - loss: 0.5300 - accuracy: 0.7250 - true_positives_47: 2348.0000 - true_negatives_47: 1504.0000 - false_positives_47: 708.0000 - false_negatives_47: 753.0000 - 661ms/epoch - 4ms/step
# 2 - [16, 1]
# 166/166 - 1s - loss: 0.5270 - accuracy: 0.7328 - true_positives_48: 2150.0000 - true_negatives_48: 1730.0000 - false_positives_48: 604.0000 - false_negatives_48: 811.0000 - 617ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5270 - accuracy: 0.7328 - true_positives_48: 2150.0000 - true_negatives_48: 1730.0000 - false_positives_48: 604.0000 - false_negatives_48: 811.0000 - 550ms/epoch - 3ms/step
# 2 - [19, 20]
# 166/166 - 1s - loss: 0.5170 - accuracy: 0.7359 - true_positives_49: 2251.0000 - true_negatives_49: 1644.0000 - false_positives_49: 544.0000 - false_negatives_49: 854.0000 - 639ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5170 - accuracy: 0.7359 - true_positives_49: 2251.0000 - true_negatives_49: 1644.0000 - false_positives_49: 544.0000 - false_negatives_49: 854.0000 - 643ms/epoch - 4ms/step
# 2 - [8, 15]
# 166/166 - 1s - loss: 0.5194 - accuracy: 0.7334 - true_positives_50: 2500.0000 - true_negatives_50: 1381.0000 - false_positives_50: 700.0000 - false_negatives_50: 711.0000 - 712ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5194 - accuracy: 0.7334 - true_positives_50: 2500.0000 - true_negatives_50: 1381.0000 - false_positives_50: 700.0000 - false_negatives_50: 711.0000 - 669ms/epoch - 4ms/step
# 2 - [18, 12]
# 167/167 - 1s - loss: 0.5396 - accuracy: 0.7218 - true_positives_51: 2342.0000 - true_negatives_51: 1497.0000 - false_positives_51: 712.0000 - false_negatives_51: 768.0000 - 641ms/epoch - 4ms/step
# 167/167 - 1s - loss: 0.5396 - accuracy: 0.7218 - true_positives_51: 2342.0000 - true_negatives_51: 1497.0000 - false_positives_51: 712.0000 - false_negatives_51: 768.0000 - 650ms/epoch - 4ms/step
# 2 - [2, 3]
# 166/166 - 1s - loss: 0.5101 - accuracy: 0.7447 - true_positives_52: 2311.0000 - true_negatives_52: 1633.0000 - false_positives_52: 466.0000 - false_negatives_52: 886.0000 - 644ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5101 - accuracy: 0.7447 - true_positives_52: 2311.0000 - true_negatives_52: 1633.0000 - false_positives_52: 466.0000 - false_negatives_52: 886.0000 - 634ms/epoch - 4ms/step
# 2 - [16, 2]
# 166/166 - 1s - loss: 0.5132 - accuracy: 0.7364 - true_positives_53: 2430.0000 - true_negatives_53: 1468.0000 - false_positives_53: 674.0000 - false_negatives_53: 721.0000 - 744ms/epoch - 4ms/step
# 166/166 - 1s - loss: 0.5132 - accuracy: 0.7364 - true_positives_53: 2430.0000 - true_negatives_53: 1468.0000 - false_positives_53: 674.0000 - false_negatives_53: 721.0000 - 787ms/epoch - 5ms/step
# 2 - [5, 6]
# 158/158 - 1s - loss: 0.5168 - accuracy: 0.7390 - true_positives_54: 2046.0000 - true_negatives_54: 1688.0000 - false_positives_54: 483.0000 - false_negatives_54: 836.0000 - 749ms/epoch - 5ms/step
# 158/158 - 1s - loss: 0.5168 - accuracy: 0.7390 - true_positives_54: 2046.0000 - true_negatives_54: 1688.0000 - false_positives_54: 483.0000 - false_negatives_54: 836.0000 - 731ms/epoch - 5ms/step
# 3 - [2, 3, 21]
# 159/159 - 1s - loss: 0.5075 - accuracy: 0.7371 - true_positives_55: 2449.0000 - true_negatives_55: 1280.0000 - false_positives_55: 660.0000 - false_negatives_55: 670.0000 - 624ms/epoch - 4ms/step
# 159/159 - 1s - loss: 0.5075 - accuracy: 0.7371 - true_positives_55: 2449.0000 - true_negatives_55: 1280.0000 - false_positives_55: 660.0000 - false_negatives_55: 670.0000 - 611ms/epoch - 4ms/step
# 3 - [9, 2, 15]
# 158/158 - 1s - loss: 0.5027 - accuracy: 0.7432 - true_positives_56: 2500.0000 - true_negatives_56: 1254.0000 - false_positives_56: 628.0000 - false_negatives_56: 669.0000 - 702ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5027 - accuracy: 0.7432 - true_positives_56: 2500.0000 - true_negatives_56: 1254.0000 - false_positives_56: 628.0000 - false_negatives_56: 669.0000 - 732ms/epoch - 5ms/step
# 3 - [12, 20, 14]
# 159/159 - 1s - loss: 0.5259 - accuracy: 0.7303 - true_positives_57: 2280.0000 - true_negatives_57: 1425.0000 - false_positives_57: 628.0000 - false_negatives_57: 740.0000 - 734ms/epoch - 5ms/step
# 159/159 - 1s - loss: 0.5259 - accuracy: 0.7303 - true_positives_57: 2280.0000 - true_negatives_57: 1425.0000 - false_positives_57: 628.0000 - false_negatives_57: 740.0000 - 821ms/epoch - 5ms/step
# 3 - [1, 20, 17]
# 158/158 - 1s - loss: 0.5060 - accuracy: 0.7476 - true_positives_58: 2361.0000 - true_negatives_58: 1416.0000 - false_positives_58: 591.0000 - false_negatives_58: 684.0000 - 708ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5060 - accuracy: 0.7476 - true_positives_58: 2361.0000 - true_negatives_58: 1416.0000 - false_positives_58: 591.0000 - false_negatives_58: 684.0000 - 814ms/epoch - 5ms/step
# 3 - [1, 14, 7]
# 159/159 - 1s - loss: 0.5167 - accuracy: 0.7373 - true_positives_59: 2047.0000 - true_negatives_59: 1688.0000 - false_positives_59: 550.0000 - false_negatives_59: 781.0000 - 717ms/epoch - 5ms/step
# 159/159 - 1s - loss: 0.5167 - accuracy: 0.7373 - true_positives_59: 2047.0000 - true_negatives_59: 1688.0000 - false_positives_59: 550.0000 - false_negatives_59: 781.0000 - 581ms/epoch - 4ms/step
# 3 - [16, 19, 12]
# 158/158 - 1s - loss: 0.5405 - accuracy: 0.7242 - true_positives_60: 1896.0000 - true_negatives_60: 1754.0000 - false_positives_60: 480.0000 - false_negatives_60: 910.0000 - 584ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5405 - accuracy: 0.7242 - true_positives_60: 1896.0000 - true_negatives_60: 1754.0000 - false_positives_60: 480.0000 - false_negatives_60: 910.0000 - 576ms/epoch - 4ms/step
# 3 - [20, 12, 13]
# 159/159 - 1s - loss: 0.5280 - accuracy: 0.7314 - true_positives_61: 2276.0000 - true_negatives_61: 1433.0000 - false_positives_61: 608.0000 - false_negatives_61: 754.0000 - 716ms/epoch - 5ms/step
# 159/159 - 1s - loss: 0.5280 - accuracy: 0.7314 - true_positives_61: 2276.0000 - true_negatives_61: 1433.0000 - false_positives_61: 608.0000 - false_negatives_61: 754.0000 - 809ms/epoch - 5ms/step
# 3 - [8, 21, 5]
# 151/151 - 1s - loss: 0.5187 - accuracy: 0.7330 - true_positives_62: 2304.0000 - true_negatives_62: 1224.0000 - false_positives_62: 639.0000 - false_negatives_62: 646.0000 - 589ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5187 - accuracy: 0.7330 - true_positives_62: 2304.0000 - true_negatives_62: 1224.0000 - false_positives_62: 639.0000 - false_negatives_62: 646.0000 - 601ms/epoch - 4ms/step
# 3 - [16, 19, 14]
# 158/158 - 1s - loss: 0.5279 - accuracy: 0.7335 - true_positives_63: 2013.0000 - true_negatives_63: 1687.0000 - false_positives_63: 555.0000 - false_negatives_63: 789.0000 - 648ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5279 - accuracy: 0.7335 - true_positives_63: 2013.0000 - true_negatives_63: 1687.0000 - false_positives_63: 555.0000 - false_negatives_63: 789.0000 - 638ms/epoch - 4ms/step
# 3 - [19, 13, 15]
# 158/158 - 1s - loss: 0.5327 - accuracy: 0.7246 - true_positives_64: 2104.0000 - true_negatives_64: 1553.0000 - false_positives_64: 591.0000 - false_negatives_64: 799.0000 - 853ms/epoch - 5ms/step
# 158/158 - 1s - loss: 0.5327 - accuracy: 0.7246 - true_positives_64: 2104.0000 - true_negatives_64: 1553.0000 - false_positives_64: 591.0000 - false_negatives_64: 799.0000 - 641ms/epoch - 4ms/step
# 3 - [3, 5, 15]
# 150/150 - 1s - loss: 0.5225 - accuracy: 0.7337 - true_positives_65: 2106.0000 - true_negatives_65: 1409.0000 - false_positives_65: 564.0000 - false_negatives_65: 712.0000 - 571ms/epoch - 4ms/step
# 150/150 - 1s - loss: 0.5225 - accuracy: 0.7337 - true_positives_65: 2106.0000 - true_negatives_65: 1409.0000 - false_positives_65: 564.0000 - false_negatives_65: 712.0000 - 583ms/epoch - 4ms/step
# 3 - [9, 18, 20]
# 159/159 - 1s - loss: 0.5155 - accuracy: 0.7402 - true_positives_66: 2436.0000 - true_negatives_66: 1310.0000 - false_positives_66: 625.0000 - false_negatives_66: 690.0000 - 633ms/epoch - 4ms/step
# 159/159 - 1s - loss: 0.5155 - accuracy: 0.7402 - true_positives_66: 2436.0000 - true_negatives_66: 1310.0000 - false_positives_66: 625.0000 - false_negatives_66: 690.0000 - 663ms/epoch - 4ms/step
# 3 - [12, 14, 15]
# 159/159 - 1s - loss: 0.5378 - accuracy: 0.7191 - true_positives_67: 2222.0000 - true_negatives_67: 1423.0000 - false_positives_67: 678.0000 - false_negatives_67: 746.0000 - 674ms/epoch - 4ms/step
# 159/159 - 1s - loss: 0.5378 - accuracy: 0.7191 - true_positives_67: 2222.0000 - true_negatives_67: 1423.0000 - false_positives_67: 678.0000 - false_negatives_67: 746.0000 - 611ms/epoch - 4ms/step
# 3 - [19, 3, 13]
# 158/158 - 1s - loss: 0.5294 - accuracy: 0.7348 - true_positives_68: 2011.0000 - true_negatives_68: 1696.0000 - false_positives_68: 491.0000 - false_negatives_68: 847.0000 - 756ms/epoch - 5ms/step
# 158/158 - 1s - loss: 0.5294 - accuracy: 0.7348 - true_positives_68: 2011.0000 - true_negatives_68: 1696.0000 - false_positives_68: 491.0000 - false_negatives_68: 847.0000 - 644ms/epoch - 4ms/step
# 3 - [1, 4, 20]
# 151/151 - 1s - loss: 0.5230 - accuracy: 0.7331 - true_positives_69: 2054.0000 - true_negatives_69: 1467.0000 - false_positives_69: 540.0000 - false_negatives_69: 742.0000 - 602ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5230 - accuracy: 0.7331 - true_positives_69: 2054.0000 - true_negatives_69: 1467.0000 - false_positives_69: 540.0000 - false_negatives_69: 742.0000 - 705ms/epoch - 5ms/step
# 3 - [10, 20, 7]
# 158/158 - 1s - loss: 0.5094 - accuracy: 0.7378 - true_positives_70: 2192.0000 - true_negatives_70: 1528.0000 - false_positives_70: 585.0000 - false_negatives_70: 737.0000 - 659ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5094 - accuracy: 0.7378 - true_positives_70: 2192.0000 - true_negatives_70: 1528.0000 - false_positives_70: 585.0000 - false_negatives_70: 737.0000 - 609ms/epoch - 4ms/step
# 3 - [18, 11, 5]
# 151/151 - 1s - loss: 0.5285 - accuracy: 0.7302 - true_positives_71: 2038.0000 - true_negatives_71: 1473.0000 - false_positives_71: 587.0000 - false_negatives_71: 710.0000 - 620ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5285 - accuracy: 0.7302 - true_positives_71: 2038.0000 - true_negatives_71: 1473.0000 - false_positives_71: 587.0000 - false_negatives_71: 710.0000 - 591ms/epoch - 4ms/step
# 3 - [1, 20, 7]
# 158/158 - 1s - loss: 0.5112 - accuracy: 0.7359 - true_positives_72: 2183.0000 - true_negatives_72: 1534.0000 - false_positives_72: 596.0000 - false_negatives_72: 738.0000 - 803ms/epoch - 5ms/step
# 158/158 - 1s - loss: 0.5112 - accuracy: 0.7359 - true_positives_72: 2183.0000 - true_negatives_72: 1534.0000 - false_positives_72: 596.0000 - false_negatives_72: 738.0000 - 690ms/epoch - 4ms/step
# 3 - [2, 18, 5]
# 151/151 - 1s - loss: 0.5100 - accuracy: 0.7366 - true_positives_73: 2280.0000 - true_negatives_73: 1261.0000 - false_positives_73: 624.0000 - false_negatives_73: 642.0000 - 610ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5100 - accuracy: 0.7366 - true_positives_73: 2280.0000 - true_negatives_73: 1261.0000 - false_positives_73: 624.0000 - false_negatives_73: 642.0000 - 699ms/epoch - 5ms/step
# 3 - [8, 12, 7]
# 158/158 - 1s - loss: 0.5229 - accuracy: 0.7362 - true_positives_74: 2277.0000 - true_negatives_74: 1444.0000 - false_positives_74: 619.0000 - false_negatives_74: 714.0000 - 739ms/epoch - 5ms/step
# 158/158 - 1s - loss: 0.5229 - accuracy: 0.7362 - true_positives_74: 2277.0000 - true_negatives_74: 1444.0000 - false_positives_74: 619.0000 - false_negatives_74: 714.0000 - 784ms/epoch - 5ms/step
# 3 - [18, 19, 21]
# 159/159 - 1s - loss: 0.5370 - accuracy: 0.7203 - true_positives_75: 2166.0000 - true_negatives_75: 1480.0000 - false_positives_75: 625.0000 - false_negatives_75: 791.0000 - 724ms/epoch - 5ms/step
# 159/159 - 1s - loss: 0.5370 - accuracy: 0.7203 - true_positives_75: 2166.0000 - true_negatives_75: 1480.0000 - false_positives_75: 625.0000 - false_negatives_75: 791.0000 - 781ms/epoch - 5ms/step
# 3 - [8, 11, 12]
# 158/158 - 1s - loss: 0.5277 - accuracy: 0.7336 - true_positives_76: 2231.0000 - true_negatives_76: 1476.0000 - false_positives_76: 619.0000 - false_negatives_76: 727.0000 - 818ms/epoch - 5ms/step
# 158/158 - 1s - loss: 0.5277 - accuracy: 0.7336 - true_positives_76: 2231.0000 - true_negatives_76: 1476.0000 - false_positives_76: 619.0000 - false_negatives_76: 727.0000 - 674ms/epoch - 4ms/step
# 3 - [18, 20, 14]
# 159/159 - 1s - loss: 0.5186 - accuracy: 0.7358 - true_positives_77: 2348.0000 - true_negatives_77: 1381.0000 - false_positives_77: 648.0000 - false_negatives_77: 691.0000 - 633ms/epoch - 4ms/step
# 159/159 - 1s - loss: 0.5186 - accuracy: 0.7358 - true_positives_77: 2348.0000 - true_negatives_77: 1381.0000 - false_positives_77: 648.0000 - false_negatives_77: 691.0000 - 635ms/epoch - 4ms/step
# 3 - [21, 12, 5]
# 151/151 - 1s - loss: 0.5398 - accuracy: 0.7182 - true_positives_78: 2118.0000 - true_negatives_78: 1351.0000 - false_positives_78: 612.0000 - false_negatives_78: 749.0000 - 576ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5398 - accuracy: 0.7182 - true_positives_78: 2118.0000 - true_negatives_78: 1351.0000 - false_positives_78: 612.0000 - false_negatives_78: 749.0000 - 652ms/epoch - 4ms/step
# 3 - [17, 11, 6]
# 158/158 - 1s - loss: 0.5075 - accuracy: 0.7530 - true_positives_79: 2197.0000 - true_negatives_79: 1604.0000 - false_positives_79: 535.0000 - false_negatives_79: 712.0000 - 682ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5075 - accuracy: 0.7530 - true_positives_79: 2197.0000 - true_negatives_79: 1604.0000 - false_positives_79: 535.0000 - false_negatives_79: 712.0000 - 631ms/epoch - 4ms/step
# 3 - [16, 1, 10]
# 158/158 - 1s - loss: 0.5277 - accuracy: 0.7320 - true_positives_80: 1940.0000 - true_negatives_80: 1744.0000 - false_positives_80: 552.0000 - false_negatives_80: 797.0000 - 641ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5277 - accuracy: 0.7320 - true_positives_80: 1940.0000 - true_negatives_80: 1744.0000 - false_positives_80: 552.0000 - false_negatives_80: 797.0000 - 678ms/epoch - 4ms/step
# 3 - [1, 17, 15]
# 158/158 - 1s - loss: 0.5191 - accuracy: 0.7345 - true_positives_81: 2378.0000 - true_negatives_81: 1330.0000 - false_positives_81: 725.0000 - false_negatives_81: 615.0000 - 769ms/epoch - 5ms/step
# 158/158 - 1s - loss: 0.5191 - accuracy: 0.7345 - true_positives_81: 2378.0000 - true_negatives_81: 1330.0000 - false_positives_81: 725.0000 - false_negatives_81: 615.0000 - 654ms/epoch - 4ms/step
# 3 - [12, 21, 15]
# 159/159 - 1s - loss: 0.5385 - accuracy: 0.7127 - true_positives_82: 2245.0000 - true_negatives_82: 1370.0000 - false_positives_82: 652.0000 - false_negatives_82: 805.0000 - 617ms/epoch - 4ms/step
# 159/159 - 1s - loss: 0.5385 - accuracy: 0.7127 - true_positives_82: 2245.0000 - true_negatives_82: 1370.0000 - false_positives_82: 652.0000 - false_negatives_82: 805.0000 - 616ms/epoch - 4ms/step
# 3 - [15, 20, 7]
# 158/158 - 1s - loss: 0.5066 - accuracy: 0.7378 - true_positives_83: 2314.0000 - true_negatives_83: 1408.0000 - false_positives_83: 603.0000 - false_negatives_83: 720.0000 - 588ms/epoch - 4ms/step
# 158/158 - 1s - loss: 0.5066 - accuracy: 0.7378 - true_positives_83: 2314.0000 - true_negatives_83: 1408.0000 - false_positives_83: 603.0000 - false_negatives_83: 720.0000 - 584ms/epoch - 4ms/step
# 3 - [1, 10, 12]
# 158/158 - 1s - loss: 0.5357 - accuracy: 0.7241 - true_positives_84: 2070.0000 - true_negatives_84: 1589.0000 - false_positives_84: 673.0000 - false_negatives_84: 721.0000 - 715ms/epoch - 5ms/step
# 158/158 - 1s - loss: 0.5357 - accuracy: 0.7241 - true_positives_84: 2070.0000 - true_negatives_84: 1589.0000 - false_positives_84: 673.0000 - false_negatives_84: 721.0000 - 752ms/epoch - 5ms/step
# 4 - [9, 3, 20, 6]
# 150/150 - 1s - loss: 0.4946 - accuracy: 0.7575 - true_positives_85: 2166.0000 - true_negatives_85: 1463.0000 - false_positives_85: 448.0000 - false_negatives_85: 714.0000 - 666ms/epoch - 4ms/step
# 150/150 - 1s - loss: 0.4946 - accuracy: 0.7575 - true_positives_85: 2166.0000 - true_negatives_85: 1463.0000 - false_positives_85: 448.0000 - false_negatives_85: 714.0000 - 688ms/epoch - 5ms/step
# 4 - [19, 3, 13, 7]
# 150/150 - 1s - loss: 0.5199 - accuracy: 0.7412 - true_positives_86: 1917.0000 - true_negatives_86: 1635.0000 - false_positives_86: 482.0000 - false_negatives_86: 758.0000 - 642ms/epoch - 4ms/step
# 150/150 - 1s - loss: 0.5199 - accuracy: 0.7412 - true_positives_86: 1917.0000 - true_negatives_86: 1635.0000 - false_positives_86: 482.0000 - false_negatives_86: 758.0000 - 645ms/epoch - 4ms/step
# 4 - [8, 17, 10, 7]
# 150/150 - 1s - loss: 0.5062 - accuracy: 0.7521 - true_positives_87: 2238.0000 - true_negatives_87: 1360.0000 - false_positives_87: 560.0000 - false_negatives_87: 626.0000 - 628ms/epoch - 4ms/step
# 150/150 - 1s - loss: 0.5062 - accuracy: 0.7521 - true_positives_87: 2238.0000 - true_negatives_87: 1360.0000 - false_positives_87: 560.0000 - false_negatives_87: 626.0000 - 756ms/epoch - 5ms/step
# 4 - [17, 2, 10, 15]
# 150/150 - 1s - loss: 0.5006 - accuracy: 0.7437 - true_positives_88: 2353.0000 - true_negatives_88: 1205.0000 - false_positives_88: 620.0000 - false_negatives_88: 606.0000 - 701ms/epoch - 5ms/step
# 150/150 - 1s - loss: 0.5006 - accuracy: 0.7437 - true_positives_88: 2353.0000 - true_negatives_88: 1205.0000 - false_positives_88: 620.0000 - false_negatives_88: 606.0000 - 711ms/epoch - 5ms/step
# 4 - [1, 18, 17, 7]
# 151/151 - 1s - loss: 0.5161 - accuracy: 0.7396 - true_positives_89: 2126.0000 - true_negatives_89: 1428.0000 - false_positives_89: 585.0000 - false_negatives_89: 666.0000 - 676ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5161 - accuracy: 0.7396 - true_positives_89: 2126.0000 - true_negatives_89: 1428.0000 - false_positives_89: 585.0000 - false_negatives_89: 666.0000 - 716ms/epoch - 5ms/step
# 4 - [18, 1, 2, 11]
# 151/151 - 1s - loss: 0.5116 - accuracy: 0.7386 - true_positives_90: 2136.0000 - true_negatives_90: 1410.0000 - false_positives_90: 615.0000 - false_negatives_90: 640.0000 - 608ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5116 - accuracy: 0.7386 - true_positives_90: 2136.0000 - true_negatives_90: 1410.0000 - false_positives_90: 615.0000 - false_negatives_90: 640.0000 - 707ms/epoch - 5ms/step
# 4 - [1, 15, 13, 7]
# 151/151 - 1s - loss: 0.5229 - accuracy: 0.7315 - true_positives_91: 1999.0000 - true_negatives_91: 1516.0000 - false_positives_91: 570.0000 - false_negatives_91: 720.0000 - 696ms/epoch - 5ms/step
# 151/151 - 1s - loss: 0.5229 - accuracy: 0.7315 - true_positives_91: 1999.0000 - true_negatives_91: 1516.0000 - false_positives_91: 570.0000 - false_negatives_91: 720.0000 - 736ms/epoch - 5ms/step
# 4 - [9, 19, 6, 17]
# 150/150 - 1s - loss: 0.5057 - accuracy: 0.7474 - true_positives_92: 2078.0000 - true_negatives_92: 1503.0000 - false_positives_92: 467.0000 - false_negatives_92: 743.0000 - 543ms/epoch - 4ms/step
# 150/150 - 1s - loss: 0.5057 - accuracy: 0.7474 - true_positives_92: 2078.0000 - true_negatives_92: 1503.0000 - false_positives_92: 467.0000 - false_negatives_92: 743.0000 - 582ms/epoch - 4ms/step
# 4 - [1, 2, 12, 14]
# 151/151 - 1s - loss: 0.5215 - accuracy: 0.7299 - true_positives_93: 2160.0000 - true_negatives_93: 1358.0000 - false_positives_93: 649.0000 - false_negatives_93: 653.0000 - 708ms/epoch - 5ms/step
# 151/151 - 1s - loss: 0.5215 - accuracy: 0.7299 - true_positives_93: 2160.0000 - true_negatives_93: 1358.0000 - false_positives_93: 649.0000 - false_negatives_93: 653.0000 - 713ms/epoch - 5ms/step
# 4 - [17, 21, 13, 15]
# 151/151 - 1s - loss: 0.5257 - accuracy: 0.7250 - true_positives_94: 2386.0000 - true_negatives_94: 1110.0000 - false_positives_94: 715.0000 - false_negatives_94: 611.0000 - 592ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5257 - accuracy: 0.7250 - true_positives_94: 2386.0000 - true_negatives_94: 1110.0000 - false_positives_94: 715.0000 - false_negatives_94: 611.0000 - 587ms/epoch - 4ms/step
# 4 - [19, 9, 2, 11]
# 150/150 - 1s - loss: 0.5007 - accuracy: 0.7494 - true_positives_95: 2136.0000 - true_negatives_95: 1455.0000 - false_positives_95: 496.0000 - false_negatives_95: 705.0000 - 581ms/epoch - 4ms/step
# 150/150 - 1s - loss: 0.5007 - accuracy: 0.7494 - true_positives_95: 2136.0000 - true_negatives_95: 1455.0000 - false_positives_95: 496.0000 - false_negatives_95: 705.0000 - 740ms/epoch - 5ms/step
# 4 - [8, 17, 2, 20]
# 150/150 - 1s - loss: 0.4722 - accuracy: 0.7653 - true_positives_96: 2717.0000 - true_negatives_96: 948.0000 - false_positives_96: 679.0000 - false_negatives_96: 445.0000 - 682ms/epoch - 5ms/step
# 150/150 - 1s - loss: 0.4722 - accuracy: 0.7653 - true_positives_96: 2717.0000 - true_negatives_96: 948.0000 - false_positives_96: 679.0000 - false_negatives_96: 445.0000 - 716ms/epoch - 5ms/step
# 4 - [1, 18, 3, 21]
# 151/151 - 1s - loss: 0.5267 - accuracy: 0.7290 - true_positives_97: 2126.0000 - true_negatives_97: 1382.0000 - false_positives_97: 638.0000 - false_negatives_97: 666.0000 - 715ms/epoch - 5ms/step
# 151/151 - 1s - loss: 0.5267 - accuracy: 0.7290 - true_positives_97: 2126.0000 - true_negatives_97: 1382.0000 - false_positives_97: 638.0000 - false_negatives_97: 666.0000 - 720ms/epoch - 5ms/step
# 4 - [8, 9, 20, 17]
# 150/150 - 1s - loss: 0.4890 - accuracy: 0.7584 - true_positives_98: 2649.0000 - true_negatives_98: 989.0000 - false_positives_98: 677.0000 - false_negatives_98: 482.0000 - 682ms/epoch - 5ms/step
# 150/150 - 1s - loss: 0.4890 - accuracy: 0.7584 - true_positives_98: 2649.0000 - true_negatives_98: 989.0000 - false_positives_98: 677.0000 - false_negatives_98: 482.0000 - 707ms/epoch - 5ms/step
# 4 - [17, 21, 13, 14]
# 152/152 - 1s - loss: 0.5241 - accuracy: 0.7296 - true_positives_99: 2317.0000 - true_negatives_99: 1215.0000 - false_positives_99: 670.0000 - false_negatives_99: 639.0000 - 571ms/epoch - 4ms/step
# 152/152 - 1s - loss: 0.5241 - accuracy: 0.7296 - true_positives_99: 2317.0000 - true_negatives_99: 1215.0000 - false_positives_99: 670.0000 - false_negatives_99: 639.0000 - 637ms/epoch - 4ms/step
# 4 - [19, 10, 3, 7]
# 150/150 - 1s - loss: 0.5135 - accuracy: 0.7473 - true_positives_100: 1882.0000 - true_negatives_100: 1684.0000 - false_positives_100: 487.0000 - false_negatives_100: 719.0000 - 687ms/epoch - 5ms/step
# 150/150 - 1s - loss: 0.5135 - accuracy: 0.7473 - true_positives_100: 1882.0000 - true_negatives_100: 1684.0000 - false_positives_100: 487.0000 - false_negatives_100: 719.0000 - 710ms/epoch - 5ms/step
# 4 - [8, 9, 11, 7]
# 150/150 - 1s - loss: 0.5032 - accuracy: 0.7498 - true_positives_101: 2190.0000 - true_negatives_101: 1407.0000 - false_positives_101: 532.0000 - false_negatives_101: 668.0000 - 703ms/epoch - 5ms/step
# 150/150 - 1s - loss: 0.5032 - accuracy: 0.7498 - true_positives_101: 2190.0000 - true_negatives_101: 1407.0000 - false_positives_101: 532.0000 - false_negatives_101: 668.0000 - 741ms/epoch - 5ms/step
# 4 - [17, 10, 4, 6]
# 142/142 - 1s - loss: 0.5159 - accuracy: 0.7376 - true_positives_102: 1887.0000 - true_negatives_102: 1461.0000 - false_positives_102: 485.0000 - false_negatives_102: 706.0000 - 592ms/epoch - 4ms/step
# 142/142 - 1s - loss: 0.5159 - accuracy: 0.7376 - true_positives_102: 1887.0000 - true_negatives_102: 1461.0000 - false_positives_102: 485.0000 - false_negatives_102: 706.0000 - 573ms/epoch - 4ms/step
# 4 - [11, 9, 3, 21]
# 151/151 - 1s - loss: 0.5158 - accuracy: 0.7365 - true_positives_103: 2146.0000 - true_negatives_103: 1399.0000 - false_positives_103: 542.0000 - false_negatives_103: 726.0000 - 668ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5158 - accuracy: 0.7365 - true_positives_103: 2146.0000 - true_negatives_103: 1399.0000 - false_positives_103: 542.0000 - false_negatives_103: 726.0000 - 721ms/epoch - 5ms/step
# 4 - [17, 12, 20, 7]
# 151/151 - 1s - loss: 0.5088 - accuracy: 0.7404 - true_positives_104: 2263.0000 - true_negatives_104: 1297.0000 - false_positives_104: 573.0000 - false_negatives_104: 675.0000 - 669ms/epoch - 4ms/step
# 151/151 - 1s - loss: 0.5088 - accuracy: 0.7404 - true_positives_104: 2263.0000 - true_negatives_104: 1297.0000 - false_positives_104: 573.0000 - false_negatives_104: 675.0000 - 669ms/epoch - 4ms/step
# 4 - [17, 20, 5, 15]
# 143/143 - 1s - loss: 0.5008 - accuracy: 0.7430 - true_positives_105: 2243.0000 - true_negatives_105: 1134.0000 - false_positives_105: 555.0000 - false_negatives_105: 613.0000 - 516ms/epoch - 4ms/step
# 143/143 - 1s - loss: 0.5008 - accuracy: 0.7430 - true_positives_105: 2243.0000 - true_negatives_105: 1134.0000 - false_positives_105: 555.0000 - false_negatives_105: 613.0000 - 575ms/epoch - 4ms/step
# 4 - [2, 5, 6, 15]
# 142/142 - 1s - loss: 0.4939 - accuracy: 0.7484 - true_positives_106: 2053.0000 - true_negatives_106: 1344.0000 - false_positives_106: 474.0000 - false_negatives_106: 668.0000 - 623ms/epoch - 4ms/step
# 142/142 - 1s - loss: 0.4939 - accuracy: 0.7484 - true_positives_106: 2053.0000 - true_negatives_106: 1344.0000 - false_positives_106: 474.0000 - false_negatives_106: 668.0000 - 717ms/epoch - 5ms/step
# 4 - [16, 9, 21, 5]
# 143/143 - 1s - loss: 0.5280 - accuracy: 0.7267 - true_positives_107: 2159.0000 - true_negatives_107: 1157.0000 - false_positives_107: 666.0000 - false_negatives_107: 581.0000 - 583ms/epoch - 4ms/step
# 143/143 - 1s - loss: 0.5280 - accuracy: 0.7267 - true_positives_107: 2159.0000 - true_negatives_107: 1157.0000 - false_positives_107: 666.0000 - false_negatives_107: 581.0000 - 662ms/epoch - 5ms/step
# 4 - [17, 20, 21, 14]
# 151/151 - 1s - loss: 0.5061 - accuracy: 0.7386 - true_positives_108: 2511.0000 - true_negatives_108: 1055.0000 - false_positives_108: 734.0000 - false_negatives_108: 528.0000 - 694ms/epoch - 5ms/step
# 151/151 - 1s - loss: 0.5061 - accuracy: 0.7386 - true_positives_108: 2511.0000 - true_negatives_108: 1055.0000 - false_positives_108: 734.0000 - false_negatives_108: 528.0000 - 754ms/epoch - 5ms/step
# 4 - [1, 18, 3, 15]
# 150/150 - 1s - loss: 0.5272 - accuracy: 0.7280 - true_positives_109: 2072.0000 - true_negatives_109: 1415.0000 - false_positives_109: 624.0000 - false_negatives_109: 679.0000 - 690ms/epoch - 5ms/step
# 150/150 - 1s - loss: 0.5272 - accuracy: 0.7280 - true_positives_109: 2072.0000 - true_negatives_109: 1415.0000 - false_positives_109: 624.0000 - false_negatives_109: 679.0000 - 732ms/epoch - 5ms/step
# 4 - [19, 11, 12, 7]
# 150/150 - 1s - loss: 0.5281 - accuracy: 0.7280 - true_positives_110: 1824.0000 - true_negatives_110: 1668.0000 - false_positives_110: 512.0000 - false_negatives_110: 793.0000 - 651ms/epoch - 4ms/step
# 150/150 - 1s - loss: 0.5281 - accuracy: 0.7280 - true_positives_110: 1824.0000 - true_negatives_110: 1668.0000 - false_positives_110: 512.0000 - false_negatives_110: 793.0000 - 744ms/epoch - 5ms/step
# 4 - [13, 21, 5, 14]
# 144/144 - 1s - loss: 0.5380 - accuracy: 0.7234 - true_positives_111: 2055.0000 - true_negatives_111: 1267.0000 - false_positives_111: 612.0000 - false_negatives_111: 658.0000 - 533ms/epoch - 4ms/step
# 144/144 - 1s - loss: 0.5380 - accuracy: 0.7234 - true_positives_111: 2055.0000 - true_negatives_111: 1267.0000 - false_positives_111: 612.0000 - false_negatives_111: 658.0000 - 667ms/epoch - 5ms/step
# 4 - [8, 16, 2, 13]
# 150/150 - 1s - loss: 0.5085 - accuracy: 0.7445 - true_positives_112: 2299.0000 - true_negatives_112: 1267.0000 - false_positives_112: 595.0000 - false_negatives_112: 629.0000 - 720ms/epoch - 5ms/step
# 150/150 - 1s - loss: 0.5085 - accuracy: 0.7445 - true_positives_112: 2299.0000 - true_negatives_112: 1267.0000 - false_positives_112: 595.0000 - false_negatives_112: 629.0000 - 754ms/epoch - 5ms/step
# 4 - [16, 18, 4, 14]
# 143/143 - 1s - loss: 0.5393 - accuracy: 0.7229 - true_positives_113: 1934.0000 - true_negatives_113: 1361.0000 - false_positives_113: 609.0000 - false_negatives_113: 654.0000 - 656ms/epoch - 5ms/step
# 143/143 - 1s - loss: 0.5393 - accuracy: 0.7229 - true_positives_113: 1934.0000 - true_negatives_113: 1361.0000 - false_positives_113: 609.0000 - false_negatives_113: 654.0000 - 686ms/epoch - 5ms/step
# 4 - [10, 3, 14, 15]
# 150/150 - 1s - loss: 0.5262 - accuracy: 0.7330 - true_positives_114: 2000.0000 - true_negatives_114: 1511.0000 - false_positives_114: 543.0000 - false_negatives_114: 736.0000 - 675ms/epoch - 4ms/step
# 150/150 - 1s - loss: 0.5262 - accuracy: 0.7330 - true_positives_114: 2000.0000 - true_negatives_114: 1511.0000 - false_positives_114: 543.0000 - false_negatives_114: 736.0000 - 744ms/epoch - 5ms/step
# 5 - [1, 2, 5, 14, 16]
# 135/135 - 1s - loss: 0.5106 - accuracy: 0.7406 - true_positives_115: 1878.0000 - true_negatives_115: 1306.0000 - false_positives_115: 536.0000 - false_negatives_115: 579.0000 - 526ms/epoch - 4ms/step
# 135/135 - 1s - loss: 0.5106 - accuracy: 0.7406 - true_positives_115: 1878.0000 - true_negatives_115: 1306.0000 - false_positives_115: 536.0000 - false_negatives_115: 579.0000 - 524ms/epoch - 4ms/step
# 5 - [1, 11, 16, 19, 21]
# 142/142 - 1s - loss: 0.5266 - accuracy: 0.7267 - true_positives_116: 1760.0000 - true_negatives_116: 1539.0000 - false_positives_116: 565.0000 - false_negatives_116: 676.0000 - 557ms/epoch - 4ms/step
# 142/142 - 1s - loss: 0.5266 - accuracy: 0.7267 - true_positives_116: 1760.0000 - true_negatives_116: 1539.0000 - false_positives_116: 565.0000 - false_negatives_116: 676.0000 - 677ms/epoch - 5ms/step
# 5 - [1, 5, 7, 12, 15]
# 135/135 - 1s - loss: 0.5280 - accuracy: 0.7304 - true_positives_117: 1703.0000 - true_negatives_117: 1439.0000 - false_positives_117: 452.0000 - false_negatives_117: 708.0000 - 535ms/epoch - 4ms/step
# 135/135 - 1s - loss: 0.5280 - accuracy: 0.7304 - true_positives_117: 1703.0000 - true_negatives_117: 1439.0000 - false_positives_117: 452.0000 - false_negatives_117: 708.0000 - 518ms/epoch - 4ms/step
# 5 - [2, 3, 4, 17, 18]
# 135/135 - 1s - loss: 0.5019 - accuracy: 0.7466 - true_positives_118: 2166.0000 - true_negatives_118: 1040.0000 - false_positives_118: 561.0000 - false_negatives_118: 527.0000 - 513ms/epoch - 4ms/step
# 135/135 - 1s - loss: 0.5019 - accuracy: 0.7466 - true_positives_118: 2166.0000 - true_negatives_118: 1040.0000 - false_positives_118: 561.0000 - false_negatives_118: 527.0000 - 505ms/epoch - 4ms/step
# 5 - [4, 6, 10, 11, 21]
# 135/135 - 1s - loss: 0.5214 - accuracy: 0.7370 - true_positives_119: 1636.0000 - true_negatives_119: 1533.0000 - false_positives_119: 409.0000 - false_negatives_119: 722.0000 - 638ms/epoch - 5ms/step
# 135/135 - 1s - loss: 0.5214 - accuracy: 0.7370 - true_positives_119: 1636.0000 - true_negatives_119: 1533.0000 - false_positives_119: 409.0000 - false_negatives_119: 722.0000 - 525ms/epoch - 4ms/step
# 5 - [2, 6, 7, 8, 21]
# 143/143 - 1s - loss: 0.4916 - accuracy: 0.7474 - true_positives_120: 2159.0000 - true_negatives_120: 1240.0000 - false_positives_120: 500.0000 - false_negatives_120: 649.0000 - 676ms/epoch - 5ms/step
# 143/143 - 1s - loss: 0.4916 - accuracy: 0.7474 - true_positives_120: 2159.0000 - true_negatives_120: 1240.0000 - false_positives_120: 500.0000 - false_negatives_120: 649.0000 - 682ms/epoch - 5ms/step
# 5 - [13, 14, 17, 19, 21]
# 144/144 - 1s - loss: 0.5266 - accuracy: 0.7319 - true_positives_121: 2123.0000 - true_negatives_121: 1227.0000 - false_positives_121: 625.0000 - false_negatives_121: 602.0000 - 554ms/epoch - 4ms/step
# 144/144 - 1s - loss: 0.5266 - accuracy: 0.7319 - true_positives_121: 2123.0000 - true_negatives_121: 1227.0000 - false_positives_121: 625.0000 - false_negatives_121: 602.0000 - 647ms/epoch - 4ms/step
# 5 - [5, 7, 8, 17, 18]
# 135/135 - 1s - loss: 0.5106 - accuracy: 0.7363 - true_positives_122: 2131.0000 - true_negatives_122: 1032.0000 - false_positives_122: 615.0000 - false_negatives_122: 518.0000 - 617ms/epoch - 5ms/step
# 135/135 - 1s - loss: 0.5106 - accuracy: 0.7363 - true_positives_122: 2131.0000 - true_negatives_122: 1032.0000 - false_positives_122: 615.0000 - false_negatives_122: 518.0000 - 653ms/epoch - 5ms/step
# 5 - [9, 12, 15, 18, 20]
# ...
# 112/112 - 0s - loss: 0.5180 - accuracy: 0.7319 - true_positives_176: 1638.0000 - true_negatives_176: 967.0000 - false_positives_176: 459.0000 - false_negatives_176: 495.0000 - 480ms/epoch - 4ms/step
# 7 - [5, 6, 9, 10, 11, 12, 14]
# 119/119 - 1s - loss: 0.5201 - accuracy: 0.7396 - true_positives_177: 1412.0000 - true_negatives_177: 1403.0000 - false_positives_177: 350.0000 - false_negatives_177: 641.0000 - 501ms/epoch - 4ms/step
# 119/119 - 1s - loss: 0.5201 - accuracy: 0.7396 - true_positives_177: 1412.0000 - true_negatives_177: 1403.0000 - false_positives_177: 350.0000 - false_negatives_177: 641.0000 - 559ms/epoch - 5ms/step
# 7 - [2, 5, 6, 16, 19, 20, 21]
# 119/119 - 0s - loss: 0.4786 - accuracy: 0.7549 - true_positives_178: 1688.0000 - true_negatives_178: 1164.0000 - false_positives_178: 360.0000 - false_negatives_178: 566.0000 - 447ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.4786 - accuracy: 0.7549 - true_positives_178: 1688.0000 - true_negatives_178: 1164.0000 - false_positives_178: 360.0000 - false_negatives_178: 566.0000 - 452ms/epoch - 4ms/step
# 7 - [2, 4, 11, 12, 13, 17, 19]
# 119/119 - 0s - loss: 0.5252 - accuracy: 0.7350 - true_positives_179: 1635.0000 - true_negatives_179: 1158.0000 - false_positives_179: 401.0000 - false_negatives_179: 606.0000 - 469ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.5252 - accuracy: 0.7350 - true_positives_179: 1635.0000 - true_negatives_179: 1158.0000 - false_positives_179: 401.0000 - false_negatives_179: 606.0000 - 436ms/epoch - 4ms/step
# 7 - [5, 7, 9, 12, 16, 17, 21]
# 120/120 - 0s - loss: 0.5217 - accuracy: 0.7292 - true_positives_180: 1824.0000 - true_negatives_180: 957.0000 - false_positives_180: 515.0000 - false_negatives_180: 518.0000 - 477ms/epoch - 4ms/step
# 120/120 - 1s - loss: 0.5217 - accuracy: 0.7292 - true_positives_180: 1824.0000 - true_negatives_180: 957.0000 - false_positives_180: 515.0000 - false_negatives_180: 518.0000 - 601ms/epoch - 5ms/step
# 7 - [2, 3, 6, 7, 8, 10, 19]
# 125/125 - 1s - loss: 0.4825 - accuracy: 0.7631 - true_positives_181: 1603.0000 - true_negatives_181: 1448.0000 - false_positives_181: 283.0000 - false_negatives_181: 664.0000 - 517ms/epoch - 4ms/step
# 125/125 - 1s - loss: 0.4825 - accuracy: 0.7631 - true_positives_181: 1603.0000 - true_negatives_181: 1448.0000 - false_positives_181: 283.0000 - false_negatives_181: 664.0000 - 521ms/epoch - 4ms/step
# 7 - [3, 4, 7, 17, 19, 20, 21]
# 119/119 - 0s - loss: 0.5002 - accuracy: 0.7477 - true_positives_182: 1827.0000 - true_negatives_182: 1006.0000 - false_positives_182: 470.0000 - false_negatives_182: 486.0000 - 477ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.5002 - accuracy: 0.7477 - true_positives_182: 1827.0000 - true_negatives_182: 1006.0000 - false_positives_182: 470.0000 - false_negatives_182: 486.0000 - 486ms/epoch - 4ms/step
# 7 - [1, 5, 6, 8, 13, 20, 21]
# 119/119 - 0s - loss: 0.5093 - accuracy: 0.7445 - true_positives_183: 1727.0000 - true_negatives_183: 1106.0000 - false_positives_183: 417.0000 - false_negatives_183: 555.0000 - 462ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.5093 - accuracy: 0.7445 - true_positives_183: 1727.0000 - true_negatives_183: 1106.0000 - false_positives_183: 417.0000 - false_negatives_183: 555.0000 - 499ms/epoch - 4ms/step
# 7 - [4, 8, 9, 11, 13, 15, 17]
# 119/119 - 0s - loss: 0.5123 - accuracy: 0.7500 - true_positives_184: 1978.0000 - true_negatives_184: 869.0000 - false_positives_184: 522.0000 - false_negatives_184: 427.0000 - 457ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.5123 - accuracy: 0.7500 - true_positives_184: 1978.0000 - true_negatives_184: 869.0000 - false_positives_184: 522.0000 - false_negatives_184: 427.0000 - 420ms/epoch - 4ms/step
# 7 - [2, 4, 7, 8, 11, 13, 18]
# 119/119 - 0s - loss: 0.5063 - accuracy: 0.7456 - true_positives_185: 1803.0000 - true_negatives_185: 1028.0000 - false_positives_185: 475.0000 - false_negatives_185: 491.0000 - 462ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.5063 - accuracy: 0.7456 - true_positives_185: 1803.0000 - true_negatives_185: 1028.0000 - false_positives_185: 475.0000 - false_negatives_185: 491.0000 - 460ms/epoch - 4ms/step
# 7 - [2, 6, 15, 16, 17, 19, 21]
# 126/126 - 0s - loss: 0.4918 - accuracy: 0.7499 - true_positives_186: 1890.0000 - true_negatives_186: 1127.0000 - false_positives_186: 451.0000 - false_negatives_186: 555.0000 - 487ms/epoch - 4ms/step
# 126/126 - 0s - loss: 0.4918 - accuracy: 0.7499 - true_positives_186: 1890.0000 - true_negatives_186: 1127.0000 - false_positives_186: 451.0000 - false_negatives_186: 555.0000 - 497ms/epoch - 4ms/step
# 7 - [4, 7, 10, 11, 14, 17, 19]
# 119/119 - 0s - loss: 0.5118 - accuracy: 0.7491 - true_positives_187: 1386.0000 - true_negatives_187: 1450.0000 - false_positives_187: 314.0000 - false_negatives_187: 636.0000 - 435ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.5118 - accuracy: 0.7491 - true_positives_187: 1386.0000 - true_negatives_187: 1450.0000 - false_positives_187: 314.0000 - false_negatives_187: 636.0000 - 437ms/epoch - 4ms/step
# 7 - [2, 3, 7, 11, 14, 19, 21]
# 127/127 - 0s - loss: 0.4926 - accuracy: 0.7537 - true_positives_188: 1746.0000 - true_negatives_188: 1305.0000 - false_positives_188: 414.0000 - false_negatives_188: 583.0000 - 466ms/epoch - 4ms/step
# 127/127 - 0s - loss: 0.4926 - accuracy: 0.7537 - true_positives_188: 1746.0000 - true_negatives_188: 1305.0000 - false_positives_188: 414.0000 - false_negatives_188: 583.0000 - 489ms/epoch - 4ms/step
# 7 - [3, 8, 12, 14, 17, 18, 19]
# 127/127 - 1s - loss: 0.5285 - accuracy: 0.7332 - true_positives_189: 1938.0000 - true_negatives_189: 1025.0000 - false_positives_189: 593.0000 - false_negatives_189: 485.0000 - 544ms/epoch - 4ms/step
# 127/127 - 1s - loss: 0.5285 - accuracy: 0.7332 - true_positives_189: 1938.0000 - true_negatives_189: 1025.0000 - false_positives_189: 593.0000 - false_negatives_189: 485.0000 - 556ms/epoch - 4ms/step
# 7 - [2, 4, 7, 8, 10, 19, 21]
# 119/119 - 0s - loss: 0.4961 - accuracy: 0.7534 - true_positives_190: 1745.0000 - true_negatives_190: 1102.0000 - false_positives_190: 413.0000 - false_negatives_190: 519.0000 - 454ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.4961 - accuracy: 0.7534 - true_positives_190: 1745.0000 - true_negatives_190: 1102.0000 - false_positives_190: 413.0000 - false_negatives_190: 519.0000 - 435ms/epoch - 4ms/step
# 7 - [1, 3, 5, 7, 8, 11, 20]
# 118/118 - 0s - loss: 0.4768 - accuracy: 0.7732 - true_positives_191: 1691.0000 - true_negatives_191: 1227.0000 - false_positives_191: 381.0000 - false_negatives_191: 475.0000 - 436ms/epoch - 4ms/step
# 118/118 - 0s - loss: 0.4768 - accuracy: 0.7732 - true_positives_191: 1691.0000 - true_negatives_191: 1227.0000 - false_positives_191: 381.0000 - false_negatives_191: 475.0000 - 447ms/epoch - 4ms/step
# 7 - [5, 6, 8, 15, 19, 20, 21]
# 119/119 - 0s - loss: 0.5045 - accuracy: 0.7392 - true_positives_192: 1703.0000 - true_negatives_192: 1089.0000 - false_positives_192: 374.0000 - false_negatives_192: 611.0000 - 466ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.5045 - accuracy: 0.7392 - true_positives_192: 1703.0000 - true_negatives_192: 1089.0000 - false_positives_192: 374.0000 - false_negatives_192: 611.0000 - 485ms/epoch - 4ms/step
# 7 - [3, 7, 9, 14, 17, 18, 20]
# 127/127 - 1s - loss: 0.4901 - accuracy: 0.7591 - true_positives_193: 2108.0000 - true_negatives_193: 970.0000 - false_positives_193: 525.0000 - false_negatives_193: 452.0000 - 764ms/epoch - 6ms/step
# 127/127 - 1s - loss: 0.4901 - accuracy: 0.7591 - true_positives_193: 2108.0000 - true_negatives_193: 970.0000 - false_positives_193: 525.0000 - false_negatives_193: 452.0000 - 567ms/epoch - 4ms/step
# 7 - [2, 4, 5, 6, 7, 20, 21]
# 111/111 - 1s - loss: 0.4683 - accuracy: 0.7579 - true_positives_194: 1725.0000 - true_negatives_194: 967.0000 - false_positives_194: 381.0000 - false_negatives_194: 479.0000 - 506ms/epoch - 5ms/step
# 111/111 - 1s - loss: 0.4683 - accuracy: 0.7579 - true_positives_194: 1725.0000 - true_negatives_194: 967.0000 - false_positives_194: 381.0000 - false_negatives_194: 479.0000 - 513ms/epoch - 5ms/step
# 7 - [1, 3, 10, 12, 17, 20, 21]
# 127/127 - 1s - loss: 0.5158 - accuracy: 0.7364 - true_positives_195: 1861.0000 - true_negatives_195: 1120.0000 - false_positives_195: 505.0000 - false_negatives_195: 562.0000 - 554ms/epoch - 4ms/step
# 127/127 - 1s - loss: 0.5158 - accuracy: 0.7364 - true_positives_195: 1861.0000 - true_negatives_195: 1120.0000 - false_positives_195: 505.0000 - false_negatives_195: 562.0000 - 537ms/epoch - 4ms/step
# 7 - [5, 7, 10, 14, 17, 20, 21]
# 120/120 - 0s - loss: 0.4966 - accuracy: 0.7484 - true_positives_196: 1840.0000 - true_negatives_196: 1013.0000 - false_positives_196: 469.0000 - false_negatives_196: 490.0000 - 438ms/epoch - 4ms/step
# 120/120 - 0s - loss: 0.4966 - accuracy: 0.7484 - true_positives_196: 1840.0000 - true_negatives_196: 1013.0000 - false_positives_196: 469.0000 - false_negatives_196: 490.0000 - 455ms/epoch - 4ms/step
# 7 - [1, 6, 10, 15, 16, 20, 21]
# 126/126 - 0s - loss: 0.5098 - accuracy: 0.7433 - true_positives_197: 1626.0000 - true_negatives_197: 1365.0000 - false_positives_197: 405.0000 - false_negatives_197: 628.0000 - 477ms/epoch - 4ms/step
# 126/126 - 1s - loss: 0.5098 - accuracy: 0.7433 - true_positives_197: 1626.0000 - true_negatives_197: 1365.0000 - false_positives_197: 405.0000 - false_negatives_197: 628.0000 - 504ms/epoch - 4ms/step
# 7 - [2, 3, 5, 12, 13, 15, 17]
# 119/119 - 0s - loss: 0.5071 - accuracy: 0.7380 - true_positives_198: 1993.0000 - true_negatives_198: 810.0000 - false_positives_198: 577.0000 - false_negatives_198: 418.0000 - 488ms/epoch - 4ms/step
# 119/119 - 0s - loss: 0.5071 - accuracy: 0.7380 - true_positives_198: 1993.0000 - true_negatives_198: 810.0000 - false_positives_198: 577.0000 - false_negatives_198: 418.0000 - 476ms/epoch - 4ms/step
# 7 - [3, 4, 8, 15, 17, 19, 21]
# 119/119 - 0s - loss: 0.5166 - accuracy: 0.7352 - true_positives_199: 1962.0000 - true_negatives_199: 815.0000 - false_positives_199: 591.0000 - false_negatives_199: 409.0000 - 497ms/epoch - 4ms/step
# 119/119 - 1s - loss: 0.5166 - accuracy: 0.7352 - true_positives_199: 1962.0000 - true_negatives_199: 815.0000 - false_positives_199: 591.0000 - false_negatives_199: 409.0000 - 522ms/epoch - 4ms/step
# 7 - [4, 6, 7, 12, 14, 16, 21]
# 120/120 - 0s - loss: 0.5281 - accuracy: 0.7342 - true_positives_200: 1446.0000 - true_negatives_200: 1355.0000 - false_positives_200: 371.0000 - false_negatives_200: 643.0000 - 429ms/epoch - 4ms/step
# 120/120 - 0s - loss: 0.5281 - accuracy: 0.7342 - true_positives_200: 1446.0000 - true_negatives_200: 1355.0000 - false_positives_200: 371.0000 - false_negatives_200: 643.0000 - 493ms/epoch - 4ms/step
# 7 - [2, 3, 6, 14, 15, 16, 21]
# 127/127 - 0s - loss: 0.4948 - accuracy: 0.7472 - true_positives_201: 1856.0000 - true_negatives_201: 1161.0000 - false_positives_201: 466.0000 - false_negatives_201: 555.0000 - 457ms/epoch - 4ms/step
# 127/127 - 0s - loss: 0.4948 - accuracy: 0.7472 - true_positives_201: 1856.0000 - true_negatives_201: 1161.0000 - false_positives_201: 466.0000 - false_negatives_201: 555.0000 - 482ms/epoch - 4ms/step
# 7 - [1, 2, 3, 6, 11, 14, 20]
# 127/127 - 0s - loss: 0.4686 - accuracy: 0.7721 - true_positives_202: 1742.0000 - true_negatives_202: 1374.0000 - false_positives_202: 359.0000 - false_negatives_202: 561.0000 - 489ms/epoch - 4ms/step
# 127/127 - 1s - loss: 0.4686 - accuracy: 0.7721 - true_positives_202: 1742.0000 - true_negatives_202: 1374.0000 - false_positives_202: 359.0000 - false_negatives_202: 561.0000 - 533ms/epoch - 4ms/step
# 7 - [1, 6, 10, 11, 13, 16, 18]
# 126/126 - 1s - loss: 0.5241 - accuracy: 0.7417 - true_positives_203: 1369.0000 - true_negatives_203: 1620.0000 - false_positives_203: 395.0000 - false_negatives_203: 646.0000 - 610ms/epoch - 5ms/step
# 126/126 - 0s - loss: 0.5241 - accuracy: 0.7417 - true_positives_203: 1369.0000 - true_negatives_203: 1620.0000 - false_positives_203: 395.0000 - false_negatives_203: 646.0000 - 445ms/epoch - 4ms/step
# 7 - [4, 5, 7, 8, 13, 14, 16]
# 111/111 - 0s - loss: 0.5280 - accuracy: 0.7330 - true_positives_204: 1459.0000 - true_negatives_204: 1143.0000 - false_positives_204: 390.0000 - false_negatives_204: 558.0000 - 463ms/epoch - 4ms/step
# 111/111 - 0s - loss: 0.5280 - accuracy: 0.7330 - true_positives_204: 1459.0000 - true_negatives_204: 1143.0000 - false_positives_204: 390.0000 - false_negatives_204: 558.0000 - 450ms/epoch - 4ms/step
# 9 - [1, 2, 7, 8, 10, 12, 13, 17, 19]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14832/3267098112.py in <module>
#      32             # Entrenamiento de modelo centralizado
#      33             model = get_model()
# ---> 34             hist = hist = model.fit(
#      35                 X_train, y_train,
#      36                 batch_size=32,
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1203       logs = None
#    1204       for epoch, iterator in data_handler.enumerate_epochs():
# -> 1205         self.reset_metrics()
#    1206         callbacks.on_epoch_begin(epoch)
#    1207         with data_handler.catch_stop_iteration():
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py in reset_metrics(self)
#    1839     """
#    1840     for m in self.metrics:
# -> 1841       m.reset_state()
#    1842
#    1843   def train_on_batch(self,
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\metrics.py in reset_state(self)
#     264       return self.reset_states()
#     265     else:
# --> 266       backend.batch_set_value([(v, 0) for v in self.variables])
#     267
#     268   @abc.abstractmethod
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\backend.py in batch_set_value(tuples)
#    3928   if tf.compat.v1.executing_eagerly_outside_functions():
#    3929     for x, value in tuples:
# -> 3930       x.assign(np.asarray(value, dtype=dtype_numpy(x)))
#    3931   else:
#    3932     with get_graph().as_default():
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     913              f"The variable shape {self._shape}, and the "
#     914              f"assigned value shape {value_tensor.shape} are incompatible."))
# --> 915       assign_op = gen_resource_variable_ops.assign_variable_op(
#     916           self.handle, value_tensor, name=name)
#     917       if read_value:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py in assign_variable_op(resource, value, name)
#     138   if tld.is_eager:
#     139     try:
# --> 140       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     141         _ctx, "AssignVariableOp", name, resource, value)
#     142       return _result
#
# KeyboardInterrupt:
