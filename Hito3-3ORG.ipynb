# %%
import os
import math

# Make TensorFlow logs less verbose
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import flwr as fl
import tensorflow as tf

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

from keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.optimizers import Adadelta

from typing import Dict

from flwr.common.logger import log
from logging import INFO
from csv import writer


from numpy.random import seed
from tensorflow.keras.utils import set_random_seed

import matplotlib.pyplot as plt

# %%
def get_empresa_conductor(conductor_id):
    for i in range(1,4):
        if (conductor_id in CONDUCTORES_IDS[i]):
            return i

# %%
''' FUNCION PARA CARGAR LOS DATOS DE UN CLIENTE EN PARTICULAR '''
def prepare_model_data(client_file):
    df = pd.read_csv(client_file)
    
    train, test = train_test_split(df, test_size=0.30, random_state=42)
    
    X_train = train[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]
    X_test = test[['psd_delta', 'psd_theta', 'psd_alpha', 'psd_beta', 'psd_gamma','eog_blinks', 'eog_var']]
    y_train = train['y_class']
    y_test = test['y_class']
    
    scaler = StandardScaler()

    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test

# %%
def cargar_dataset_varios_clientes(clientes):
    base_path = "./data/centralizado"
    
    X_train, X_val, y_train, y_val = prepare_model_data(f'{base_path}/cliente_{clientes[0]}.csv')
    
    for cid in clientes[1:]:
        path = f'{base_path}/cliente_{cid}.csv'
        X_train_act, X_val_act, y_train_act, y_val_act = prepare_model_data(path)
    
        X_train = np.vstack((X_train, X_train_act))
        X_val = np.vstack((X_val, X_val_act))
        y_train = np.concatenate((y_train, y_train_act))
        y_val = np.concatenate((y_val, y_val_act))
        
    return X_train, X_val, y_train, y_val

# %%
def get_model():
    # Model best hyperparameters (Ver notebook Hito0-Optimizacion-Baseline)
    neurons = 36
    activation = "relu"
    learning_rate = 0.180165
    optimizer = Adadelta(learning_rate=learning_rate)
    
    input_shape = (7,)
    
    # Create model
    model = Sequential()
    
    model.add(Dense(neurons, input_shape=input_shape, activation=activation))
    
    model.add(BatchNormalization())
        
    model.add(Dense(neurons, activation=activation))
    model.add(Dense(neurons, activation=activation))
    model.add(Dense(neurons, activation=activation))
    
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
def get_weights_from_file(path):
    a = np.load(path, allow_pickle=True)

    n_elems = [252, 36,
               36, 36, 36, 36,
               1296, 36,
               1296, 36,
               1296, 36,
               36, 1]

    weights = []

    # https://numpy.org/devdocs/reference/generated/numpy.lib.format.html#version-numbering
    # En base a la doc sabemos que los datos de interes estan al final, y como deben ser float32 => 4 bytes
    # por lo que se toman los n_elementos*4bytes del final

    for i, t in enumerate(a["arr_0"][0].tensors):
        act = np.frombuffer(t[-n_elems[i]*4:], dtype=np.float32)
        weights.append(act)

    # Se cambia la forma para que se adapte a la del modelo
    weights[0] = weights[0].reshape(7,36)
    weights[6] = weights[6].reshape(36,36)
    weights[8] = weights[8].reshape(36,36)
    weights[10] = weights[10].reshape(36,36)
    weights[12] = weights[12].reshape(36,1)
    
    return weights

# %% [markdown]
# # Level 1 functionality

# %%
class ConductorClient(fl.client.NumPyClient):
    def __init__(self, cid, empresa, model, x_train, y_train, x_val, y_val) -> None:
        self.cid = cid
        self.empresa = empresa
        self.model = model
        self.x_train, self.y_train = x_train, y_train
        self.x_val, self.y_val = x_val, y_val

    def get_parameters(self):
        return self.model.get_weights()

    def fit(self, parameters, config):
        self.model.set_weights(parameters)
        
        seed(1)
        set_random_seed(2)
        
        self.model.fit(self.x_train, self.y_train,
                       epochs=1,
                       batch_size=32,
                       verbose=0)
        
        return self.model.get_weights(), len(self.x_train), {"client": self.cid, "empresa": self.empresa}

    def evaluate(self, parameters, config):
        self.model.set_weights(parameters)
        
        loss, acc = self.model.evaluate(self.x_val, self.y_val, verbose=0)
        
        return loss, len(self.x_val), {"accuracy": acc, "client": self.cid, "empresa": self.empresa}

# %%
def conductor_fn(cid: str) -> fl.client.Client:
    model = get_model()
    
    empresa = get_empresa_conductor(int(cid))
    
    # Load data partition
    base_path = "./data/horizontal_v3/"
    path = f"{base_path}empresa_{empresa}/cliente_{cid}.csv"
    
    x_train_cid, x_val_cid, y_train_cid, y_val_cid = prepare_model_data(path)

    # Create and return client
    return ConductorClient(cid, empresa, model, x_train_cid, y_train_cid, x_val_cid, y_val_cid)

# %%
class L1SaveModelStrategy(fl.server.strategy.FedAvg):
    def aggregate_fit(self, rnd, results, failures):
        aggregated_weights = super().aggregate_fit(rnd, results, failures)
        
        # COMPROBAR DE QUE EMPRESA ES EL CLIENTE
        emp_id = results[1].metrics["empresa"]
        
        if aggregated_weights is not None:
            # Save aggregated_weights
            print(f"Saving round {rnd} aggregated_weights...")
            np.savez(f"./rounds/hito3_L1-round-{rnd}-E{emp_id}-weights.npz", aggregated_weights)
            
        return aggregated_weights

    def aggregate_evaluate(self, rnd, results, failures):
        super_result = super().aggregate_evaluate(rnd, results, failures)
        
#         log(
#             INFO,
#             f"round-{rnd}-EVALUATION"
#         )
        
#         accuracy = []
#         data = {}
#         for r in results:
#             acc = r[1].metrics["accuracy"]
#             client = r[1].metrics["client"]
#             data[client] = acc
#             accuracy.append(acc)
        
#         df = pd.DataFrame(data, index=[0], columns=sorted(data.keys()))
#         df.to_csv(f"./results/hito1_v3-empresa_{EMPRESA_ACTUAL}.csv", mode='a', index=False, header=False)
        
#         log(
#             INFO,
#             sorted(data.items())
#         )
        
#         np.array(accuracy)
#         log(
#             INFO,
#             f"Aggregated accuracy: {np.mean(accuracy)} +- {np.std(accuracy)}"
#         )
        
        return super_result

# %% [markdown]
# # Level 2 functionality

# %%
class EmpresaClient(fl.client.NumPyClient):
    def __init__(self, cid, model, x_train, y_train, x_val, y_val) -> None:
        self.cid = cid
        self.model = model
        self.x_train, self.y_train = x_train, y_train
        self.x_val, self.y_val = x_val, y_val

    def get_parameters(self):
        return self.model.get_weights()

    def fit(self, parameters, config):
        emp_id = int(self.cid[-1])
        
        def L1_fit_config(rnd: int) -> Dict[str, str]:
            config = {
                "round": str(rnd)
            }
            return config
        
        fl.simulation.start_simulation(
        client_fn=conductor_fn,
        clients_ids=CONDUCTORES_IDS[emp_id],
        client_resources={"num_cpus": 1},
        num_rounds=1,
        strategy=L1SaveModelStrategy(
                min_available_clients = len(CONDUCTORES_IDS[emp_id]),
                min_fit_clients = len(CONDUCTORES_IDS[emp_id]),
                min_eval_clients = len(CONDUCTORES_IDS[emp_id]),
                on_fit_config_fn = L1_fit_config,
                on_evaluate_config_fn = L1_fit_config,
                accept_failures=False,
                initial_parameters=parameters
            )
        )
        
        # Se cargan los pesos agregados para la epoch de todos los conductores
        rnd = int(config["round"])
        path = f"./rounds/hito3_L1-round-{1}-E{emp_id}-weights.npz"
        
        weights = get_weights_from_file(path)
        
        # Se recuentan cuantas observaciones de train hay
        obs_total = len(self.x_train)
        
        return weights, obs_total, {"client": self.cid}

    def evaluate(self, parameters, config):
        self.model.set_weights(parameters)
        
        loss, acc = self.model.evaluate(self.x_val, self.y_val, verbose=0)
        
        # Se recuentan cuantas observaciones de test hay
        obs_total = len(self.x_val)
        
        return loss, obs_total, {"accuracy": acc, "client": self.cid}

# %%
def empresa_fn(cid: str) -> fl.client.Client:
    model = get_model()
    
    # Load data partition
    emp_id = int(cid[-1])
    x_train_cid, x_val_cid, y_train_cid, y_val_cid = cargar_dataset_varios_clientes(CONDUCTORES_IDS[emp_id])
    
    # Create and return client
    print(f"Creada empresa {cid}")
    return EmpresaClient(cid, model, x_train_cid, y_train_cid, x_val_cid, y_val_cid)

# %%
class L2SaveModelStrategy(fl.server.strategy.FedAvg):
    def aggregate_fit(self, rnd, results, failures):
        aggregated_weights = super().aggregate_fit(rnd, results, failures)
        
        if aggregated_weights is not None:
            # Save aggregated_weights
            print(f"Saving round {rnd} aggregated_weights...")
            np.savez(f"./rounds/hito3_L2-round-{rnd}-weights.npz", aggregated_weights)
            
        return aggregated_weights

    def aggregate_evaluate(self, rnd, results, failures):
        super_result = super().aggregate_evaluate(rnd, results, failures)
        
        log(
            INFO,
            f"round-{rnd}-EVALUATION"
        )
        
        accuracy = []
        data = {}
        for r in results:
            acc = r[1].metrics["accuracy"]
            client = r[1].metrics["client"]
            data[client] = acc
            
            accuracy.append(acc)
        
        df = pd.DataFrame(data, index=[0], columns=sorted(data.keys()))
        df.to_csv(f"./results/hito3.csv", mode='a', index=False, header=False)
        
        log(
            INFO,
            sorted(data.items())
        )
        
        np.array(accuracy)
        log(
            INFO,
            f"Aggregated accuracy: {np.mean(accuracy)} +- {np.std(accuracy)}"
        )
        
        return super_result

# %%
seed(1)
set_random_seed(2)

model = get_model()

# Get model weights as a list of NumPy ndarray's
weights = model.get_weights()
# Serialize ndarrays to `Parameters`
parameters = fl.common.weights_to_parameters(weights)

# %%
# Ahora los clientes son las tres empresas (L2) y los conductores (L1)
global EMPRESAS_IDS
EMPRESAS_IDS = ["empresa_1", "empresa_2", "empresa_3"]

global CONDUCTORES_IDS
CONDUCTORES_IDS = {
    1: [3,4,5,12,  2,8,  1],
    2: [13,14,    6,7,10,11,16],
    3: [15,18,  9,17,20,21,  19]
}

 # Se inicializa el fichero de resultados
header = EMPRESAS_IDS

with open(f"./results/hito3.csv", 'w', ) as f:
    csv_writer = writer(f)
    csv_writer.writerow(header)

# Configuracion de parametros para el entrenamiento desde el servidor
def L2_fit_config(rnd: int) -> Dict[str, str]:
    config = {
        "round": str(rnd)
    }
    return config

# Start Flower simulation
    # min_fit_clients y min_eval_clients se ponen al maximo de clientes disponibles ya que estamos en un escenario controlado
fl.simulation.start_simulation(
    client_fn=empresa_fn,
    clients_ids=EMPRESAS_IDS,
    client_resources={"num_cpus": 3},
    num_rounds=1,
    strategy=L2SaveModelStrategy(
        min_available_clients = len(EMPRESAS_IDS),
        min_fit_clients = len(EMPRESAS_IDS),
        min_eval_clients = len(EMPRESAS_IDS),
        on_fit_config_fn = L2_fit_config,
        on_evaluate_config_fn = L2_fit_config,
        accept_failures=False,
        initial_parameters=parameters
    )
)
# Out:
# INFO flower 2022-05-02 18:28:29,766 | app.py:144 | Ray initialized with resources: {'object_store_memory': 2527183257.0, 'CPU': 8.0, 'memory': 5054366516.0, 'GPU': 1.0, 'node:127.0.0.1': 1.0}
# INFO flower 2022-05-02 18:28:29,768 | app.py:153 | Starting Flower simulation running: {'num_rounds': 1}
# INFO flower 2022-05-02 18:28:29,768 | server.py:128 | Initializing global parameters
# INFO flower 2022-05-02 18:28:29,769 | server.py:323 | Using initial parameters provided by strategy
# INFO flower 2022-05-02 18:28:29,769 | server.py:130 | Evaluating initial parameters
# INFO flower 2022-05-02 18:28:29,769 | server.py:143 | FL starting
# DEBUG flower 2022-05-02 18:28:29,770 | server.py:265 | fit_round: strategy sampled 3 clients (out of 3)
#  pid=6264) Creada empresa empresa_2
#  pid=15432) Creada empresa empresa_1
#  pid=6264) [2022-05-02 18:28:35,324 C 6264 8948] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=6264) *** StackTrace Information ***
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyType_GenericNew
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264)     PyObject_GC_Del
#  pid=6264)     PyFunction_Vectorcall
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264)     PyObject_GC_Del
#  pid=6264)     PyFunction_Vectorcall
#  pid=6264)     PyVectorcall_Call
#  pid=6264)     PyObject_Call
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264)     PyObject_GC_Del
#  pid=6264)     PyFunction_Vectorcall
#  pid=6264)     PyVectorcall_Call
#  pid=6264)     PyObject_Call
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264)     PyObject_GC_Del
#  pid=6264)     PyFunction_Vectorcall
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264)     PyFunction_Vectorcall
#  pid=6264)     PyVectorcall_Call
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyInit__raylet
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264)     PyEval_EvalFrameDefault
#  pid=6264) h_and_fit
#  pid=6264) Stack (most recent call first):
#  pid=6264)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=6264)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=6264)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=6264)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=6264)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=6264)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=6264)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=6264)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=6264)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:28:35,589	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 856cbe232f28566b1787a9209439fea4877d42b601000000 Worker ID: 57abccf65d808475bf98db5f783d64a48732466bc41a95399d742415 Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49461 Worker PID: 6264
#  pid=15432) [2022-05-02 18:28:36,351 C 15432 2380] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=15432) *** StackTrace Information ***
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyType_GenericNew
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432)     PyObject_GC_Del
#  pid=15432)     PyFunction_Vectorcall
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432)     PyObject_GC_Del
#  pid=15432)     PyFunction_Vectorcall
#  pid=15432)     PyVectorcall_Call
#  pid=15432)     PyObject_Call
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432)     PyObject_GC_Del
#  pid=15432)     PyFunction_Vectorcall
#  pid=15432)     PyVectorcall_Call
#  pid=15432)     PyObject_Call
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432)     PyObject_GC_Del
#  pid=15432)     PyFunction_Vectorcall
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432)     PyFunction_Vectorcall
#  pid=15432)     PyVectorcall_Call
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyInit__raylet
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432)     PyEval_EvalFrameDefault
#  pid=15432) _and_fit
#  pid=15432) Stack (most recent call first):
#  pid=15432)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=15432)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=15432)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=15432)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=15432)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=15432)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=15432)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=15432)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=15432)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:28:36,421	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 29dabc5f04a91fd4573c4a42420f8f0dbe47ed3201000000 Worker ID: bcc1eeaa1e21629398276ed0f5cb30c5c8c3978e900f655b8f3f0210 Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49456 Worker PID: 15432
#  pid=19408) Creada empresa empresa_3
#  pid=19720) Creada empresa empresa_2
#  pid=19408) [2022-05-02 18:28:41,196 C 19408 19672] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=19408) *** StackTrace Information ***
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyType_GenericNew
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408)     PyObject_GC_Del
#  pid=19408)     PyFunction_Vectorcall
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408)     PyObject_GC_Del
#  pid=19408)     PyFunction_Vectorcall
#  pid=19408)     PyVectorcall_Call
#  pid=19408)     PyObject_Call
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408)     PyObject_GC_Del
#  pid=19408)     PyFunction_Vectorcall
#  pid=19408)     PyVectorcall_Call
#  pid=19408)     PyObject_Call
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408)     PyObject_GC_Del
#  pid=19408)     PyFunction_Vectorcall
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408)     PyFunction_Vectorcall
#  pid=19408)     PyVectorcall_Call
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyInit__raylet
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408)     PyEval_EvalFrameDefault
#  pid=19408) _and_fit
#  pid=19408) Stack (most recent call first):
#  pid=19408)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=19408)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=19408)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=19408)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=19408)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=19408)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=19408)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=19408)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=19408)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:28:41,379	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 7c1fa6ebeb24844bbb525d7b85c9161bf7b7b4f201000000 Worker ID: 2cfe6143a6b1dfd7758daf4397ae648ec79f1943da21c99c43441e0a Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49445 Worker PID: 19408
#  pid=19720) [2022-05-02 18:28:42,210 C 19720 15924] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=19720) *** StackTrace Information ***
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyType_GenericNew
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720)     PyObject_GC_Del
#  pid=19720)     PyFunction_Vectorcall
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720)     PyObject_GC_Del
#  pid=19720)     PyFunction_Vectorcall
#  pid=19720)     PyVectorcall_Call
#  pid=19720)     PyObject_Call
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720)     PyObject_GC_Del
#  pid=19720)     PyFunction_Vectorcall
#  pid=19720)     PyVectorcall_Call
#  pid=19720)     PyObject_Call
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720)     PyObject_GC_Del
#  pid=19720)     PyFunction_Vectorcall
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720)     PyFunction_Vectorcall
#  pid=19720)     PyVectorcall_Call
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyInit__raylet
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720)     PyEval_EvalFrameDefault
#  pid=19720) _and_fit
#  pid=19720) Stack (most recent call first):
#  pid=19720)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=19720)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=19720)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=19720)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=19720)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=19720)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=19720)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=19720)   File "C:\Users\34601\AppDa
#  pid=19720) ta\d_fit
#  pid=19720) Roaming\P
#  pid=19720) ython\it
#  pid=19720) Pytd_fit
#  pid=19720) hon39fit
#  pid=19720) \snd_fit
#  pid=19720) ite-pfit
#  pid=19720) ackagest
#  pid=19720) \rnd_fit
#  pid=19720) ay\w_fit
#  pid=19720) orkerfit
#  pid=19720) .pnd_fit
#  pid=19720) yand_fit
#  pid=19720) ", line
#  pid=19720) 430 in mai
#  pid=19720) n_nd_fit
#  pid=19720) lond_fit
#  pid=19720) opnd_fit
#  pid=19720) _and_fit
#  pid=19720)   File t
#  pid=19720) "and_fit
#  pid=19720) Cand_fit
#  pid=19720) :\Ud_fit
#  pid=19720) serd_fit
#  pid=19720) sand_fit
#  pid=19720) \34601\Ap
#  pid=19720) pand_fit
#  pid=19720) Dand_fit
#  pid=19720) tand_fit
#  pid=19720) \and_fit
#  pid=19720) Rand_fit
#  pid=19720) oaminfit
#  pid=19720) g\nd_fit
#  pid=19720) Pytd_fit
#  pid=19720) hon\Pyit
#  pid=19720) thon39\site-pa
#  pid=19720) ckagesit
#  pid=19720) \ray\wit
#  pid=19720) orkers\de
#  pid=19720) fand_fit
#  pid=19720) ult__fit
#  pid=19720) workefit
#  pid=19720) r.py", line
#  pid=19720) 224 in t
#  pid=19720) <module>
# 2022-05-02 18:28:42,309	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 1a9b7a18b9c986adfd7346ef4248846f01e6985501000000 Worker ID: a28e4e9761524c9224c59472cb5ad366b96efdba9723c3cfaaee432c Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49439 Worker PID: 19720
#  pid=19380) Creada empresa empresa_1
#  pid=13200) Creada empresa empresa_3
#  pid=19380) [2022-05-02 18:28:46,242 C 19380 2512] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=19380) *** StackTrace Information ***
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyType_GenericNew
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380)     PyObject_GC_Del
#  pid=19380)     PyFunction_Vectorcall
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380)     PyObject_GC_Del
#  pid=19380)     PyFunction_Vectorcall
#  pid=19380)     PyVectorcall_Call
#  pid=19380)     PyObject_Call
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380)     PyObject_GC_Del
#  pid=19380)     PyFunction_Vectorcall
#  pid=19380)     PyVectorcall_Call
#  pid=19380)     PyObject_Call
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380)     PyObject_GC_Del
#  pid=19380)     PyFunction_Vectorcall
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380)     PyFunction_Vectorcall
#  pid=19380)     PyVectorcall_Call
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyInit__raylet
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380)     PyEval_EvalFrameDefault
#  pid=19380) _and_fit
#  pid=19380) Stack (most recent call first):
#  pid=19380)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=19380)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=19380)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=19380)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=19380)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=19380)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=19380)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=19380)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=19380)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:28:46,426	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: e7a03f473f4d60dfa3885869c5277ef717e10b8101000000 Worker ID: 656f7ea720b71dad0f9a42723fe9aa8ff2337aa7ca86620dce0a16ec Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49444 Worker PID: 19380
# 2022-05-02 18:28:47,638	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: a8d8f5f91a4dca6c35fa351df8dfc30615fad4be01000000 Worker ID: 4543d1576745b5c6fbb572e9fc67db67c1da1d975dd0a3e79758042c Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49449 Worker PID: 13200
#  pid=13200) [2022-05-02 18:28:47,575 C 13200 20012] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=13200) *** StackTrace Information ***
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyType_GenericNew
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200)     PyObject_GC_Del
#  pid=13200)     PyFunction_Vectorcall
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200)     PyObject_GC_Del
#  pid=13200)     PyFunction_Vectorcall
#  pid=13200)     PyVectorcall_Call
#  pid=13200)     PyObject_Call
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200)     PyObject_GC_Del
#  pid=13200)     PyFunction_Vectorcall
#  pid=13200)     PyVectorcall_Call
#  pid=13200)     PyObject_Call
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200)     PyObject_GC_Del
#  pid=13200)     PyFunction_Vectorcall
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200)     PyFunction_Vectorcall
#  pid=13200)     PyVectorcall_Call
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyInit__raylet
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200)     PyEval_EvalFrameDefault
#  pid=13200) _and_fit
#  pid=13200) Stack (most recent call first):
#  pid=13200)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=13200)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=13200)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=13200)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=13200)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=13200)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=13200)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=13200)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=13200)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
#  pid=9448) Creada empresa empresa_2
#  pid=19464) Creada empresa empresa_1
#  pid=9448) [2022-05-02 18:28:51,325 C 9448 18420] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=9448) *** StackTrace Information ***
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyType_GenericNew
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448)     PyObject_GC_Del
#  pid=9448)     PyFunction_Vectorcall
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448)     PyObject_GC_Del
#  pid=9448)     PyFunction_Vectorcall
#  pid=9448)     PyVectorcall_Call
#  pid=9448)     PyObject_Call
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448)     PyObject_GC_Del
#  pid=9448)     PyFunction_Vectorcall
#  pid=9448)     PyVectorcall_Call
#  pid=9448)     PyObject_Call
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448)     PyObject_GC_Del
#  pid=9448)     PyFunction_Vectorcall
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448)     PyFunction_Vectorcall
#  pid=9448)     PyVectorcall_Call
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyInit__raylet
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448)     PyEval_EvalFrameDefault
#  pid=9448) h_and_fit
#  pid=9448) Stack (most recent call first):
#  pid=9448)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=9448)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=9448)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=9448)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=9448)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=9448)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=9448)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=9448)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=9448)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:28:51,509	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 3dde5c3b8e900cad7b17344404efd5e4cd927eaa01000000 Worker ID: c079f8a9390ff70bb8b25e98df25491a20af1217d8d75d88c6d3de70 Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49414 Worker PID: 9448
# 2022-05-02 18:28:53,365	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 32c39a45dd520478d22172ea03b2cd4edfc3990101000000 Worker ID: 14606cd3cca0fc7ec49f0ef66d99f56c16135781dc659939d7460790 Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49416 Worker PID: 19464
#  pid=19464) [2022-05-02 18:28:53,302 C 19464 20160] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=19464) *** StackTrace Information ***
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyType_GenericNew
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464)     PyObject_GC_Del
#  pid=19464)     PyFunction_Vectorcall
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464)     PyObject_GC_Del
#  pid=19464)     PyFunction_Vectorcall
#  pid=19464)     PyVectorcall_Call
#  pid=19464)     PyObject_Call
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464)     PyObject_GC_Del
#  pid=19464)     PyFunction_Vectorcall
#  pid=19464)     PyVectorcall_Call
#  pid=19464)     PyObject_Call
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464)     PyObject_GC_Del
#  pid=19464)     PyFunction_Vectorcall
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464)     PyFunction_Vectorcall
#  pid=19464)     PyVectorcall_Call
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyInit__raylet
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464)     PyEval_EvalFrameDefault
#  pid=19464) _and_fit
#  pid=19464) Stack (most recent call first):
#  pid=19464)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=19464)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=19464)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=19464)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=19464)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=19464)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=19464)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=19464)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=19464)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
#  pid=17964) Creada empresa empresa_3
#  pid=17964) [2022-05-02 18:28:56,394 C 17964 15792] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=17964) *** StackTrace Information ***
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyType_GenericNew
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964)     PyObject_GC_Del
#  pid=17964)     PyFunction_Vectorcall
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964)     PyObject_GC_Del
#  pid=17964)     PyFunction_Vectorcall
#  pid=17964)     PyVectorcall_Call
#  pid=17964)     PyObject_Call
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964)     PyObject_GC_Del
#  pid=17964)     PyFunction_Vectorcall
#  pid=17964)     PyVectorcall_Call
#  pid=17964)     PyObject_Call
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964)     PyObject_GC_Del
#  pid=17964)     PyFunction_Vectorcall
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964)     PyFunction_Vectorcall
#  pid=17964)     PyVectorcall_Call
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyInit__raylet
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964)     PyEval_EvalFrameDefault
#  pid=17964) _and_fit
#  pid=17964) Stack (most recent call first):
#  pid=17964)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=17964)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=17964)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=17964)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=17964)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=17964)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=17964)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=17964)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=17964)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:28:56,598	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 31874cfedd270976c1e8654d25aaa21e1cde40bb01000000 Worker ID: 12d0fac0d7b4f98f4342a9502e25f68a02997b5e1196f1713bed9481 Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49600 Worker PID: 17964
#  pid=19644) Creada empresa empresa_2
#  pid=19644) [2022-05-02 18:28:58,839 C 19644 7740] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=19644) *** StackTrace Information ***
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyType_GenericNew
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644)     PyObject_GC_Del
#  pid=19644)     PyFunction_Vectorcall
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644)     PyObject_GC_Del
#  pid=19644)     PyFunction_Vectorcall
#  pid=19644)     PyVectorcall_Call
#  pid=19644)     PyObject_Call
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644)     PyObject_GC_Del
#  pid=19644)     PyFunction_Vectorcall
#  pid=19644)     PyVectorcall_Call
#  pid=19644)     PyObject_Call
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644)     PyObject_GC_Del
#  pid=19644)     PyFunction_Vectorcall
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644)     PyFunction_Vectorcall
#  pid=19644)     PyVectorcall_Call
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyInit__raylet
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644)     PyEval_EvalFrameDefault
#  pid=19644) _and_fit
#  pid=19644) Stack (most recent call first):
#  pid=19644)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=19644)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=19644)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=19644)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=19644)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=19644)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=19644)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=19644)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=19644)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:28:58,918	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: f1e8ed16061e5f435ea4647a745f21755c52f60701000000 Worker ID: a42d7c0f3a9bfbb676601bc1ca301d9af6dc175ca0e1d2a2d7e43995 Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49636 Worker PID: 19644
#  pid=7372) Creada empresa empresa_1
#  pid=7372) [2022-05-02 18:29:01,485 C 7372 3208] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=7372) *** StackTrace Information ***
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyType_GenericNew
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372)     PyObject_GC_Del
#  pid=7372)     PyFunction_Vectorcall
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372)     PyObject_GC_Del
#  pid=7372)     PyFunction_Vectorcall
#  pid=7372)     PyVectorcall_Call
#  pid=7372)     PyObject_Call
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372)     PyObject_GC_Del
#  pid=7372)     PyFunction_Vectorcall
#  pid=7372)     PyVectorcall_Call
#  pid=7372)     PyObject_Call
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372)     PyObject_GC_Del
#  pid=7372)     PyFunction_Vectorcall
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372)     PyFunction_Vectorcall
#  pid=7372)     PyVectorcall_Call
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyInit__raylet
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372)     PyEval_EvalFrameDefault
#  pid=7372) h_and_fit
#  pid=7372) Stack (most recent call first):
#  pid=7372)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=7372)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=7372)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=7372)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=7372)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=7372)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=7372)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=7372)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=7372)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:29:01,557	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: aa232451e5bb864afb397953eb97e591c3ad434301000000 Worker ID: fefc756be936f84d69259c606caf772fab9abc38b2432fc17996ac2c Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49648 Worker PID: 7372
#  pid=18268) Creada empresa empresa_3
#  pid=18268) [2022-05-02 18:29:04,523 C 18268 3228] core_worker_process.cc:29:  Check failed: !core_worker_process The process is already initialized for core worker.
#  pid=18268) *** StackTrace Information ***
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyType_GenericNew
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268)     PyObject_GC_Del
#  pid=18268)     PyFunction_Vectorcall
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268)     PyObject_GC_Del
#  pid=18268)     PyFunction_Vectorcall
#  pid=18268)     PyVectorcall_Call
#  pid=18268)     PyObject_Call
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268)     PyObject_GC_Del
#  pid=18268)     PyFunction_Vectorcall
#  pid=18268)     PyVectorcall_Call
#  pid=18268)     PyObject_Call
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268)     PyObject_GC_Del
#  pid=18268)     PyFunction_Vectorcall
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268)     PyFunction_Vectorcall
#  pid=18268)     PyVectorcall_Call
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyInit__raylet
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268)     PyEval_EvalFrameDefault
#  pid=18268) _and_fit
#  pid=18268) Stack (most recent call first):
#  pid=18268)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 1529 in connect
#  pid=18268)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 977 in init
#  pid=18268)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105 in wrapper
#  pid=18268)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\app.py", line 143 in start_simulation
#  pid=18268)   File "C:\Users\34601\AppData\Local\Temp/ipykernel_7956/2710289745.py", line 20 in fit
#  pid=18268)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\client\numpy_client.py", line 227 in fit
#  pid=18268)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 109 in launch_and_fit
#  pid=18268)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\worker.py", line 430 in main_loop
#  pid=18268)   File "C:\Users\34601\AppData\Roaming\Python\Python39\site-packages\ray\workers\default_worker.py", line 224 in <module>
# 2022-05-02 18:29:04,597	WARNING worker.py:1326 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: 636f36310cd69c40dcdc87958e1f44d6b53f89d101000000 Worker ID: 62a7e50a014a9e755f0b763b67a06cd5220f860464201415cb9867b7 Node ID: 1631c468ef4fcba60348801420b3412bc67ad617f5a3d5713632aafb Worker IP address: 127.0.0.1 Worker port: 49686 Worker PID: 18268
# DEBUG flower 2022-05-02 18:29:04,600 | server.py:277 | fit_round received 0 results and 3 failures
# DEBUG flower 2022-05-02 18:29:04,603 | server.py:211 | evaluate_round: strategy sampled 3 clients (out of 3)
# Saving round 1 aggregated_weights...
#  pid=16260) Creada empresa empresa_3
#  pid=15416) Creada empresa empresa_1
#  pid=16260) Creada empresa empresa_2
# DEBUG flower 2022-05-02 18:29:16,321 | server.py:223 | evaluate_round received 3 results and 0 failures
# INFO flower 2022-05-02 18:29:16,322 | 3757911614.py:15 | round-1-EVALUATION
# INFO flower 2022-05-02 18:29:16,325 | 3757911614.py:32 | [('empresa_1', 0.5615113973617554), ('empresa_2', 0.7681894898414612), ('empresa_3', 0.4327850341796875)]
# INFO flower 2022-05-02 18:29:16,326 | 3757911614.py:38 | Aggregated accuracy: 0.5874953071276346 +- 0.138155491854851
# INFO flower 2022-05-02 18:29:16,326 | server.py:182 | FL finished in 46.5561058
# INFO flower 2022-05-02 18:29:16,327 | app.py:149 | app_fit: losses_distributed [(1, 0.6788757778575973)]
# INFO flower 2022-05-02 18:29:16,327 | app.py:150 | app_fit: metrics_distributed {}
# INFO flower 2022-05-02 18:29:16,328 | app.py:151 | app_fit: losses_centralized []
# INFO flower 2022-05-02 18:29:16,328 | app.py:152 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.6788757778575973

# %%
#TODO, revisar todo y probar funcionamiento, ver Cpus, etc
